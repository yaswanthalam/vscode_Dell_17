# %% [markdown]
# https://www.youtube.com/watch?v=2IsF7DEtVjg&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=9

# %% [markdown]
# # **Dictionary**

# %% [markdown]
# # **The keys in the dictionary are immutable**

# %%
data = {'A':105, 'B':'Yaswanth', 4:'Naveen'}

# %%
data
# Out:
# {'A': 105, 'B': 'Yaswanth', 4: 'Naveen'}

# %%
data['A']
# Out:
# 105

# %%
hello={1:10, 2:'habhah',3:5855}

# %%
hello
# Out:
# {1: 10, 2: 'habhah', 3: 5855}

# %%
hello[1]
# Out:
# 10

# %%
hello[2]
# Out:
# 'habhah'

# %%
hello[3]
# Out:
# 5855

# %%
hello.get(1)
# Out:
# 10

# %%
hello.get(2)
# Out:
# 'habhah'

# %%
hello.get(10)

# %%
hello.items()
# Out:
# dict_items([(1, 10), (2, 'habhah'), (3, 5855)])

# %%
hello.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
hello.values()
# Out:
# dict_values([10, 'habhah', 5855])

# %%
hello.get(30,'Not Found')
# Out:
# 'Not Found'

# %%
hello.get(30)
print(hello.get(30))
# Out:
# None

# %%
hello.popitem(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1807877456.py in <cell line: 0>()
# ----> 1 hello.popitem(3)
#
# TypeError: dict.popitem() takes no arguments (1 given)

# %%
hello
# Out:
# {1: 10, 2: 'habhah', 3: 5855}

# %%
hello.pop(1)
# Out:
# 10

# %%
hello
# Out:
# {2: 'habhah', 3: 5855}

# %%
keys=['a','b','c']
values=['hello','hen','duck']

# %%
azure=dict(zip(keys, values))
azure
# Out:
# {'a': 'hello', 'b': 'hen', 'c': 'duck'}

# %%
azure
# Out:
# {'a': 'hello', 'b': 'hen', 'c': 'duck'}

# %%
azure
# Out:
# {'a': 'hello', 'b': 'hen', 'c': 'duck'}

# %%
azure['a']
# Out:
# 'hello'

# %%
azure['b']
# Out:
# 'hen'

# %% [markdown]
# # **Nested dictionary**

# %%
prog={'js':'atom','cs':'vs','puthon':['pycharm','sublime'], 'java':{'JSE':'netbeans'}}
prog
# Out:
# {'js': 'atom',
#  'cs': 'vs',
#  'puthon': ['pycharm', 'sublime'],
#  'java': {'JSE': 'netbeans'}}

# %%
prog['js']
# Out:
# 'atom'

# %%
prog
# Out:
# {'js': 'atom',
#  'cs': 'vs',
#  'puthon': ['pycharm', 'sublime'],
#  'java': {'JSE': 'netbeans'}}

# %%
prog['cs']
# Out:
# 'vs'

# %%
prog['java']
# Out:
# {'JSE': 'netbeans'}

# %%
prog['puthon']
# Out:
# ['pycharm', 'sublime']
