# %% [markdown]
# # **Why Numpy? Installing Numpy in Pycharm**

# %% [markdown]
# https://www.youtube.com/watch?v=8LlXhtfNZEQ&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=34

# %% [markdown]
# **Why NUMPY and how to install NUMPY ?**

# %% [markdown]
# # **multi Dimensional array, multiple arrays and columns **

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from array import *

arr = array('i',[1,2,3],[2,5,4])

print(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-948379552.py in <cell line: 0>()
#       1 from array import *
#       2
# ----> 3 arr = array('i',[1,2,3],[2,5,4])
#       4
#       5 print(arr)
#
# TypeError: array() takes at most 2 arguments (3 given)

# %%
# !pip install numpy
from numpy import *

arr = array([1,2,3,2,5,4])

print(arr)
# Out:
# ...
# [1 2 3 2 5 4]

# %%
# !pip install numpy
from numpy import *

arr = array([1,2,3,2,5,4],int)

print(arr)
# Out:
# ...
# [1 2 3 2 5 4]

# %%
# !pip install numpy
from numpy import *

arr = array('i',[1,2,3],[2,5,4])

print(arr)
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-958691008.py in <cell line: 0>()
#       2 from numpy import *
#       3
# ----> 4 arr = array('i',[1,2,3],[2,5,4])
#       5
#       6 print(arr)
#
# TypeError: array() takes from 1 to 2 positional arguments but 3 were given

# %%
import numpy

# %%
from numpy import *

arr = array([1,2,3,2,5,4])

print(arr)
# Out:
# [1 2 3 2 5 4]
