# %% [markdown]
# https://www.youtube.com/watch?v=TqPzwenhMj0&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=6

# %% [markdown]
# # **Variables in python**

# %%
2+3
# Out:
# 5

# %%
5+8
# Out:
# 13

# %%
1+1
# Out:
# 2

# %%
x=2
x+3
# Out:
# 5

# %%
y=3
x+y
# Out:
# 5

# %%
x=9
x+y
# Out:
# 12

# %%
z=x+y
z
# Out:
# 12

# %%
z
# Out:
# 12

# %%
x+10
# Out:
# 19

# %%
name='youtube'
name
# Out:
# 'youtube'

# %%
hello=name + 'rocks'
hello
# Out:
# 'youtuberocks'

# %%
hello
# Out:
# 'youtuberocks'

# %%
hello[0]
# Out:
# 'y'

# %%
hello[6]
# Out:
# 'e'

# %%
hello[-1]
# Out:
# 's'

# %%
hello[-2]
# Out:
# 'k'

# %%
hello[0:2]
# Out:
# 'yo'

# %%
hello[1:4]
# Out:
# 'out'

# %%
hello[2:6]
# Out:
# 'utub'

# %%
hello[1:]
# Out:
# 'outuberocks'

# %%
hello[:3]
# Out:
# 'you'

# %%
hello[:-3]
# Out:
# 'youtubero'

# %%
hello
# Out:
# 'youtuberocks'

# %%
hello[3:10]
# Out:
# 'tuberoc'

# %%
hello[3:100]
# Out:
# 'tuberocks'

# %% [markdown]
# # **Strings in Python are immutable**

# %%
hello[0:3]='my'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3597961355.py in <cell line: 0>()
# ----> 1 hello[0:3]='my'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# The error TypeError: 'str' object does not support item assignment occurs because strings in Python are immutable. This means you cannot change individual characters or slices of an existing string.
#
# To achieve a similar result, you need to create a new string by concatenating the desired parts. Here's how you can replace the first three characters of the hello string:

# %%
hello[0]='R'

# %%
'my'+hello[3:6]

# %%
hello

# %%
'yaswanth'+ hello[0:10]

# %%
hello

# %%
hello[0:5]='test'

# %%
'test'+hello

# %%
len(hello)

# %%
len(hello)

# %% [markdown]
# https://www.youtube.com/watch?v=_OZIAHg5i7M&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=13

# %% [markdown]
# # **More on variables**
#
# # **#9 Python Tutorial for Beginners | More on Variables in Python**

# %%
num=5
num

# %%
num1=10
num1

# %%
hen=num+num1
hen

# %%
id(num)

# %%
id(num1)

# %%
id2='yaswanth'
id2

# %%
id(id2)

# %%
a=10
b=a
b

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2167009006.py in <cell line: 0>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1685013873.py in <cell line: 0>()
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
id(a)

# %%
id(b)

# %%
k=10
k

# %%
id(k)

# %%
a

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1685013873.py in <cell line: 0>()
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
a=9
id(a)

# %%
b=15255
id(b)

# %%
c=0.5
id(c)

# %%
z='nsjfnsjsn'
id(z)

# %%
pi=3.14
id(pi)

# %%
id(pi)

# %%
pi=6.5
id(pi)
