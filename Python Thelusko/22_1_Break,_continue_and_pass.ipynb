# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.youtube.com/watch?v=JCRpVwtVL4I&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=28

# %%
for i in range(5):

  if i==3:
    break
  print("Hello",i)
# Out:
# Hello 0
# Hello 1
# Hello 2

# %%
for i in range(50):

  if i==10:
    break
  print("Hello",i)
# Out:
# Hello 0
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5
# Hello 6
# Hello 7
# Hello 8
# Hello 9

# %%
for i in range(50):

  if i==10:
    continue
  print("Hello",i)
# Out:
# Hello 0
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5
# Hello 6
# Hello 7
# Hello 8
# Hello 9
# Hello 11
# Hello 12
# Hello 13
# Hello 14
# Hello 15
# Hello 16
# Hello 17
# Hello 18
# Hello 19
# Hello 20
# Hello 21
# Hello 22
# Hello 23
# Hello 24
# Hello 25
# Hello 26
# Hello 27
# Hello 28
# Hello 29
# Hello 30
# Hello 31
# Hello 32
# Hello 33
# Hello 34
# Hello 35
# Hello 36
# Hello 37
# Hello 38
# Hello 39
# Hello 40
# Hello 41
# Hello 42
# Hello 43
# Hello 44
# Hello 45
# Hello 46
# Hello 47
# Hello 48
# Hello 49
