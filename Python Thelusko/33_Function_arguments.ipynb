# %% [markdown]
# https://www.youtube.com/watch?v=ijXMGpoMkhQ&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=39

# %% [markdown]
# # **33- Function Arguments in Python**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def update(x):
  x=8
  print(x)

update(10)
# Out:
# 8

# %%
def update(x):
  x=8
  print(x)

update(10)
# Out:
# 8

# %%
def update(x):
  x=8
  print(x)

a=10
update(a)
# Out:
# 8

# %%
def update(x):
  x=8
  print("x", x)

a=1
update(a)
print("Y", a)
# Out:
# x 8
# Y 1

# %%
a="yaswanth"
print("the value ", a)
# Out:
# the value  yaswanth

# %%
def update(x):
  x=8,9
  print("x", x)

a=1
update(a)
print("Y", a)
# Out:
# x (8, 9)
# Y 1

# %%
def update(x):
  x=8,9
  print("x", x)

update(a)
# Out:
# x (8, 9)

# %%
def update(x):
  x=8,9
  print(x)

update(a)
# Out:
# (8, 9)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def update(x):
  print(id(x))
  x=8,9
  print(x)

update(a)
print(id(a))
# Out:
# 11654376
# (8, 9)
# 11654376

# %%
def update(x):
  print(id(x))
  x=8,9,8966
  print(x)

update(a)
print(id(a))
# Out:
# 11654376
# (8, 9, 8966)
# 11654376

# %%
def update(lst):

  lst[1]=25
  print(lst)

lst=[1,8,2,6,32,5,5]
update(lst)
# Out:
# [1, 25, 2, 6, 32, 5, 5]

# %%
def update(lst):

  print(lst)

lst=[1,8,2,6,32,5,5]
update(lst)
# Out:
# [1, 8, 2, 6, 32, 5, 5]

# %%
def update(str):
  print(str)

str={1,4,7,5,4,8,7}
update(str)
# Out:
# {1, 4, 5, 7, 8}

# %%
def yaswanth(lst):
  print(lst)

lst=[1,8,5,2,98,0,25,85,5]
yaswanth(lst)
# Out:
# [1, 8, 5, 2, 98, 0, 25, 85, 5]
