# %%
from array import *
vals = array('i',[5,5,0,8,9,2])
print(vals)
# Out:
# array('i', [5, 5, 0, 8, 9, 2])

# %%
from array import *

vals = array('I',(855,2,5,2,65,5,956526,65652652,4,59652))
print(vals)
# Out:
# array('I', [855, 2, 5, 2, 65, 5, 956526, 65652652, 4, 59652])

# %%
from array import *
vals = array('i',[5,9.5,4,2])
print(vals)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from array import *
# ----> 2 vals = array('i',[5,9.5,4,2])
#       3 print(vals)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
from array import *
vals = array('I',[5,-9,4,2])
print(vals)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[4], line 2
#       1 from array import *
# ----> 2 vals = array('I',[5,-9,4,2])
#       3 print(vals)
#
# OverflowError: can't convert negative value to unsigned int

# %%
from array import *
vals = array('i',[5,-9,4,2])
print(vals.reverse())
# Out:
# None

# %% [markdown]
# vals.rerverse and print should be given seperately.

# %%
from array import *
vals = array('i',[5,-9,4,2])
vals.reverse()
print(vals)
# Out:
# array('i', [2, 4, -9, 5])
