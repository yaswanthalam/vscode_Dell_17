# %% [markdown]
# # **32-Functions in Python**

# %% [markdown]
# https://www.youtube.com/watch?v=BVfCWuca9nw&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=38

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In function we have to call it everytime when it completes it.
#
#
# def greet():
#
#   print("Hello")
#
#   print("Good Morning")
#
# Above steps are for defining the function
#
# greet()
#
#
# This is for calling an function

# %%
def greet():
  print("Hello")
  print("Good Morning")

greet()
# Out:
# Hello
# Good Morning

# %%
def yaswanth():
  print("I am an network enginer")
  print("I work for MSFT")

yaswanth()
# Out:
# I am an network enginer
# I work for MSFT

# %%
def  hello():
  print("I am learning")

hello()
# Out:
# I am learning

# %%
def  hello():
  print("I am learninf")

hello()

hello()
# Out:
# I am learninf
# I am learninf

# %%
def greet():
  print("Hello")
  print("Good Morning")

def add(x,y):
  z=x+y
  print(z)

add(5,4)
greet()
# Out:
# 9
# Hello
# Good Morning

# %%
def greet():
  print("Hello")
  print("Good Morning")

def add(x,y):
  z=x+y
  return z

add(5,4)
result = add(5,10)
print(result)
greet()
# Out:
# 15
# Hello
# Good Morning

# %%
def add(x,y):
  z=x+y
  return z

add(5,4)
result = add(5,10)
print(result)
# Out:
# 15

# %%
def add(x,y):
  z=x+y
  return z

result1=add(5,1)
result2=add(9,45)
print(result1, result2)
# Out:
# 6 54

# %%
def add_sub(x,y):
  z=x+y
  m=x-y
  return z,m

result1, result2 = add_sub(5,10)
print(result1 , result2)
# Out:
# 15 -5
