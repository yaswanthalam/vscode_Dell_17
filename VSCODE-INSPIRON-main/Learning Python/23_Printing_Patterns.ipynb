# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.youtube.com/watch?v=k8SXsT5TLxQ&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=30

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("#", end=" ")
print("#", end=" ")
print("#", end=" ")
print("#", end=" ")
# Out:
# # # # #

# %%
i=1
while i<=4:
  print('#')
  i=i+1
# Out:
# #
# #
# #
# #

# %%
i=1
while i<=4:
  print('# # # #')
  i=i+1
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
i=1
while i<=4:
  print('#', end=" ")
  i=i+1
# Out:
# # # # #

# %% [markdown]
# # **The range starts from 0 and end at 3 that is the value of range (4)**

# %%
for j in range(4):
  print("#",end=" ")
# Out:
# # # # #

# %%
for j in range(4):
  print("#",end=" ")

print()

for j in range(4):
  print("#",end=" ")

print()

for j in range(4):
  print("#",end=" ")
# Out:
# # # # #
# # # # #
# # # # #

# %%
for i in range(4):
  for j in range(4):
    print("#",end=" ")
  print()
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(5):
  for j in range(i):
    print("#",end=" ")
  print()
# Out:
# #
# # #
# # # #
# # # # #

# %%
for i in range(4):
  for j in range(i+1):
    print("#",end=" ")
  print()
# Out:
# #
# # #
# # # #
# # # # #

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(4):
  for j in range(i):
    print("#",end=" ")
  print()
# Out:
# #
# # #

# %%
for i in range(4):
  for j in range(4-i):
    print("#",end=" ")
  print()
# Out:
# # # # #
# # # #
# # #
# #

# %%
for i in range(5):
  for j in range(0+i):
    print("#",end=" ")
  print()
# Out:
# #
# # #
# # # #
# # # # #

# %%
for i in range(4):
  for j in range(4+i):
    print("#",end=" ")
  print()
# Out:
# # # # #
# # # # # #
# # # # # # #
# # # # # # # #

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(4):
  for j in range(4):
    print("j",end="")
  print()
# Out:
# jjjj
# jjjj
# jjjj
# jjjj

# %%
x=["1,2,3,4"]
for i in x:
  print(i)

# %%
x=["1,2,3,4"]
for i in x:
  print(i)
# Out:
# 1,2,3,4

# %%
for i in range(1, 5):
    # The inner loop prints numbers from i to 4
    for j in range(i, 5):
        print(j, end="")
    print() # Newline after each row
# Out:
# 1234
# 234
# 34
# 4

# %%
for i in range(4):
    for j in range(4):
        if(i<j):
            print(chr(65+14+j), end=" ")
        else :
            print(chr(65+j), end=" ")
    print()
# Out:
# A P Q R
# A B Q R
# A B C R
# A B C D
