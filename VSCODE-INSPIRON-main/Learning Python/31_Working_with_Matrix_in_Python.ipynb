# %% [markdown]
# # **31-Working with Matrix in Python**

# %% [markdown]
# https://www.youtube.com/watch?v=Blzp9iuhZqo&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=37

# %% [markdown]
# # **The reason for using NUMPY was MULTI DIMENSIONAL ARRAY.  **
#
#
# # **For an regular arrays we can ARRAY function. **

# %%
from numpy import *

arr1 = array([

              [1,2,3],
              [4,5,6]

])

print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
from numpy import *

arr1 = array([

              [1,2,3],
              [4,5,6]

])

print(arr1.dtype)
# Out:
# int64

# %%
from numpy import *

arr1 = array([

              [1,2,3],
              [4,5,6]

])

print(arr1.ndim)
# Out:
# 2

# %%
from numpy import *

arr1 = array([

              [1,2,3],
              [4,5,6]

])

print(arr1.shape)
# Out:
# (2, 3)

# %%
from numpy import *

arr1 = array([

              [1,2,3],
              [4,5,6]

])

print(arr1.size)
# Out:
# 6

# %%
from numpy import *

arr1 = array([

              [1,2,3],
              [4,5,6]

])

arr2= arr1.flatten()

print(arr2)
print(arr1)
# Out:
# [1 2 3 4 5 6]
# [[1 2 3]
#  [4 5 6]]

# %%
from numpy import *

arr1 = array([

              [1,2,3],
              [4,5,6]

])

arr2= arr1.flatten()

print(arr2)
# Out:
# [1 2 3 4 5 6]

# %%
from numpy import *

arr1 = array([

              [1,2,3,9,10],
              [4,5,6,18,45]

])

arr2= arr1.flatten()

print(arr2)
# Out:
# [ 1  2  3  9 10  4  5  6 18 45]

# %%
from numpy import *

arr1 = array([

              [1,2,3,9,10],
              [4,5,6,18]

])

arr2= arr1.flatten()

print(arr2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1274408906.py in <cell line: 0>()
#       1 from numpy import *
#       2
# ----> 3 arr1 = array([
#       4
#       5               [1,2,3,9,10],
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.

# %%
from array import *

arr1 = array([

              [1,2,3,9,10],
              [4,5,6,18,45]

])

arr2= arr1.flatten()

print(arr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2291320722.py in <cell line: 0>()
#       1 from array import *
#       2
# ----> 3 arr1 = array([
#       4
#       5               [1,2,3,9,10],
#
# TypeError: array() argument 1 must be a unicode character, not list

# %%
from numpy import *

arr1 = array([

              [1,2,3,9,6,89],
              [4,5,6,18,45,86]

])

arr2= arr1.flatten()

arr3= arr2.reshape(3,4)

print(arr3)
# Out:
# [[ 1  2  3  9]
#  [ 6 89  4  5]
#  [ 6 18 45 86]]

# %%
from numpy import *

arr1 = array([

              [1,2,3,9,6,89],
              [4,5,6,18,45,86]

])

arr2= arr1.flatten()

arr3= arr2.reshape(2,2,3)

print(arr3)
# Out:
# [[[ 1  2  3]
#   [ 9  6 89]]
#
#  [[ 4  5  6]
#   [18 45 86]]]

# %%
from numpy import *

arr1 = array([

              [1,2,3],
              [4,5,6]

])

m=matrix(arr1)

print(m)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
from numpy import *

arr1 = array([

              [1,2,3],
              [4,5,6]

])

m=matrix('1 2 3 6; 4 5 8 9')

print(m)
# Out:
# [[1 2 3 6]
#  [4 5 8 9]]

# %%
from numpy import *


m=matrix('1 2 3 6; 4 5 8 9')

print(m)
# Out:
# [[1 2 3 6]
#  [4 5 8 9]]

# %%
from numpy import *


m=matrix('1 2 3 6; 4 5 8 9; 74,52,8,966')

print(m)
# Out:
# [[  1   2   3   6]
#  [  4   5   8   9]
#  [ 74  52   8 966]]

# %%
from numpy import *


m=matrix('1 2 3 6; 4 5 8 9; 74,52,8,966')

print(diagonal(m))
# Out:
# [1 5 8]

# %%
from numpy import *


m=matrix('1 2 3 6; 4 5 8 9; 74,52,8,966')

print(m.min())
# Out:
# 1

# %%
from numpy import *


m=matrix('1 2 3 6; 4 5 8 9; 74,52,8,966')

print(m.max())
# Out:
# 966

# %%
from numpy import *


m=matrix('1 2 3 6; 4 5 8 9; 74,52,8,966')

print(m.sum())
# Out:
# 1138

# %%
from numpy import *


m1=matrix('1 2; 4 5')

m2=matrix('1 2; 4 5')
m3=m1*m2;

print(m3)
# Out:
# [[ 9 12]
#  [24 33]]

# %%
from numpy import *


m1=matrix('1 2 8; 4 5 9; 89 52 1')

m2=matrix('1 2 4; 4 5 0; 4 7 4')
m3=m1*m2;

print(m3)
# Out:
# [[ 41  68  36]
#  [ 60  96  52]
#  [301 445 360]]

# %%
from numpy import *


m1=matrix('1 2 8; 4 5 9; 89 52 1')

m2=matrix('1 2 4; 4 5 0; 4 7 4')
m3=m1*m2

print(m3)
# Out:
# [[ 41  68  36]
#  [ 60  96  52]
#  [301 445 360]]

# %%
from numpy import *


m1=matrix('1 2 8; 4 5 9; 89 52 1')

m2=matrix('1 2 4; 4 5 0; 4 7 4')
m3=m1+m2

print(m3)
# Out:
# [[ 2  4 12]
#  [ 8 10  9]
#  [93 59  5]]

# %%
from numpy import *


m1=matrix('1 2 8; 4 5 9; 89 52 1')

m2=matrix('1 2 4; 4 5 0; 4 7 4')
m3=m1-m2

print(m3)
# Out:
# [[ 0  0  4]
#  [ 0  0  9]
#  [85 45 -3]]

# %%
from numpy import *


m1=matrix('1 2 8; 4 5 9; 89 52 1')

m2=matrix('1 2 4; 4 5 0; 4 7 4')
m3=m1/m2

print(m3)
# Out:
# [[ 1.          1.          2.        ]
#  [ 1.          1.                 inf]
#  [22.25        7.42857143  0.25      ]]
# /tmp/ipython-input-2818745806.py:7: RuntimeWarning: divide by zero encountered in divide
#   m3=m1/m2

# %%
from numpy import *


m1=matrix('1 2 8; 4 5 9; 89 52 1')

m2=matrix('1 2 4; 4 5 0; 4 7 4')
m3=m1%m2

print(m3)
# Out:
# [[0 0 0]
#  [0 0 0]
#  [1 3 1]]
# /tmp/ipython-input-1963818252.py:7: RuntimeWarning: divide by zero encountered in remainder
#   m3=m1%m2
