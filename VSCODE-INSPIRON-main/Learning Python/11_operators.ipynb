# %% [markdown]
# Here’s a complete list of **operators in Python** grouped by category with examples:
#
# ---
#
# ### 🔢 **1. Arithmetic Operators**
#
# Used for basic mathematical operations.
#
# | Operator | Description    | Example       |
# | -------- | -------------- | ------------- |
# | `+`      | Addition       | `3 + 2 → 5`   |
# | `-`      | Subtraction    | `5 - 2 → 3`   |
# | `*`      | Multiplication | `2 * 3 → 6`   |
# | `/`      | Division       | `5 / 2 → 2.5` |
# | `//`     | Floor Division | `5 // 2 → 2`  |
# | `%`      | Modulus        | `5 % 2 → 1`   |
# | `**`     | Exponentiation | `2 ** 3 → 8`  |
#
# ---
#
# ### ⚖️ **2. Comparison (Relational) Operators**
#
# Used to compare values; returns `True` or `False`.
#
# | Operator | Description      | Example          |
# | -------- | ---------------- | ---------------- |
# | `==`     | Equal            | `5 == 5 → True`  |
# | `!=`     | Not equal        | `5 != 3 → True`  |
# | `>`      | Greater than     | `5 > 3 → True`   |
# | `<`      | Less than        | `5 < 3 → False`  |
# | `>=`     | Greater or equal | `5 >= 5 → True`  |
# | `<=`     | Less or equal    | `5 <= 3 → False` |
#
# ---
#
# ### 🔁 **3. Assignment Operators**
#
# Used to assign values to variables.
#
# | Operator | Description         | Example              |
# | -------- | ------------------- | -------------------- |
# | `=`      | Assign              | `x = 5`              |
# | `+=`     | Add and assign      | `x += 1` (x = x + 1) |
# | `-=`     | Subtract and assign | `x -= 1`             |
# | `*=`     | Multiply and assign | `x *= 2`             |
# | `/=`     | Divide and assign   | `x /= 2`             |
# | `//=`    | Floor divide assign | `x //= 2`            |
# | `%=`     | Modulus assign      | `x %= 2`             |
# | `**=`    | Power assign        | `x **= 2`            |
#
# ---
#
# ### 🧠 **4. Logical Operators**
#
# Used to combine conditional statements.
#
# | Operator | Description | Example                  |
# | -------- | ----------- | ------------------------ |
# | `and`    | Logical AND | `True and False → False` |
# | `or`     | Logical OR  | `True or False → True`   |
# | `not`    | Logical NOT | `not True → False`       |
#
# ---
#
# ### 🔤 **5. Identity Operators**
#
# Compare memory locations (object identity).
#
# | Operator | Description       | Example      |
# | -------- | ----------------- | ------------ |
# | `is`     | Same object       | `x is y`     |
# | `is not` | Different objects | `x is not y` |
#
# ---
#
# ### 🔎 **6. Membership Operators**
#
# Check if a value is present in a sequence (like list, string, tuple).
#
# | Operator | Description         | Example                     |
# | -------- | ------------------- | --------------------------- |
# | `in`     | Present in sequence | `'a' in 'apple' → True`     |
# | `not in` | Not present         | `'x' not in 'apple' → True` |
#
# ---
#
# ### ⚙️ **7. Bitwise Operators**
#
# Operate on bits (used in low-level programming).
#
# | Operator | Description      | Example       |     |         |
# | -------- | ---------------- | ------------- | --- | ------- |
# | `&`      | AND              | `5 & 3 → 1`   |     |         |
# | \`       | \`               | OR            | \`5 | 3 → 7\` |
# | `^`      | XOR              | `5 ^ 3 → 6`   |     |         |
# | `~`      | NOT (complement) | `~5 → -6`     |     |         |
# | `<<`     | Left shift       | `5 << 1 → 10` |     |         |
# | `>>`     | Right shift      | `5 >> 1 → 2`  |     |         |
#
# ---
#
# Would you like a printable cheat sheet or a diagram version?

# %% [markdown]
# https://www.youtube.com/watch?v=v5MR5JnKcZI&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=15

# %% [markdown]
# # **Operators in Python**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=2
y=3
c=x+y
c
# Out:
# 5

# %%
d=c*10
d
# Out:
# 50

# %%
x+y
# Out:
# 5

# %%
x-y
# Out:
# -1

# %%
x*y
# Out:
# 6

# %%
x/y
# Out:
# 0.6666666666666666

# %%
x=x+10
x
# Out:
# 22

# %%
y
# Out:
# 3

# %%
x+=2
x
# Out:
# 26

# %%
x*=3
x
# Out:
# 78

# %%
a,b=5,6

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
a=5
b=6
a,b=b,a
print(a,b)
# Out:
# 6 5

# %% [markdown]
# # **unary opeartor**

# %%
n=7
n
# Out:
# 7

# %%
-n
# Out:
# -7

# %%
n
# Out:
# 'm'

# %%
x=5
y=6

# %%
x<y
# Out:
# True

# %%
x>y
# Out:
# False

# %%
x==y
# Out:
# False

# %%
x<=y
# Out:
# True

# %%
x>=y
# Out:
# False

# %%
x!=y
# Out:
# True

# %%
x=!y

# %%
x
# Out:
# ['/bin/bash: line 1: y: command not found']

# %%
y
# Out:
# 6

# %% [markdown]
# # **LOgical Operators**

# %% [markdown]
# # **AND operator id denoted as   '&'**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a=6
b=4

# %%
a<10 & b<5
# Out:
# False

# %%
a>10 & b<5
# Out:
# True

# %% [markdown]
# # **OR Operator**

# %% [markdown]
# OR operator
#
# ![image.png](data:image/png;base64,...)

# %%
x=6
y=52

x>6 | y<145
# Out:
# False
