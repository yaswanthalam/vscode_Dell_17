# %% [markdown]
# # **list are mutable and they are defined in the [ ]. **
#
# # **so use them wisely **

# %% [markdown]
# https://www.youtube.com/watch?v=Eaz5e6M8tL4&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=7

# %% [markdown]
# # **List**

# %% [markdown]
# If we have numbers and variables and if we want to group them together we will use lists

# %%
nums=[25, 12, 36, 95, 14, 'yas']
nums
# Out:
# [25, 12, 36, 95, 14, 'yas']

# %%
nums
# Out:
# [25, 12, 36, 95, 14, 'yas']

# %%
nums[0]
# Out:
# 25

# %%
nums[0:10]
# Out:
# [25, 12, 36, 95, 14, 'yas']

# %%
nums[1:5]
# Out:
# [12, 36, 95, 14]

# %%
nums[-1]
# Out:
# 'yas'

# %%
nums[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2335047925.py in <cell line: 0>()
# ----> 1 nums[8]
#
# IndexError: list index out of range

# %%
nums[4]
# Out:
# 14

# %%
nums[-1]
# Out:
# 'yas'

# %%
nums[-2]
# Out:
# 14

# %%
nums[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1608244755.py in <cell line: 0>()
# ----> 1 nums[-10]
#
# IndexError: list index out of range

# %%
names=['yas','kiran','josh']

# %%
names
# Out:
# ['yas', 'kiran', 'josh']

# %%
nums
# Out:
# [25, 12, 36, 95, 14, 'yas']

# %%
mil=[names,nums]
mil
# Out:
# [['yas', 'kiran', 'josh'], [25, 12, 36, 95, 14, 'yas']]

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'], [25, 12, 36, 95, 14, 'yas']]

# %% [markdown]
# # **Lists are mutable**

# %%
mil.append(45)
mil
# Out:
# [['yas', 'kiran', 'josh'], [25, 12, 36, 95, 14, 'yas'], 45, 45]

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'], [25, 12, 36, 95, 14, 'yas'], 45, 45]

# %%
mil.append('nani')
mil
# Out:
# [['yas', 'kiran', 'josh'], [25, 12, 36, 95, 14, 'yas'], 45, 45, 'nani', 'nani']

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'], [25, 12, 36, 95, 14, 'yas'], 45, 45, 'nani', 'nani']

# %%
mil.append('xyz')

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'nani',
#  'xyz']

# %%
mil.append('pen')
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'nani',
#  'xyz',
#  'pen',
#  'pen']

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'nani',
#  'xyz',
#  'pen',
#  'pen']

# %%
mil.append('hen')

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'nani',
#  'xyz',
#  'pen',
#  'pen',
#  'hen']

# %% [markdown]
# # **append adds value at the end of list**

# %%
mil.insert(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2391111339.py in <cell line: 0>()
# ----> 1 mil.insert(5)
#
# TypeError: insert expected 2 arguments, got 1

# %%
mil.insert(5,'ink')
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'ink',
#  'ink',
#  'nani',
#  'xyz',
#  'pen',
#  'pen',
#  'hen']

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'ink',
#  'ink',
#  'nani',
#  'xyz',
#  'pen',
#  'pen',
#  'hen']

# %%
mil.insert(0,'iron')

# %%
mil
# Out:
# ['iron',
#  ['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'ink',
#  'ink',
#  'nani',
#  'xyz',
#  'pen',
#  'pen',
#  'hen']

# %% [markdown]
# In the insert define the value that needs to be inserted at which place

# %%
mil.remove('pen')

# %%
mil
# Out:
# ['iron',
#  ['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'ink',
#  'ink',
#  'nani',
#  'xyz',
#  'pen']

# %%
mil
# Out:
# ['iron',
#  ['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'ink',
#  'ink',
#  'nani',
#  'xyz',
#  'pen']

# %%
mil.remove('ink')

# %%
mil
# Out:
# ['iron',
#  ['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'ink',
#  'nani',
#  'xyz',
#  'pen']

# %%
mil.remove('45')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2913257014.py in <cell line: 0>()
# ----> 1 mil.remove('45')
#
# ValueError: list.remove(x): x not in list

# %%
mil
# Out:
# ['iron',
#  ['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'nani',
#  'ink',
#  'nani',
#  'xyz',
#  'pen']

# %%
mil.pop(5)
# Out:
# 'nani'

# %%
mil
# Out:
# ['iron',
#  ['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  'nani',
#  'xyz',
#  'pen']

# %%
mil.pop(50)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3207746712.py in <cell line: 0>()
# ----> 1 mil.pop(50)
#
# IndexError: pop index out of range

# %%
mil
# Out:
# ['iron',
#  ['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  'nani',
#  'xyz',
#  'pen']

# %%
mil.pop(-1)
# Out:
# 'pen'

# %%
mil
# Out:
# ['iron',
#  ['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  'nani',
#  'xyz']

# %%
mil
# Out:
# ['iron',
#  ['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  'nani',
#  'xyz']

# %%
mil.pop(0)
# Out:
# 'iron'

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  'nani',
#  'xyz']

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  'nani',
#  'xyz']

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  'nani',
#  'xyz']

# %%
del.mil[6:]
# Out:
#   File "/tmp/ipython-input-154995900.py", line 1
#     del.mil[6:]
#        ^
# SyntaxError: invalid syntax

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  'nani',
#  'xyz']

# %%
del mil[7:]

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  'nani',
#  'xyz']

# %%
del mil[5:]

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'], [25, 12, 36, 95, 14, 'yas'], 45, 45, 'ink']

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'], [25, 12, 36, 95, 14, 'yas'], 45, 45, 'ink']

# %%
mil.extend (29,45,55515,7555)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3071593164.py in <cell line: 0>()
# ----> 1 mil.extend (29,45,55515,7555)
#
# TypeError: list.extend() takes exactly one argument (4 given)

# %%
mil.extend([5,5451,4515,8,9,6,8,6,8,6,8,5,8,5])

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  5,
#  5451,
#  4515,
#  8,
#  9,
#  6,
#  8,
#  6,
#  8,
#  6,
#  8,
#  5,
#  8,
#  5]

# %%
mil
# Out:
# [['yas', 'kiran', 'josh'],
#  [25, 12, 36, 95, 14, 'yas'],
#  45,
#  45,
#  'ink',
#  5,
#  5451,
#  4515,
#  8,
#  9,
#  6,
#  8,
#  6,
#  8,
#  6,
#  8,
#  5,
#  8,
#  5]

# %%
min(mil)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2295576845.py in <cell line: 0>()
# ----> 1 min(mil)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
hello=[8,7,5,8,2,8,9,1,5,85,8885,9696,36532,417825,9696969696,58258,456456,85963]

# %%
hello
# Out:
# [8,
#  7,
#  5,
#  8,
#  2,
#  8,
#  9,
#  1,
#  5,
#  85,
#  8885,
#  9696,
#  36532,
#  417825,
#  9696969696,
#  58258,
#  456456,
#  85963]

# %%
min(hello)
# Out:
# 1

# %%
max(hello)
# Out:
# 9696969696

# %%
sum(hello)
# Out:
# 9698043449

# %%
hello.sort()

# %%
hello
# Out:
# [1,
#  2,
#  5,
#  5,
#  7,
#  8,
#  8,
#  8,
#  9,
#  85,
#  8885,
#  9696,
#  36532,
#  58258,
#  85963,
#  417825,
#  456456,
#  9696969696]
