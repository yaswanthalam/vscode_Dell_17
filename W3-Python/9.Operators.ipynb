# %% [markdown]
# https://www.w3schools.com/python/python_operators.asp
#
# Python Operators
#
# Operators are used to perform operations on variables and values.
#
# In the example below, we use the + operator to add together two values:

# %%
print(10+5)
# Out:
# 15

# %%
sum1 = 545+55415

sum2 = sum1 + 65515

sum3 = sum1 + sum2

print(sum1 , sum2, sum3)
# Out:
# 55960 121475 177435

# %% [markdown]
# https://www.w3schools.com/python/python_operators_arithmetic.asp
#
#
# Arithmetic Operators
# Arithmetic operators are used with numeric values to perform common mathematical operations:
#
#
# Operator	Name	Example
# +	Addition	x + y
# -	Subtraction	x - y
# *	Multiplication	x * y
# /	Division	x / y
# %	Modulus	x % y
# **	Exponentiation	x ** y
# //	Floor division	x // y

# %%
x = 5
y = 10

print(x+y)
# Out:
# 15

# %%
x = 5
y = 10

print(x-y)
# Out:
# -5

# %%
x = 5
y = 10

print(x*y)
# Out:
# 50

# %%
x = 5
y = 10

print(x/y)
# Out:
# 0.5

# %%
x = 5
y = 10

print(x%y)
# Out:
# 5

# %%
x = 5
y = 10

print(x**y)
# Out:
# 9765625

# %%
x = 5
y = 10

print(x//y)
# Out:
# 0

# %%
x=2
y=5

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x % y)
print(x ** y)
print(x // y)
# Out:
# 7
# -3
# 10
# 0.4
# 2
# 32
# 0

# %% [markdown]
# Division in Python
# Python has two division operators:
#
# / - Division (returns a float)
# // - Floor division (returns an integer)

# %%
x=2
y=5

print(x/y)
print(x//y)
# Out:
# 0.4
# 0

# %% [markdown]
# Example
# Floor division always returns an integer.
#
# It rounds DOWN to the nearest integer:

# %%
x=5
y=8
print(x//y)
# Out:
# 0

# %%
x=2
y=3
print(x%y)
# Out:
# 2

# %% [markdown]
# https://www.w3schools.com/python/python_operators_assign.asp
#
#
# Assignment Operators
# Assignment operators are used to assign values to variables:
#
#
# Operator	Example	Same As
# #ERROR!	x = 5	x = 5
# #ERROR!	x += 3	x = x + 3
# -=	x -= 3	x = x - 3
# *=	x *= 3	x = x * 3
# /=	x /= 3	x = x / 3
# %=	x %= 3	x = x % 3
# //=	x //= 3	x = x // 3
# **=	x **= 3	x = x ** 3
# &=	x &= 3	x = x & 3
# |=	x |= 3	x = x | 3
# ^=	x ^= 3	x = x ^ 3
# >>=	x >>= 3	x = x >> 3
# <<=	x <<= 3	x = x << 3
# :=	print(x := 3)	"x = 3
# print(x)"
#
# ![image.png](attachment:image.png)

# %%
x=5

print(x)
# Out:
# 5

# %%
x=5
x+=3

print(x)
# Out:
# 8

# %%
x=5
x-=3

print(x)
# Out:
# 2

# %%
x=5
x*=3

print(x)
# Out:
# 15

# %%
x=5
x/=3

print(x)
# Out:
# 1.6666666666666667

# %%
x=5
x%=3

print(x)
# Out:
# 2

# %%
x=5
x//=3

print(x)
# Out:
# 1

# %%
x=5
x**=3

print(x)
# Out:
# 125

# %%
x=5
x&=3

print(x)
# Out:
# 1

# %%
x=5
x|=3

print(x)
# Out:
# 7

# %%
x=5
x^=3

print(x)
# Out:
# 6

# %%
x=5
x>>=3

print(x)
# Out:
# 0

# %%
x=5
x<<=3

print(x)
# Out:
# 40

# %%
x := 3

print(x)
# Out:
#   Cell In[18], line 1
#     x := 3
#       ^
# SyntaxError: invalid syntax

# %%
x := 3
print(x)
# Out:
#   Cell In[19], line 1
#     x := 3
#       ^
# SyntaxError: invalid syntax

# %%
if (x := 3) > 2:
    print(x)
# Out:
# 3

# %% [markdown]
# The Walrus Operator
# Python 3.8 introduced the := operator, known as the "walrus operator". It assigns values to variables as part of a larger expression:

# %%
alam = [5,2,5,2,5,84,484,5415,484,48]
count =len(alam)

if count > 3:
    print(f"List has {count} elements")

if (count := len((alam))) >3:
    print(f"list has {count} elements ")
# Out:
# List has 10 elements
# list has 10 elements

# %%
alam = [5,2,5,2,5,84,484,5415,484,48]
count =len(alam)

if count > 3:
    print(f"List has {count} elements")

if (count := len((alam))) >3:
    print(f"list has {count} elements ")
# Out:
# List has 10 elements
# list has 10 elements

# %%
alam = [1,8,9,5,7,2,5,6,32,1551,5151,5415,41,5,2,5,2,2]

# %%
alam = [1,8,5,5,2,9,6,10,20,30,5852,555,55]

count = len(alam)

if count > 3:
    print(f" The length of elements is {count} is the number")

if (count := len(alam)) >> 3:
    print(f" List has {count} elements")
# Out:
#  The length of elements is 13 is the number
#  List has 13 elements

# %% [markdown]
# https://www.w3schools.com/python/python_operators_comparison.asp
#
#
# Python Comparison Operators
#
#
# Operator	Name	Example
# ==	       Equal	x == y
# !=	       Not equal	x != y
# >	    Greater than	x > y
# <	       Less than	x < y
# >=	  Greater than or equal to	x >= y
# <=	   Less than or equal to	x <= y
#
#
# ![image.png](attachment:image.png)

# %%
x = 5
y = 3

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %%
x = 5

print(1 < x < 10)

print(1<x and x<10)
# Out:
# True
# True

# %%
y = 10

print(2 < y < 20)

print(1 < y and y > 40)

print(1 < 10 or y>52)
# Out:
# True
# False
# True

# %% [markdown]
# https://www.w3schools.com/python/python_operators_logical.asp
#
#
# Logical Operators
# Logical operators are used to combine conditional statements:
#
# ![image.png](attachment:image.png)

# %%
x = 5

print( x > 10 and x < 100)
# Out:
# False

# %%
x = 5

print( x > 3 and x < 100)
# Out:
# True

# %%
x = 5

print( x > 3 or x < 100)
# Out:
# True

# %%
x = 5

print( x > 10 or x < 100)
# Out:
# True

# %%
x = 5

print( x > 10 or x > 100)
# Out:
# False

# %%
x = 5

print(not(x > 3 and x < 10))
# Out:
# False

# %%
x = 5

print(not(x > 3 or x < 10))
# Out:
# False

# %%
if 5 == 10 or 1==1:
    print(" At least one of the statements are TRUE")
# Out:
#  At least one of the statements are TRUE

# %%
if 5 == 10 and 1==1:
    print(" At least one of the statements are TRUE")

else:
    print(" The least of the one statemnet  ")
# Out:
#  The least of the one statemnet

# %% [markdown]
# https://www.w3schools.com/python/python_operators_identity.asp
#
#
# Identity Operators
# Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location:
#
# ![image.png](attachment:image.png)

# %%
x  = ["Apple" , "Banana"]
y = ["Apple" , "Banana"]
z=x

print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# True

# %%
x  = ["Apple" , "Banana"]
y = ["Apple" , "banana"]
z=x

print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# False

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# True

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]

print(x is not y)
# Out:
# True

# %%
x = [1 , 2 , 45 , 55 , 6566]
y = [1 , 2 , 45 , 55 , 6566]

print(x is not y )

print(x and y)
# Out:
# True
# [1, 2, 45, 55, 6566]

# %%
x = [1 , 2 , 45 , 55 , 6566]
y = [1 , 2 , 45 , 55 , 65]

print(x is not y )

print(x and y)

print(x or y )

print(x is y)
# Out:
# True
# [1, 2, 45, 55, 65]
# [1, 2, 45, 55, 6566]
# False

# %% [markdown]
# Difference Between is and ==
# is - Checks if both variables point to the same object in memory
# == - Checks if the values of both variables are equal

# %%
x = [1 , 2 , 3]
y = [1 , 2 , 3]

print(x is y)
print(x == y)
# Out:
# False
# True

# %%
x = [1 , 2 , 4]
y = [1 , 2 , 3]

print(x is y)
print(x == y)
# Out:
# False
# False

# %%
x = [1 , 2 , 3]
y = [1 , 2 , 3]

x = y

print(x is y)
print(x == y)
# Out:
# True
# True

# %% [markdown]
# https://www.w3schools.com/python/python_operators_membership.asp
#
# Membership Operators
#
#
# ![image.png](attachment:image.png)

# %%
fruits = ["apple", "Banana", "Cherry"]

print("banana" in fruits)
# Out:
# False

# %%
fruits = ["apple", "Banana", "Cherry"]

print("Banana" in fruits)
# Out:
# True

# %%
fruits = ["apple", "Banana", "Cherry"]

print("apple" in fruits)
# Out:
# True

# %%
fruits = ["apple", "Banana", "Cherry"]

print("Cherry" in fruits)
# Out:
# True

# %%
abc = ["apple", "Mango", "Calcusl"]

print("apple" in abc)
# Out:
# True

# %%
if 5 == 5:
    print(" Both are equal")

else:
    print(" Both are not equal ")
# Out:
#  Both are equal

# %%
text = "Hello World"

print("h" in text)
print("hello" in text )
print("W" in text)
print("o" in text)
# Out:
# False
# False
# True
# True

# %%
fruits = ["apple", "5454", "vshgbsh"]

print("apple" in fruits)

print("5454" in fruits)
# Out:
# True
# True

# %%
fruits = ["apple", "5454", "vshgbsh"]

print("apple" not in fruits)
# Out:
# False

# %%
fruits = ["apple", "5454", "vshgbsh" , 45]

print("a" in fruits)
print(45 in fruits)
# Out:
# False
# True

# %%
fruits = ("apple", "5454", "vshgbsh" , 45)

print("a" in fruits)
print(45 in fruits)
# Out:
# False
# True

# %%
fruits = {"apple", "5454", "vshgbsh" , 45}

print("a" in fruits)
print(45 in fruits)
# Out:
# False
# True

# %% [markdown]
# https://www.w3schools.com/python/python_operators_bitwise.asp
#
#
# Python Bitwise Operators
#
#
# Operator	Name	Description	Example
# & 	AND	Sets each bit to 1 if both bits are 1	x & y
# |	OR	Sets each bit to 1 if one of two bits is 1	x | y
# ^	XOR	Sets each bit to 1 if only one of two bits is 1	x ^ y
# ~	NOT	Inverts all the bits	~x
# <<	Zero fill left shift	Shift left by pushing zeros in from the right and let the leftmost bits fall off	x << 2
# >>	Signed right shift	Shift right by pushing copies of the leftmost bit in from the left, and let the rightmost bits fall off	x >> 2
#
# ![image.png](attachment:image.png)

# %%
print(6 & 3)
print(6 | 3)
print(6 ^ 3)
print(6 >> 3)
print(6 << 3)
# Out:
# 2
# 7
# 5
# 0
# 48

# %% [markdown]
# https://www.w3schools.com/python/python_operators_precedence.asp
#
#
# Operator Precedence
#
# Operator precedence describes the order in which operations are performed.
#
# ExampleGet your own Python Server
#
# Parentheses has the highest precedence, meaning that expressions inside parentheses must be evaluated first:

# %%
print((6+3) - (6-3))
# Out:
# 6

# %%
print(100*6525+9)
# Out:
# 652509

# %%
print(525+545+155-5456+65125-625221+26265-6256)
# Out:
# -544318
