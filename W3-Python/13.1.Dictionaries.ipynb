# %% [markdown]
# https://www.w3schools.com/python/python_dictionaries_loop.asp
#
# Python - Loop Dictionaries
#
# Loop Through a Dictionary
#
# You can loop through a dictionary by using a for loop.
#
# When looping through a dictionary, the return value are the keys of the dictionary, but there are methods to return the values as well.

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x in thisdict:
  print(x)
# Out:
# brand
# model
# year

# %%
yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248}

for x in yas:
    print(x)
# Out:
# abc
# cdn
# 54
# he

# %%
yas = {"cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248}

for x in yas:
    print(yas[x])
# Out:
# boy
# 45
# henighe
# 845248

# %%
yas = {"cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248}

for x in yas:
    print(x)
    print(yas[x])
# Out:
# cdn
# boy
# 54
# 45
# he
# henighe
# abc
# 845248

# %% [markdown]
# Example
#
# You can also use the values() method to return values of a dictionary:

# %%
yas = {"cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248 , "xdfnsjf" :  "tyests"}

for x in yas.values():
    print(x)
# Out:
# boy
# 45
# henighe
# 845248
# tyests

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x in thisdict.values():
  print(x)
# Out:
# Ford
# Mustang
# 1964

# %%
yas = {"cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248 , "xdfnsjf" :  "tyests"}

for x in yas.keys():
    print(x)
# Out:
# cdn
# 54
# he
# abc
# xdfnsjf

# %%
yas = {"cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248 , "xdfnsjf" :  "tyests"}

for x in yas.values():
    print(x)
# Out:
# boy
# 45
# henighe
# 845248
# tyests

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x, y in thisdict.items():
  print(x, y)
# Out:
# brand Ford
# model Mustang
# year 1964

# %%
yas = {"cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248 , "xdfnsjf" :  "tyests"}

for x,y in yas.items():
    print(x, y)
# Out:
# cdn boy
# 54 45
# he henighe
# abc 845248
# xdfnsjf tyests

# %% [markdown]
# https://www.w3schools.com/python/python_dictionaries_copy.asp
#
#
# Python - Copy Dictionaries
#
# Copy a Dictionary
#
# You cannot copy a dictionary simply by typing dict2 = dict1, because: dict2 will only be a reference to dict1, and changes made in dict1 will automatically also be made in dict2.
#
# There are ways to make a copy, one way is to use the built-in Dictionary method copy().

# %% [markdown]
# Make a copy of a dictionary with the copy() method:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = thisdict.copy()
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
yas = {"cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248 , "xdfnsjf" :  "tyests"}

alam = yas.copy()

print(alam)
# Out:
# {'cdn': 'boy', 54: 45, 'he': 'henighe', 'abc': 845248, 'xdfnsjf': 'tyests'}

# %% [markdown]
# Another way to make a copy is to use the built-in function dict().
#
# Example
#
# Make a copy of a dictionary with the dict() function:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = dict(thisdict)
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
yas = {"cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248 , "xdfnsjf" :  "tyests"}

alam = dict(yas)

print(alam)
# Out:
# {'cdn': 'boy', 54: 45, 'he': 'henighe', 'abc': 845248, 'xdfnsjf': 'tyests'}

# %%
yas = {"cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248 , "xdfnsjf" :  "tyests"}

alam = yas.copy()

print(alam)
# Out:
# {'cdn': 'boy', 54: 45, 'he': 'henighe', 'abc': 845248, 'xdfnsjf': 'tyests'}

# %% [markdown]
# Dict and Copy do the same jon but the way we define them is different.

# %% [markdown]
# https://www.w3schools.com/python/python_dictionaries_nested.asp
#
#
# Python - Nested Dictionaries
#
# Nested Dictionaries
#
# A dictionary can contain dictionaries, this is called nested dictionaries.

# %%
yas =  {
    "yas" : {
        "Hello":"Hi",
        "test":"nskfmsflkm"
    },
    "alam" : {
        65254151 : 485415415,
        "jxbhfujdnf" : 545151
    },
    "network" : {
        "sbhsfbj" : 5454154,
        848485 : "zdhfgnejf"
    }
}


print(yas)
# Out:
# {'yas': {'Hello': 'Hi', 'test': 'nskfmsflkm'}, 'alam': {65254151: 485415415, 'jxbhfujdnf': 545151}, 'network': {'sbhsfbj': 5454154, 848485: 'zdhfgnejf'}}

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

print(myfamily)
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}

# %%
yas = {

    "child1" : {
        "sdfnsjfnj" : 545415615,
        "jzdjsijfgi": "jxbdfjdfnjdgn",
        5456151541 : "sbndfhfnsjisdjf"
    },
    "alam" : {
        5465415415 : 45415458458, 
        "sdfbhsdfbdj" : "snfjkndfkjdmgk",
        548485 : "al;am"
    }, 
    "test" : {
        81 : "sdfgndjndj",
        56454 : "Test isn azure is ywasnth="
    }
}

print(yas)
# Out:
# {'child1': {'sdfnsjfnj': 545415615, 'jzdjsijfgi': 'jxbdfjdfnjdgn', 5456151541: 'sbndfhfnsjisdjf'}, 'alam': {5465415415: 45415458458, 'sdfbhsdfbdj': 'snfjkndfkjdmgk', 548485: 'al;am'}, 'test': {81: 'sdfgndjndj', 56454: 'Test isn azure is ywasnth='}}

# %% [markdown]
# Or, if you want to add three dictionaries into a new dictionary:
#
# Example
# Create three dictionaries, then create one dictionary that will contain the other three dictionaries:

# %%
child1 = {
        "sdfnsjfnj" : 545415615,
        "jzdjsijfgi": "jxbdfjdfnjdgn",
        5456151541 : "sbndfhfnsjisdjf"
    },
child2 = {
        5465415415 : 45415458458, 
        "sdfbhsdfbdj" : "snfjkndfkjdmgk",
        548485 : "al;am"
    }, 
child3 = {
        81 : "sdfgndjndj",
        56454 : "Test isn azure is ywasnth="
    }

alam = {
    "child1" : child1,
    "child2" : child2,
    "child3" : child3
}

print(alam)
# Out:
# {'child1': ({'sdfnsjfnj': 545415615, 'jzdjsijfgi': 'jxbdfjdfnjdgn', 5456151541: 'sbndfhfnsjisdjf'},), 'child2': ({5465415415: 45415458458, 'sdfbhsdfbdj': 'snfjkndfkjdmgk', 548485: 'al;am'},), 'child3': {81: 'sdfgndjndj', 56454: 'Test isn azure is ywasnth='}}

# %%
yas = {
    "test" : 54545,
    "jszbndfjsdnfj" : "sfndfjndkjf"
},
alam= {
    545645458 : "sdfhsdfjbnjdk",
    "dnfjdfndjk" : 415415154154154
},
ndm = {
    5454 : "sfjbndfjndjg",
    "xcbdfnd" : 84541541515
}

abc = {
    "yas" : yas,
    "alam" : alam,
    "ndm" : ndm
}

print(abc)
# Out:
# {'yas': ({'test': 54545, 'jszbndfjsdnfj': 'sfndfjndkjf'},), 'alam': ({545645458: 'sdfhsdfjbnjdk', 'dnfjdfndjk': 415415154154154},), 'ndm': {5454: 'sfjbndfjndjg', 'xcbdfnd': 84541541515}}

# %% [markdown]
# Access Items in Nested Dictionaries
#
# To access items from a nested dictionary, you use the name of the dictionaries, starting with the outer dictionary:
#
# Example
#
# Print the name of child 2:

# %%
yas = {

    "child1" : {
        "sdfnsjfnj" : 545415615,
        "jzdjsijfgi": "jxbdfjdfnjdgn",
        5456151541 : "sbndfhfnsjisdjf"
    },
    "alam" : {
        5465415415 : 45415458458, 
        "sdfbhsdfbdj" : "snfjkndfkjdmgk",
        548485 : "al;am"
    }, 
    "test" : {
        81 : "sdfgndjndj",
        56454 : "Test isn azure is ywasnth="
    }
}

print(yas ["alam"][548485])
# Out:
# al;am

# %% [markdown]
# Loop Through Nested Dictionaries
#
# You can loop through a dictionary by using the items() method like this:
#
# Example
#
# Loop through the keys and values of all nested dictionaries:

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

for x, obj in myfamily.items():
    print(x)
    
    for y in obj:
        print(y + ':', obj[y])
# Out:
# child1
# name: Emil
# year: 2004
# child2
# name: Tobias
# year: 2007
# child3
# name: Linus
# year: 2011

# %%
yas = {

    "child1" : {
        "sdfnsjfnj" : "545415615",
        "jzdjsijfgi": "jxbdfjdfnjdgn",
        "5456151541" : "sbndfhfnsjisdjf"
    },
    "alam" : {
        "5465415415" : "45415458458", 
        "sdfbhsdfbdj" : "snfjkndfkjdmgk",
        "548485" : "al;am"
    }, 
    "test" : {
        "81" : "sdfgndjndj",
        "56454" : "Test isn azure is ywasnth="
    }
}

for x, obj in yas.items():
    print(x)

    for y in obj:
        print(y + ':', obj[y])
# Out:
# child1
# sdfnsjfnj: 545415615
# jzdjsijfgi: jxbdfjdfnjdgn
# 5456151541: sbndfhfnsjisdjf
# alam
# 5465415415: 45415458458
# sdfbhsdfbdj: snfjkndfkjdmgk
# 548485: al;am
# test
# 81: sdfgndjndj
# 56454: Test isn azure is ywasnth=

# %% [markdown]
# https://www.w3schools.com/python/python_dictionaries_methods.asp
#
#
# Python Dictionary Methods
#
#
# Python has a set of built-in methods that you can use on dictionaries.
#
# ![image.png](attachment:image.png)
