# %% [markdown]
# https://www.w3schools.com/python/python_tuples.asp
#
#
# Tuple
# Tuples are used to store multiple items in a single variable.
#
# Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage.
#
# A tuple is a collection which is ordered and unchangeable.
#
# Tuples are written with round brackets.

# %%
abc = ("snsjf",5151, "znsjfndjf", "5462652")
print(abc)
# Out:
# ('snsjf', 5151, 'znsjfndjf', '5462652')

# %% [markdown]
# Tuple Items
#
# Tuple items are ordered, unchangeable, and allow duplicate values.
#
# Tuple items are indexed, the first item has index [0], the second item has index [1] etc.
#
# Ordered
#
# When we say that tuples are ordered, it means that the items have a defined order, and that order will not change.
#
# Unchangeable
#
# Tuples are unchangeable, meaning that we cannot change, add or remove items after the tuple has been created.
#
# Allow Duplicates
#
# Since tuples are indexed, they can have items with the same value:

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')

# %% [markdown]
# Tuple Length
# To determine how many items a tuple has, use the len() function:
#
# Example
# Print the number of items in the tuple:

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(len(abc))
# Out:
# 12

# %% [markdown]
# Create Tuple With One Item
#
# To create a tuple with only one item, you have to add a comma after the item, otherwise Python will not recognize it as a tuple.

# %%
abc = ("yaswanth")

print(type(abc))
# Out:
# <class 'str'>

# %%
abc = ("yaswanth",)

print(type(abc))
# Out:
# <class 'tuple'>

# %% [markdown]
# Tuple Items - Data Types
#
# Tuple items can be of any data type:
#
# Example
#
# String, int and boolean data types:

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

amc = (1,2,3,4,5,2,5)

avc = (True, False, True)

print(abc)
print(amc)
print(avc)

print(abc, amc, avc)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')
# (1, 2, 3, 4, 5, 2, 5)
# (True, False, True)
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk') (1, 2, 3, 4, 5, 2, 5) (True, False, True)

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')

# %%
mytuple = ("apple", "banana", "cherry")
print(type(mytuple))
# Out:
# <class 'tuple'>

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(type(abc))
# Out:
# <class 'tuple'>

# %% [markdown]
# The tuple() Constructor
# It is also possible to use the tuple() constructor to make a tuple.
#
# Example
# Using the tuple() method to make a tuple:

# %%
thistuple = tuple(("apple", "banana", "cherry"))
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
abc = tuple(("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk"))

print(abc)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')

# %%
abc = tuple(("1256232"))
print(abc)
print(type(abc))
# Out:
# ('1', '2', '5', '6', '2', '3', '2')
# <class 'tuple'>

# %%
abc = tuple(("1256232",))
print(abc)
# Out:
# ('1256232',)

# %% [markdown]
# Python Collections (Arrays)
#
# There are four collection data types in the Python programming language:
#
# List is a collection which is ordered and changeable. Allows duplicate members.
#
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
#
# Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
#
# Dictionary is a collection which is ordered** and changeable. No duplicate members.

# %% [markdown]
# Access Tuple Items
#
# You can access tuple items by referring to the index number, inside square brackets:
#
# ExampleGet your own Python Server
#
# Print the second item in the tuple:

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[1])
# Out:
# alam

# %%
abc = tuple(("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk"))

print(abc [5])
# Out:
# 85

# %%
abc = tuple(("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk"))

print(abc [[5], [3]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 abc = tuple(("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk"))
# ----> 3 print(abc [[5], [3]])
#
# TypeError: tuple indices must be integers or slices, not tuple

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[5], abc[0])
# Out:
# 85 yaswanth

# %% [markdown]
# Negative Indexing
#
# Negative indexing means start from the end.
#
# -1 refers to the last item, -2 refers to the second last item etc.
#
# Example
#
# Print the last item of the tuple:

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[-5])
# Out:
# 4151515

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[-10])
# Out:
# alam

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[-1])
# Out:
# jk

# %% [markdown]
# Range of Indexes
#
# You can specify a range of indexes by specifying where to start and where to end the range.
#
# When specifying a range, the return value will be a new tuple with the specified items.
#
# Example
#
# Return the third, fourth, and fifth item:
#
# Note: The search will start at index 2 (included) and end at index 5 (not included).

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[2 : 8])
# Out:
# ('alam', 41, 41, '85', '85', '4151515')

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[ : 8])
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515')

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[6 : ])
# Out:
# ('85', '4151515', 0, 5451, 'and', 'jk')

# %% [markdown]
# Range of Negative Indexes
#
# Specify negative indexes if you want to start the search from the end of the tuple:
#
# Example
#
# This example returns the items from index -4 (included) to index -1 (excluded)

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[-4 : -1])
# Out:
# (0, 5451, 'and')

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[-10 : -1])
# Out:
# ('alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and')

# %% [markdown]
# Check if Item Exists
#
# To determine if a specified item is present in a tuple use the in keyword:

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc[-10 : -1])
# Out:
# ('alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and')

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

if "alam" in abc:
    print("Yes, the elemnet is in abc ")
else:
    print("No the elemenet is not present")
# Out:
# Yes, the elemnet is in abc

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

if "ala" in abc:
    print("Yes, the elemnet is in abc ")
else:
    print("No the elemenet is not present")
# Out:
# No the elemenet is not present

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

if "alam" in abc:
    print("Yes, the elemnet is in abc")
# Out:
# Yes, the elemnet is in abc

# %% [markdown]
# https://www.w3schools.com/python/python_tuples_update.asp
#
# Tuples are unchangeable, meaning that you cannot change, add, or remove items once the tuple is created.
#
# But there are some workarounds.
#
# Change Tuple Values
#
# Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.
#
# But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple.

# %% [markdown]
# Convert the tuple into a list to be able to change it:

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

y = list(abc)

y[1] = "Kiwi"

x = tuple(y)

print(x)
# Out:
# ('yaswanth', 'Kiwi', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc)

xyz = list(abc)

print(xyz)

xyz[5] = "hsfusnfnisjijsfivdjfijdivjdigjdojd"

mn = tuple(xyz)

print(mn)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')
# ['yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk']
# ('yaswanth', 'alam', 'alam', 41, 41, 'hsfusnfnisjijsfivdjfijdivjdigjdojd', '85', '4151515', 0, 5451, 'and', 'jk')

# %% [markdown]
# Add Items
#
# Since tuples are immutable, they do not have a built-in append() method, but there are other ways to add items to a tuple.
#
# 1. Convert into a list: Just like the workaround for changing a tuple, you can convert it into a list, add your item(s), and convert it back into a tuple

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc)

xyz = list(abc)

print(xyz)

xyz.append("hsfusnfnisjijsfivdjfijdivjdigjdojd")

mn = tuple(xyz)

print(mn)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')
# ['yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk']
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk', 'hsfusnfnisjijsfivdjfijdivjdigjdojd')

# %% [markdown]
# Add tuple to a tuple. You are allowed to add tuples to tuples, so if you want to add one item, (or many), create a new tuple with the item(s), and add it to the existing tuple:

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

mn = (551,45621,5845)
mn = mn + abc

print(mn)
# Out:
# (551, 45621, 5845, 'yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

mn = abc + (551,45621,5845)
#mn = mn + abc

print(mn)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk', 551, 45621, 5845)

# %% [markdown]
# Note: When creating a tuple with only one item, remember to include a comma after the item, otherwise it will not be identified as a tuple.

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

mn = abc + (551,)
#mn = mn + abc

print(mn)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk', 551)

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

mn = abc + (551)
#mn = mn + abc

print(mn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")
# ----> 3 mn = abc + (551)
#       4 #mn = mn + abc
#       6 print(mn)
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

mn = abc + ("551")
#mn = mn + abc

print(mn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 3
#       1 abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")
# ----> 3 mn = abc + ("551")
#       4 #mn = mn + abc
#       6 print(mn)
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %% [markdown]
# Remove Items
#
# Note: You cannot remove items in a tuple.
#
# Tuples are unchangeable, so you cannot remove items from it, but you can use the same workaround as we used for changing and adding tuple items:

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)

print(thistuple)
# Out:
# ('banana', 'cherry')

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc)

xyz = list(abc)

print(xyz)

xyz.remove("alam")

mn = tuple(xyz)

print(mn)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')
# ['yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk']
# ('yaswanth', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc)

xyz = list(abc)

print(xyz)

xyz.remove("yaswanth")

mn = tuple(xyz)

print(mn)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')
# ['yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk']
# ('alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')

# %% [markdown]
# Or you can delete the tuple completely:
#
# Example
#
# The del keyword can delete the tuple completely

# %%
thistuple = ("apple", "banana", "cherry")
del thistuple
print(thistuple) #this will raise an error because the tuple no longer exists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 3
#       1 thistuple = ("apple", "banana", "cherry")
#       2 del thistuple
# ----> 3 print(thistuple) #this will raise an error because the tuple no longer exists
#
# NameError: name 'thistuple' is not defined

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

del abc

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

del abc

print(abc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 5
#       1 abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")
#       3 del abc
# ----> 5 print(abc)
#
# NameError: name 'abc' is not defined
