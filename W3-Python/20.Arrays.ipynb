# %% [markdown]
# https://www.w3schools.com/python/python_arrays.asp
#
#
# Note: Python does not have built-in support for Arrays, but Python Lists can be used instead.
#
# ![image.png](attachment:image.png)
#
#
#
# Note: This page shows you how to use LISTS as ARRAYS, however, to work with arrays in Python you will have to import a library, like the NumPy library.
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# Arrays are used to store multiple values in one single variable:

# %% [markdown]
# example:
#
# Create an array containing car names:

# %%
cars = ["Ford", "Volvo", "BMW"]

print(cars)
# Out:
# ['Ford', 'Volvo', 'BMW']

# %%
car = ["yaswanth","alam","test","mango","yellow","ink"]

print(car)
print(cars)
# Out:
# ['yaswanth', 'alam', 'test', 'mango', 'yellow', 'ink']
# ['Ford', 'Volvo', 'BMW']

# %%
car = ["yasw","al","tt","mo","ye","i"]

print(car)
# Out:
# ['yasw', 'al', 'tt', 'mo', 'ye', 'i']

# %% [markdown]
# What is an Array?
#
# An array is a special variable, which can hold more than one value at a time.
#
# If you have a list of items (a list of car names, for example), storing the cars in single variables could look like this:
#
#
# car1 = "Ford"
# car2 = "Volvo"
# car3 = "BMW"
#
# However, what if you want to loop through the cars and find a specific one? And what if you had not 3 cars, but 300?
#
# The solution is an array!
#
# An array can hold many values under a single name, and you can access the values by referring to an index number.

# %% [markdown]
# Access the Elements of an Array
#
# You refer to an array element by referring to the index number.
#
# Example
#
# Get the value of the first array item:

# %%
cars = ["Ford", "Volvo", "BMW"]

x = cars[0]

print(x)
# Out:
# Ford

# %%
yas = ["jsndf","sdbsdf",65215615]

alam = yas[2]

print(alam)
# Out:
# 65215615

# %%
yas = ["jsndf","sdbsdf",65215615]

print(yas[2])
# Out:
# 65215615

# %%
yas = ["jsndf","sdbsdf",65215615]

print(yas[0])
# Out:
# jsndf

# %%
yas = ["jsndf","sdbsdf",65215615]

print(yas[1])
# Out:
# sdbsdf

# %%
yasw = ["jsndf","sdbsdf",65215615]

alam = yasw[2]

print(alam)
# Out:
# 65215615

# %%
yasw = ["jsndf","sdbsdf",65215615]

ala = yasw[0]

print(ala)
# Out:
# jsndf

# %%
yasw = ["jsndf","sdbsdf",65215615]

ala = yasw[1]

print(ala)
# Out:
# sdbsdf

# %%
yasw = ["jsndf","sdbsdf",65215615]

in = yasw[1]

print(in)
# Out:
#   Cell In[24], line 3
#     in = yasw[1]
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# You’re getting an error because in is a reserved keyword in Python.
#
# You cannot use in as a variable name.

# %% [markdown]
# Example
#
# Modify the value of the first array item:

# %%
cars = ["Ford", "Volvo", "BMW"]

cars[0] = "Toyota"

print(cars)
# Out:
# ['Toyota', 'Volvo', 'BMW']

# %%
yuin = ["alam","yaswanth","test"]

print(yuin)
#yuin[0] = ""
# Out:
# ['alam', 'yaswanth', 'test']

# %%
yuin = ["alam","yaswanth","test"]

print(yuin)

yuin[0] = "India"

print(yuin)
# Out:
# ['alam', 'yaswanth', 'test']
# ['India', 'yaswanth', 'test']

# %% [markdown]
# The Length of an Array.
#
# Use the len() method to return the length of an array (the number of elements in an array).
#
# Example
#
#
# Return the number of elements in the cars array:

# %%
cars = ["Ford", "Volvo", "BMW"]

x = len(cars)

print(x)
# Out:
# 3

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd",5125641515]

u = len(yuin)

print(u)
# Out:
# 5

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd",5125641515, "shdfbdfgbnjdf",541210]

print(len(yuin))
# Out:
# 7

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

print(len(yuin))
# Out:
# 4

# %%
yuin = ["alam","yaswanth","test", 5418415154151545415415415415515415]

print(len(yuin))
# Out:
# 4

# %% [markdown]
# Note: The length of an array is always one more than the highest array index.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Looping Array Elements
#
# You can use the for in loop to loop through all the elements of an array.
#
# Example
#
#
# Print each item in the cars array:

# %%
cars = ["Ford", "Volvo", "BMW"]

for x in cars:
  print(x)
# Out:
# Ford
# Volvo
# BMW

# %%
yaswanth = ["gun", "game", "pion"]

for x in yaswanth:
    print(x)
# Out:
# gun
# game
# pion

# %%
yaswanth = ["gun", "game", "pion"]

for x in yaswanth:
    print(yaswanth)
# Out:
# ['gun', 'game', 'pion']
# ['gun', 'game', 'pion']
# ['gun', 'game', 'pion']

# %% [markdown]
# Adding Array Elements
#
# You can use the append() method to add an element to an array.
#
# Example
#
# Add one more element to the cars array:

# %%
cars = ["Ford", "Volvo", "BMW"]

print(cars)

cars.append("Honda")

print(cars)
# Out:
# ['Ford', 'Volvo', 'BMW']
# ['Ford', 'Volvo', 'BMW', 'Honda']

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.append("855151")

print(yuin)
# Out:
# ['alam', 'yaswanth', 'test', 'sdhgsfrgbd', '855151']

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.append(145641651265215)

print(yuin)
# Out:
# ['alam', 'yaswanth', 'test', 'sdhgsfrgbd', 145641651265215]

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.append("Magic")

print(yuin)
# Out:
# ['alam', 'yaswanth', 'test', 'sdhgsfrgbd', 'Magic']

# %% [markdown]
# Removing Array Elements
#
# You can use the pop() method to remove an element from the array.
#
# Example
#
#
# Delete the second element of the cars array:

# %%
cars = ["Ford", "Volvo", "BMW"]

cars.pop(1)

print(cars)
# Out:
# ['Ford', 'BMW']

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.pop(2)

print(yuin)
# Out:
# ['alam', 'yaswanth', 'sdhgsfrgbd']

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.pop(0)

print(yuin)
# Out:
# ['yaswanth', 'test', 'sdhgsfrgbd']

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.pop(4)

print(yuin)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 3
#       1 yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]
# ----> 3 yuin.pop(4)
#       5 print(yuin)
#
# IndexError: pop index out of range

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.pop()

print(yuin)
# Out:
# ['alam', 'yaswanth', 'test']

# %% [markdown]
# The last element will be removed using the pop keywpord

# %% [markdown]
# You can also use the remove() method to remove an element from the array.
#
# Example
#
# Delete the element that has the value "Volvo":

# %%
cars = ["Ford", "Volvo", "BMW"]

cars.remove("Volvo")

print(cars)
# Out:
# ['Ford', 'BMW']

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.remove()

print(yuin)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]
# ----> 3 yuin.remove()
#       5 print(yuin)
#
# TypeError: list.remove() takes exactly one argument (0 given)

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.remove("alam")

print(yuin)
# Out:
# ['yaswanth', 'test', 'sdhgsfrgbd']

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.remove("Alam")

print(yuin)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 3
#       1 yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]
# ----> 3 yuin.remove("Alam")
#       5 print(yuin)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# Note: The list's remove() method only removes the first occurrence of the specified value.
#
# ![image.png](attachment:image.png)

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.clear()

print(yuin)
# Out:
# []

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.pop()

print(yuin)
# Out:
# ['alam', 'yaswanth', 'test']

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.reverse()

print(yuin)
# Out:
# ['sdhgsfrgbd', 'test', 'yaswanth', 'alam']

# %%
yuin = ["alam","yaswanth","test", "sdhgsfrgbd"]

yuin.sort()

print(yuin)
# Out:
# ['alam', 'sdhgsfrgbd', 'test', 'yaswanth']

# %% [markdown]
# Array Methods
#
# Python has a set of built-in methods that you can use on lists/arrays.
#
# Method	Description
#
#
# append()	Adds an element at the end of the list
# clear()	Removes all the elements from the list
# copy()	Returns a copy of the list
# count()	Returns the number of elements with the specified value
# extend()	Add the elements of a list (or any iterable), to the end of the current list
# index()	Returns the index of the first element with the specified value
# insert()	Adds an element at the specified position
# pop()	Removes the element at the specified position
# remove()	Removes the first item with the specified value
# reverse()	Reverses the order of the list
# sort()	Sorts the list
#
#
# Note: Python does not have built-in support for Arrays, but Python Lists can be used instead.
#
#
#
# ![image.png](attachment:image.png)

# %%
fruits = ['apple', 'banana', 'cherry']
print(fruits[0])
# Out:
# apple
