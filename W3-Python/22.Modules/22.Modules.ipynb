# %% [markdown]
# https://www.w3schools.com/python/python_modules.asp
#
#
# What is a Module?
#
# Consider a module to be the same as a code library.
#
# A file containing a set of functions you want to include in your application.
#
#
# Create a Module
#
#
# To create a module just save the code you want in a file with the file extension .py:
#
#
# Example:
#
#     Save this code in a file named mymodule.py

# %%
def greeting(name):
  print("Hello, " + name)

# %% [markdown]
# Use a Module
#
# Now we can use the module we just created, by using the import statement:
#
# Example
#
# Import the module named mymodule, and call the greeting function:

# %%
import mymodule

mymodule.greeting("Jonathan")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import mymodule
#       3 mymodule.greeting("Jonathan")
#
# ModuleNotFoundError: No module named 'mymodule'

# %%
import module

module.greeting("Jonathan")
# Out:
# Hello, Jonathan
# Hello, I am yaswanth alam and network Enginner learning python,    Jonathan

# %%
def greeting(name):
  print("Hello, " + name)

greeting("sjdhfjsf")
# Out:
# Hello, sjdhfjsf

# %% [markdown]
# Note: When using a function from a module, use the syntax: module_name.function_name.
#
# ![image.png](attachment:image.png)
#
# Variables in Module
#
# The module can contain functions, as already described, but also variables of all types (arrays, dictionaries, objects etc):

# %% [markdown]
# Example
# Save this code in the file mymodule.py

# %% [markdown]
# Example
#
# Import the module named mymodule, and access the person1 dictionary:
#
# In the below examples, we defined an module in other file and importing it here

# %%
import module_dict

a = module_dict.person["Age"]
print(a)
# Out:
# 474

# %%
import module_dict

a = module_dict.person["age"]
print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 import module_dict
# ----> 3 a = module_dict.person["age"]
#       4 print(a)
#
# KeyError: 'age'

# %% [markdown]
# Naming a Module
#
# You can name the module file whatever you like, but it must have the file extension .py
#
# Re-naming a Module
#
#
# You can create an alias when you import a module, by using the as keyword:
#
# Example
#
#
# Create an alias for mymodule called mx:

# %%
import module_dict as mx

a = mx.person["Age"]
print(a)
# Out:
# 474

# %%
import module_dict as alam

a = alam.person["Counrty"]
print(a)
# Out:
# India

# %% [markdown]
# Built-in Modules
#
# There are several built-in modules in Python, which you can import whenever you like.
#
# Example
#
# Import and use the platform module:

# %%
import platform

x = platform.system()
print(x)
# Out:
# Windows

# %% [markdown]
# Using the dir() Function
#
# There is a built-in function to list all the function names (or variable names) in a module. The dir() function:
#
# Example
#
# List all the defined names belonging to the platform module:

# %%
import platform

x = dir(platform)
print(x)
# Out:
# ['AndroidVer', 'IOSVersionInfo', '_Processor', '_WIN32_CLIENT_RELEASES', '_WIN32_SERVER_RELEASES', '__builtins__', '__cached__', '__copyright__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__version__', '_comparable_version', '_default_architecture', '_follow_symlinks', '_get_machine_win32', '_java_getprop', '_mac_ver_xml', '_node', '_norm_version', '_os_release_cache', '_os_release_candidates', '_parse_os_release', '_platform', '_platform_cache', '_sys_version', '_sys_version_cache', '_syscmd_file', '_syscmd_ver', '_uname_cache', '_unknown_as_blank', '_ver_stages', '_win32_ver', '_wmi', '_wmi_query', 'android_ver', 'architecture', 'collections', 'freedesktop_os_release', 'functools', 'ios_ver', 'itertools', 'java_ver', 'libc_ver', 'mac_ver', 'machine', 'node', 'os', 'platform', 'processor', 'python_branch', 'python_build', 'python_compiler', 'python_implementation', 'python_revision', 'python_version', 'python_version_tuple', 're', 'release', 'sys',
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import module_dict

x = dir(module_dict)
print(x)
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'person']

# %% [markdown]
# Import From Module
#
# You can choose to import only parts from a module, by using the from keyword.
#
# Example
#
# The module named mymodule has one function and one dictionary:

# %%
def greeting(name):
  print("Hello, " + name)

person1 = {
  "name": "John",
  "age": 36,
  "country": "Norway"
}

# %% [markdown]
# Example
#
# Import only the person1 dictionary from the module:

# %%
from from_module import person1

print(person1["age"])
# Out:
# 36

# %%
import from_module

print(person1["age"])
# Out:
# 36

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from from_module1 import person1

print(person1["age"])
# Out:
# 36

# %%
from from_module1 import person1

print(person2["age"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 from from_module1 import person1
# ----> 3 print(person2["age"])
#
# NameError: name 'person2' is not defined

# %%
from from_module1 import person2

print(person2["age"])
# Out:
# 5454541

# %%
from from_module1 import person2

print(person1["age"])
# Out:
# 36

# %%
from from_module1 import person3

print(person3["age"])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from from_module1 import person3
#       3 print(person3["age"])
#
# ImportError: cannot import name 'person3' from 'from_module1' (d:\vscode\W3-Python\22.Modules\from_module1.py)

# %%
from from_module1 import person3

print(person2["age"])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from from_module1 import person3
#       3 print(person2["age"])
#
# ImportError: cannot import name 'person3' from 'from_module1' (d:\vscode\W3-Python\22.Modules\from_module1.py)

# %%
from from_module1 import person2

print(person2["country"])
# Out:
# India

# %%
from from_module1 import person3

print(person3["country"])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 from from_module1 import person3
#       3 print(person3["country"])
#
# ImportError: cannot import name 'person3' from 'from_module1' (d:\vscode\W3-Python\22.Modules\from_module1.py)
