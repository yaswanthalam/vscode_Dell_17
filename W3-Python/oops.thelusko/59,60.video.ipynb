# %% [markdown]
# #59 Python Tutorial for Beginners | Operator Overloading | Polymorphism
#
#
# https://youtu.be/9wd50TKv_OQ?si=JeEK9zTVzhA-e2wJ
#
#
# https://www.youtube.com/watch?v=9wd50TKv_OQ&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=65
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 45
b = "yaswanth"

print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 a = 45
#       2 b = "yaswanth"
# ----> 4 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Synthetic sugar are predefined fucntions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#         What ever happens in python will happen with the help of object behind the scenes

# %%
a = 45
b = 5125612

print(a+6*b)
# Out:
# 30753717

# %%
a = 40

b = 6562

print(a+b)

print(int.__add__(a,b))
# Out:
# 6602
# 6602

# %% [markdown]
# print(a+b)
#
# print(int.__add__(a,b))   both do the same job

# %%
a = 40

b = 6562

print(a+b)

print(int.__add__(a,b))
# Out:
# 6602
# 6602

# %% [markdown]
# The built in method built is also accessible and can be seen

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#         When we try to add two strings use below function as shown in below

# %%
a = '4'

b = '6'

print(a+b)

print(str.__add__(a,b))
# Out:
# 46
# 46

# %% [markdown]
# Methods in operators:
#
# ![image.png](attachment:image.png)

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2


s1 = student(5,4)
s2 = student(8,10)

s3 = s1 + s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       7 s1 = student(5,4)
#       8 s2 = student(8,10)
# ---> 10 s3 = s1 + s2
#
# TypeError: unsupported operand type(s) for +: 'student' and 'student'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2

    def __add__(self,other):
        m1 = self.m1 + other.m1
        m2 = self.m2 + other.m2
        s3 = student(m1,m2)
        return s3


s1 = student(5,4)
s2 = student(100,10)

s3 = s1 + s2
print(s3.m1)
# Out:
# 105

# %% [markdown]
# 5+8 = 13

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2

    def __sub__(self,other):
        m1 = self.m1 - other.m1
        m2 = self.m2 - other.m2
        s3 = student(m1,m2)
        return s3


s1 = student(5,4)
s2 = student(8,10)

s3 = s1 - s2
print(s3.m1)
# Out:
# -3

# %% [markdown]
# 5-8 = -3

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2

    def __mul__(self,other):
        m1 = self.m1 * other.m1
        m2 = self.m2 * other.m2
        s3 = student(m1,m2)
        return s3


s1 = student(5,4)
s2 = student(8,10)

s3 = s1 * s2
print(s3.m1)
# Out:
# 40

# %% [markdown]
# 5*8 = 40

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2

    def __mul__(self,other):
        m1 = self.m1 * other.m1
        m2 = self.m2 * other.m2
        s3 = student(m1,m2)
        return s3


s1 = student(5,4)
s2 = student(8,10)

s3 = s1 * s2
print(s3.m1)
# Out:
# 40

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2

    def __add__(self,other):
        m1 = self.m1 + other.m1
        m2 = self.m2 + other.m2
        s3 = student(m1,m2)
        return s3
    
    def __gt__(self,other):
        r1 = self.m1 + self.m2
        r2 = other.m1 + other.m2
        if r1 > r2:
            return True
        else:
            return False


s1 = student(5,4)
s2 = student(8,10)

s3 = s1 + s2

if s1 > s2:
    print("s1 wins")
else:
    print("S2 wins")

print(s3.m1)
# Out:
# S2 wins
# 13

# %% [markdown]
#     __gt__ is greater than
#
#     __get__ is greather than equal to

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2

    def __add__(self,other):
        m1 = self.m1 + other.m1
        m2 = self.m2 + other.m2
        s3 = student(m1,m2)
        return s3
    
    def __gt__(self,other):
        r1 = self.m1 + self.m2
        r2 = other.m1 + other.m2
        if r1 > r2:
            return True
        else:
            return False


s1 = student(5,4)
s2 = student(8,10)

s3 = s1 + s2

if s1 > s2:
    print("s1 wins")
else:
    print("S2 wins")


a = 9
print(a)

print(s1)
# Out:
# S2 wins
# 9
# ...

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2

    def __add__(self,other):
        m1 = self.m1 + other.m1
        m2 = self.m2 + other.m2
        s3 = student(m1,m2)
        return s3
    
    def __gt__(self,other):
        r1 = self.m1 + self.m2
        r2 = other.m1 + other.m2
        if r1 > r2:
            return True
        else:
            return False


s1 = student(5,4)
s2 = student(8,10)

s3 = s1 + s2

if s1 > s2:
    print("s1 wins")
else:
    print("S2 wins")


a = 9
print(a.__str__())

print(s1.__str__())
# Out:
# S2 wins
# 9
# ...

# %% [markdown]
#         __str__ is called internally an STRING
#
#         __ str__ is an built in object

# %% [markdown]
#     Over laoding means same method name and the type of arguments are different.
#
# ![image.png](attachment:image.png)
#
#
#     for example, an + is called as __add__ and the - is called as __sub__

# %% [markdown]
#     #60 Python Tutorial for Beginners | Method Overloading and Method Overriding
#
#
# https://youtu.be/CcTzTuIsoFk?si=mpw1ZrATJstSI4ms
#
#
# https://www.youtube.com/watch?v=CcTzTuIsoFk&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=66
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# In python we can not create 2 methods with same name

# %% [markdown]
#     Method Overloading

# %% [markdown]
#     Method overloading doesn't support directly like other coding languages, we have to implement in the below way we did it

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2


    def sum(self,a,b):
        s = a+b
        return s

s1 = student(10,100)
print(s1.sum(5,15,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 12
#       9         return s
#      11 s1 = student(10,100)
# ---> 12 print(s1.sum(5,15,20))
#
# TypeError: student.sum() takes 3 positional arguments but 4 were given

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2


    def sum(self,a,b):
        s = a+b
        return s

s1 = student(10,100)
print(s1.sum(5,15))
# Out:
# 20

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2


    def sum(self,a,b,c):
        s = a+b+c
        return s

s1 = student(10,100)
print(s1.sum(5,15,5))
# Out:
# 25

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2


    def sum(self,a,b,c):
        s = a+b+c
        return s

s1 = student(10,100)
print(s1.sum(5,15))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       9         return s
#      11 s1 = student(10,100)
# ---> 12 print(s1.sum(5,15))
#
# TypeError: student.sum() missing 1 required positional argument: 'c'

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2


    def sum(self,a=None,b=None,c=None):
        s = a+b+c
        return s

s1 = student(10,100)
print(s1.sum(5,15,10))
# Out:
# 30

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2


    def sum(self,a=None,b=None,c=None):
        s = 0
        
        if a!=None and b!=None and c!=None:
            s = a+b+c
        elif a!=None and b!=None:
            s = a+b
        else:
            s = a
        return s

s1 = student(10,100)
print(s1.sum(5,15,10))
# Out:
# 30

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2


    def sum(self,a=None,b=None,c=None):
        s = 0
        
        if a!=None and b!=None and c!=None:
            s = a+b+c
        elif a!=None and b!=None:
            s = a+b
        else:
            s = a
        return s

s1 = student(10,100)
print(s1.sum(5,15))
# Out:
# 20

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2


    def sum(self,a=None,b=None,c=None):
        s = 0
        
        if a!=None and b!=None and c!=None:
            s = a+b+c
        elif a!=None and b!=None:
            s = a+b
        else:
            s = a
        return s

s1 = student(10,100)
print(s1.sum(5))
# Out:
# 5

# %% [markdown]
#     Method overriding
#
#
#     This is an very important concept and used very heavily

# %%
class A:
    def show(self):
        print("in A show")


class B:
    pass



a1 = B()
a1.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 12
#       7     pass
#      11 a1 = B()
# ---> 12 a1.show()
#
# AttributeError: 'B' object has no attribute 'show'

# %% [markdown]
#     The process of calling class B from A is called as INHERITANCE

# %%
class A:
    def show(self):
        print("in A show")


class B(A):
    pass



a1 = B()
a1.show()
# Out:
# in A show

# %%
class A:
    def show(self):
        print("in A show, Example if Father have Nokia Phone")


class B(A):
    def show(self):
        print("in B show, Example is the child have the motorala phone")



a1 = B()
a1.show()
# Out:
# in B show, Example is the child have the motorala phone
