# %% [markdown]
#                                                                                                    Video and Intro 48

# %% [markdown]
# https://www.youtube.com/watch?v=gZwPdqC2Os0&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=54
#
#
#
# https://youtu.be/gZwPdqC2Os0?si=CEcNr1hlU0RRQ6Ml
#
#
#
# Pythion is an functional prpogramming, which means we can achieve certain task by manipulating certain amount of data and yield the required results.
#
# OOPS in python
#
# OOPS contain classes and objects.
#
# Objects are functions.

# %% [markdown]
# Company is an class
#
#     employee is an Object
#     Every object will have certain attributes like salary, expertise, age, weight etc.
#     Objects is an place to store data and execute.
#     Functions with object oriented programming are called as methods.
#
#
# Concepts in OOPS:
#
# ![image.png](attachment:image.png)
#
# Classes will have multiple objects.
#
#
#
# Class is an desighn or an Blue print.
#
#     For example, the design or blue print of the motorola phone is called as Class
#     The assembly and manufacturing are called as objects.
#     With out having and desig or blue print it is not possible to design the classes

# %% [markdown]
# Video 49
#
#     Class is an design for the objects.
#
# ![image.png](attachment:image.png)
#
#
#  https://youtu.be/8O5kX73OkIY?si=AoCOPYJ5rvWsfVvY
#
#
# https://www.youtube.com/watch?v=8O5kX73OkIY&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=55

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class computer:
    def config(self):
        print("i7, 32GB, 1TB SSD")

a = '8'
com1 = computer()

print(type(com1))
# Out:
# <class '__main__.computer'>

# %%
class computer:
    def config(self):
        print("i7, 32GB, 1TB SSD")

a = '8'
print(type(a))
com1 = computer()

print(type(com1))
# Out:
# <class 'str'>
# <class '__main__.computer'>

# %%
class computer:
    def config(self):
        print("i7, 32GB, 1TB SSD")

x = 9
print(type(x))

a = '8'
print(type(a))

com1 = computer()
print(type(com1))
# Out:
# <class 'int'>
# <class 'str'>
# <class '__main__.computer'>

# %%
class computer:
    def config(self):
        print("i7, 32GB, 1TB SSD")

com1 = computer()
computer.config(com1)
# Out:
# i7, 32GB, 1TB SSD

# %%
class computer:
    def config(self):
        print("i7, 32GB, 1TB SSD")

com1 = computer()
computer.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3         print("i7, 32GB, 1TB SSD")
#       5 com1 = computer()
# ----> 6 computer.config()
#
# TypeError: computer.config() missing 1 required positional argument: 'self'

# %% [markdown]
# class name and then mention the config and in the config call the object that need to call.
#
# Example:
#
#     computer.config()

# %% [markdown]
# Self is the object which we called

# %% [markdown]
# Self key word was removed and tested

# %%
class computer:
    def config():
        print("i7, 32GB, 1TB SSD")

com1 = computer()
com2 = computer()
computer.config(com1)
computer.config(com2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       5 com1 = computer()
#       6 com2 = computer()
# ----> 7 computer.config(com1)
#       8 computer.config(com2)
#
# TypeError: computer.config() takes 0 positional arguments but 1 was given

# %%
class computer:
    def config(self):
        print("i7, 32GB, 1TB SSD")

com1 = computer()
com2 = computer()
computer.config(com1)
computer.config(com2)
# Out:
# i7, 32GB, 1TB SSD
# i7, 32GB, 1TB SSD

# %%
class yaswanth:
    def alam(self):
        print("I am learning Python to become automation engineer")

test1 = yaswanth()
yaswanth.alam(test1)
# Out:
# I am learning Python to become automation engineer

# %%
class computer:
    def config(self):
        print("i7, 32GB, 1TB SSD")

com1 = computer()
com2 = computer()
computer.config(com1)
computer.config(com2)

com1.config()
com2.config()
# Out:
# i7, 32GB, 1TB SSD
# i7, 32GB, 1TB SSD
# i7, 32GB, 1TB SSD
# i7, 32GB, 1TB SSD

# %%
class computer:
    def config(self):
        print("i7, 32GB, 1TB SSD")

com1 = computer()
com2 = computer()
com1.config()
com2.config()
# Out:
# i7, 32GB, 1TB SSD
# i7, 32GB, 1TB SSD

# %%
class auto:
    def network():
        print("Network is best and good")
        print("I am Yasweanth")


c1 = auto
c2 = auto

auto.network()
# Out:
# Network is best and good
# I am Yasweanth

# %%
class auto:
    def network():
        print("Network is best and good")
        print("I am Yasweanth")


c1 = auto
c2 = auto

c1.network()
c2.network()
# Out:
# Network is best and good
# I am Yasweanth
# Network is best and good
# I am Yasweanth

# %%
class computer:
    def config(self):
        print("i7, 32GB, 1TB SSD")

com1 = computer()
com2 = computer()
com1.config()
com2.config()

a = 5
a.bit_length()
# Out:
# i7, 32GB, 1TB SSD
# i7, 32GB, 1TB SSD
# 3

# %%
class computer:
    def config(self):
        print("i7, 32GB, 1TB SSD")

com1 = computer()
com2 = computer()
com1.config()
com2.config()

a = 5
a.bit_count()
# Out:
# i7, 32GB, 1TB SSD
# i7, 32GB, 1TB SSD
# 2

# %% [markdown]
#             Explanation

# %% [markdown]
# ![image.png](attachment:image.png)
#
# bit_count() and bit_length are inbuilt functions and we can see the underlying code behind it by calling that functions.
#
# ![image-2.png](attachment:image-2.png)
