# %% [markdown]
# https://youtu.be/6P-P879BcHQ?si=ayTVx_qb8mMcVQ-ac
#
# https://www.youtube.com/watch?v=6P-P879BcHQ&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=63
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
#
# ![image-4.png](attachment:image-4.png)

# %%
class a:

    def __init__(self):
        print("in A Init")



    def feature1(self):
        print("feature 1 working")

    def feature2(self):
        print("feature 2 working")

class b(a):
    def feature3(self):
        print("feature 3 working")

    def feature4(self):
        print("feature 4 working")

a1 = a()
# Out:
# in A Init

# %%
class a:

    def __init__(self):
        print("in A Init")

    def feature1(self):
        print("feature 1 working")

    def feature2(self):
        print("feature 2 working")

class b(a):
    
    def feature3(self):
        print("feature 3 working")

    def feature4(self):
        print("feature 4 working")

a1 = b()
# Out:
# in A Init

# %%
class a:

    def __init__(self):
        print("in A Init")

    def feature1(self):
        print("feature 1 working")

    def feature2(self):
        print("feature 2 working")

class b(a):

    def __init__(self):
        print("in B Init")
    
    def feature3(self):
        print("feature 3 working")

    def feature4(self):
        print("feature 4 working")

a1 = b()
# Out:
# in B Init

# %%
class a:

    def __init__(self):
        print("in A Init")

    def feature1(self):
        print("feature 1 working")

    def feature2(self):
        print("feature 2 working")

class b(a):
    
    def feature3(self):
        print("feature 3 working")

    def feature4(self):
        print("feature 4 working")

a1 = b()
# Out:
# in A Init

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class a:

    def __init__(self):
        print("in A Init")

    def feature1(self):
        print("feature 1 working")

    def feature2(self):
        print("feature 2 working")

class b(a):

    def __init__(self):
        print("in B Init")
    
    def feature3(self):
        print("feature 3 working")

    def feature4(self):
        print("feature 4 working")

a1 = b()
# Out:
# in B Init

# %% [markdown]
# The below code calls both classes A and B

# %%
class a:

    def __init__(self):
        print("in A Init")

    def feature1(self):
        print("feature 1 working")

    def feature2(self):
        print("feature 2 working")

class b(a):

    def __init__(self):
        super().__init__()
        print("in B Init")
    
    def feature3(self):
        print("feature 3 working")

    def feature4(self):
        print("feature 4 working")

a1 = b()
# Out:
# in A Init
# in B Init

# %% [markdown]
#     super().__init__()  this command calls data from super class

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class a:

    def __init__(self):
        print("in A Init")

    def feature1(self):
        print("feature 1 working")

    def feature2(self):
        print("feature 2 working")

class b:

    def __init__(self):
        super().__init__()
        print("in B Init")
    
    def feature3(self):
        print("feature 3 working")

    def feature4(self):
        print("feature 4 working")

class c(a,b):
    def __init__(self):
        print("in C init")


a1 = c()
# Out:
# in C init

# %%
class a:

    def __init__(self):
        print("in A Init")

    def feature1(self):
        print("feature 1 working")

    def feature2(self):
        print("feature 2 working")

class b:

    def __init__(self):
        super().__init__()
        print("in B Init")
    
    def feature3(self):
        print("feature 3 working")

    def feature4(self):
        print("feature 4 working")

class c(a,b):
    def __init__(self):
        super().__init__()
        print("in C init")


a1 = c()
# Out:
# in A Init
# in C init

# %% [markdown]
#     The above super().__init__ is not taking the data from class B

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     The inheritance starts from left to right

# %%
class a:

    def __init__(self):
        print("in A Init")

    def feature1(self):
        print("feature 1-A working")

    def feature2(self):
        print("feature 2 working")

class b:

    def __init__(self):
        super().__init__()
        print("in B Init")
    
    def feature3(self):
        print("feature 3-B working")

    def feature4(self):
        print("feature 4 working")

class c(a,b):
    def __init__(self):
        super().__init__()
        print("in C init")


a1 = c()
a1.feature1()
# Out:
# in A Init
# in C init
# feature 1-A working

# %%
class a:

    def __init__(self):
        print("in A Init")

    def feature1(self):
        print("feature 1-A working")

    def feature2(self):
        print("feature 2 working")

class b:

    def __init__(self):
        super().__init__()
        print("in B Init")
    
    def feature3(self):
        print("feature 3-B working")

    def feature4(self):
        print("feature 4 working")

class c(a,b):
    def __init__(self):
        super().__init__()
        print("in C init")


a1 = c()
a1.feature1()
a1.feature3()
# Out:
# in A Init
# in C init
# feature 1-A working
# feature 3-B working

# %% [markdown]
# https://youtu.be/P1vH3Pfw6BI?si=ONif6H5xs3FTq6eq
#
#
# https://www.youtube.com/watch?v=P1vH3Pfw6BI&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=63
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#         Polymorphism means one thing is available in multiple forms

# %% [markdown]
# polymorphism means one thing available in multiple ways

# %% [markdown]
#
#         #58 Python Tutorial for Beginners | Duck Typing
#
#
# https://youtu.be/CuK0g8OFzwo?si=gZSOfrHWiKsE_8d8
#
# https://www.youtube.com/watch?v=CuK0g8OFzwo&list=PLsyeobzWxl7poL9JTVyndKe62ieoN-MZ3&index=64
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 55

x = "yaswanth"

print(id(x))
print(type(x))
# Out:
# 2218614924016
# <class 'str'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class pycharm:
    def execute(self):
        print("Compiling")
        print("Running")


class laptop:
    def code(self, ide):
        ide.execute()

ide = pycharm()

lap1 = laptop()
lap1.code(ide)
# Out:
# Compiling
# Running

# %%
class pycharm:
    def execute(self):
        print("Compiling")
        print("Running")

class myeditor:
    def execute(self):
        print("Spell Check")
        print("Convetion Check")
        print("Compiling")
        print("Running")
        

class laptop:
    def code(self, ide):
        ide.execute()

ide = pycharm()

lap1 = laptop()
lap1.code(ide)
# Out:
# Compiling
# Running

# %%
class pycharm:
    def execute(self):
        print("Compiling")
        print("Running")

class myeditor:
    def execute(self):
        print("Spell Check")
        print("Convetion Check")
        print("Compiling")
        print("Running")
        

class laptop:
    def code(self, ide):
        ide.execute()

ide = myeditor()

lap1 = laptop()
lap1.code(ide)
# Out:
# Spell Check
# Convetion Check
# Compiling
# Running

# %%
class yaswanth:
    def execute(self):
        print("Yaswanth Alam")
        print("I am network engineer")

class alam:
    def execute(self):
        print("Automation is the best")
        print("I love automation")

class yash:
    def test(self,ide):
        ide.execute()

ide = alam()
    
lap1 = yash()
lap1.test(ide)
# Out:
# Automation is the best
# I love automation

# %%
class yaswanth:
    def execute(self):
        print("Yaswanth Alam")
        print("I am network engineer")

class alam:
    def execute(self):
        print("Automation is the best")
        print("I love automation")

class yash:
    def test(self,ide):
        ide.execute()

ide = alam()
ide = yaswanth()

    
    
lap1 = yash()
lap1.test(ide)
# Out:
# Yaswanth Alam
# I am network engineer
