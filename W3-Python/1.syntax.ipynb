# %% [markdown]
# https://www.w3schools.com/python/python_syntax.asp

# %%
print("hello World")
# Out:
# hello World

# %%
if 5>2:
    print("The number 5 is greater than 2")
# Out:
# The number 5 is greater than 2

# %%
if 5>2:
print("The number 5 is greater than 2")
# Out:
#   Cell In[3], line 2
#     print("The number 5 is greater than 2")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# The number of spaces is up to you as a programmer, the most common use is four, but it has to be at least one.

# %%
if 5>2:
    print("The number 5 is greater than 2")

if 5>2:
        print("The Number is grater ")
# Out:
# The number 5 is greater than 2
# The Number is grater

# %%
if 5>2:
    print("The number 5 is greater than 2")
        print("The Number is grater ")
# Out:
#   Cell In[5], line 3
#     print("The Number is grater ")
#     ^
# IndentationError: unexpected indent

# %%
x=5
y="Yaswanth"

print(x,y)
# Out:
# 5 Yaswanth

# %%
x=5
y="Yaswanth"

print(x)
print(y)
# Out:
# 5
# Yaswanth

# %% [markdown]
# https://www.w3schools.com/python/python_statements.asp

# %%
print("learning python is my dream and python")
# Out:
# learning python is my dream and python

# %%
print("hello")
print("Hi")
print("How are you ")
# Out:
# hello
# Hi
# How are you

# %%
print("hello");print("Hi");print("How are you ")
# Out:
# hello
# Hi
# How are you

# %%
print("Hi") print("How are you ")
# Out:
#   Cell In[11], line 1
#     print("Hi") print("How are you ")
#                 ^
# SyntaxError: invalid syntax
