# %% [markdown]
# https://www.w3schools.com/python/python_user_input.asp
#
#
# User Input
#
# Python allows for user input.
#
# That means we are able to ask the user for input.
#
# The following example asks for your name, and when you enter a name, it gets printed on the screen

# %%
print("Enter your name:")
name = input()
print(f"Hello {name}")
# Out:
# Enter your name:
# Hello test

# %%
name = input()
print(f"Hello name is {name}")
# Out:
# Hello name is yaswanth

# %%
name = input()
print(f"My name is {name}")
# Out:
# My name is alam

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
name = input("Enter your name:")
print(f"Hello {name}")
# Out:
# Hello test

# %%
test = input("ERnter your name ")

print(test)
# Out:
# Yaswanth Alam

# %%
test = input("ERnter your name ")

print(f"My name is {test}")
# Out:
# My name is a;a,

# %% [markdown]
# Multiple Inputs
#
# You can add as many inputs as you want, Python will stop executing at each of them, waiting for user input:

# %%
name = input("Enter your name:")
print(f"Hello {name}")
fav1 = input("What is your favorite animal? ")
fav2 = input("What is your favorite color? ")
fav3 = input("What is your favorite number? ")
print(f"Do you want a {fav2} {fav1} with {fav3} legs?")
# Out:
# Hello hsdf
# Do you want a xfg sfgrs with dfg legs?

# %% [markdown]
# Input Number
#
# The input from the user is treated as a string. Even if, in the example above, you can input a number, the Python interpreter will still treat it as a string.
#
# You can convert the input into a number with the float() function:
#
# Example
#
# To find the square root, the input has to be converted into a number:

# %%
import math

x = input("Enter a number:")

#find the square root of the number:
y = math.sqrt(float(x))

print(f"The square root of {x} is {y}")
# Out:
# The square root of 626 is 25.019992006393608

# %%
import math

x = input("Enter a number:")

#find the square root of the number:
y = math.sqrt(int(x))

print(f"The square root of {x} is {y}")
# Out:
# The square root of 9855 is 99.27235264664579

# %%
import math

d = input("Enter an number")

t = math.sqrt(int(d))

print(f"The square root of {d} is {t}")
# Out:
# The square root of 54141 is 232.6821866838972

# %%
import math

d = input("Enter an number")

t = math.sqrt(int(d))

print(f"The square root of {d} is {t}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       1 import math
#       3 d = input("Enter an number")
# ----> 5 t = math.sqrt(int(d))
#       7 print(f"The square root of {d} is {t}")
#
# ValueError: invalid literal for int() with base 10: 'sfgs'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y = True
while y == True:
  x = input("Enter a number:")
  try:
    x = float(x);
    y = False
  except:
    print("Wrong input, please try again.")

print("Thank you!")
# Out:
# Thank you!

# %%
y = True
while y == True:
  x = input("Enter a number:")
  try:
    x = float(x);
    y = False
  except:
    print("Wrong input, please try again.")

print("Thank you!")
# Out:
# Wrong input, please try again.
# Thank you!

# %%
y = True
while y == True:
  x = input("Enter a number:")
  try:
    x = float(x);
    y = False
  except:
    print("Wrong input, please try again.")

print("Thank you!")
# Out:
# Wrong input, please try again.
# Wrong input, please try again.
# Wrong input, please try again.
# Wrong input, please try again.
# Wrong input, please try again.
# Wrong input, please try again.
# Wrong input, please try again.
# Thank you!
