# %% [markdown]
# https://www.w3schools.com/python/python_tuples_unpack.asp
#
#
# Python - Unpack Tuples
#
# Unpacking a Tuple
#
# When we create a tuple, we normally assign values to it. This is called "packing" a tuple:

# %%
fruits = ("apple", "banana", "cherry")

print(fruits)
# Out:
# ('apple', 'banana', 'cherry')

# %%
abc = ("yaswanth" ,"alam" , "alam" , 41,41, "85", "85" , "4151515", 0,5451,"and","jk")

print(abc)
# Out:
# ('yaswanth', 'alam', 'alam', 41, 41, '85', '85', '4151515', 0, 5451, 'and', 'jk')

# %% [markdown]
# But, in Python, we are also allowed to extract the values back into variables. This is called "unpacking":
#
# Example
#
# Unpacking a tuple:

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# Note: The number of variables must match the number of values in the tuple, if not, you must use an asterisk to collect the remaining values as a list.

# %%
abc = ("alam" , "ab" , 545, "5451")

(alam, ab , xn , mn) = abc

print(alam)
print(ab)
print(xn)
print(mn)

print(alam, ab, xn, mn)
# Out:
# alam
# ab
# 545
# 5451
# alam ab 545 5451

# %% [markdown]
# Using Asterisk*
#
# If the number of variables is less than the number of values, you can add an * to the variable name and the values will be assigned to the variable as a list:
#
# Example
#
# Assign the rest of the values as a list called "red":

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, yellow, *red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
yaswanth = ("alam" "sdfnjs" , "sdfghsdfj" ,"sfghdfjd" ,"sfgdjn" , "xcnvjx" , 5454154)

(al, nc, *guy) = yaswanth

print(al)
print(nc)
print(guy)
# Out:
# alamsdfnjs
# sdfghsdfj
# ['sfghdfjd', 'sfgdjn', 'xcnvjx', 5454154]

# %% [markdown]
# If the asterisk is added to another variable name than the last, Python will assign values to the variable until the number of values left matches the number of variables left.
#
# Example
#
#
# Add a list of values the "tropic" variable:

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

(green, *tropic, red) = fruits

print(green)
print(tropic)
print(red)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry

# %%
yas = ("ajsdnj" ,"xfgdfn" , 5156125 , 21020121, 8798959, "xnxjfndjk", "sdfhdfjn")

(abc , xyz , lon) = yas

print(abc)
print(xyz)
print(lon)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 yas = ("ajsdnj" ,"xfgdfn" , 5156125 , 21020121, 8798959, "xnxjfndjk", "sdfhdfjn")
# ----> 3 (abc , xyz , lon) = yas
#       5 print(abc)
#       6 print(xyz)
#
# ValueError: too many values to unpack (expected 3)

# %%
yas = ("ajsdnj" ,"xfgdfn" , 5156125 , 21020121, 8798959, "xnxjfndjk", "sdfhdfjn")

(abc , *xyz , lon) = yas

print(abc)
print(xyz)
print(lon)
# Out:
# ajsdnj
# ['xfgdfn', 5156125, 21020121, 8798959, 'xnxjfndjk']
# sdfhdfjn

# %%
fruits = ('apple', 'banana', 'cherry')
(x, *y) = fruits
print(y)
# Out:
# ['banana', 'cherry']

# %% [markdown]
# https://www.w3schools.com/python/python_tuples_loop.asp
#
#
# Python - Loop Tuples
#
# Loop Through a Tuple
#
#
# You can loop through the tuple items by using a for loop.

# %%
abc = ("yas","mnc" ,"har")

for i in abc:
    print(abc)
# Out:
# ('yas', 'mnc', 'har')
# ('yas', 'mnc', 'har')
# ('yas', 'mnc', 'har')

# %%
abc = ("yas","mnc" ,"har")

for i in abc:
    print(i)
# Out:
# yas
# mnc
# har

# %% [markdown]
# Loop Through the Index Numbers
#
# You can also loop through the tuple items by referring to their index number.
#
# Use the range() and len() functions to create a suitable iterable.

# %%
abc = ("yas","mnc" ,"har")

for i in range(len(abc)):
    print(abc[i])
# Out:
# yas
# mnc
# har

# %%
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %%
ji = ("asd" ,"asdfsd" ,"sfnbsdfj" ,"xfndf" ,"xffdnj",62165125, "545151")

for i in range(len(ji)):

    print(ji[i])
# Out:
# asd
# asdfsd
# sfnbsdfj
# xfndf
# xffdnj
# 62165125
# 545151

# %%
jm = ("asd" ,"asdfsd" ,"sfnbsdfj" ,"xfndf" ,"xffdnj",62165125, "545151")

for i in range(len(jm)):
    print(jm[i])
# Out:
# asd
# asdfsd
# sfnbsdfj
# xfndf
# xffdnj
# 62165125
# 545151

# %% [markdown]
# Using a While Loop
#
# You can loop through the tuple items by using a while loop.
#
# Use the len() function to determine the length of the tuple, then start at 0 and loop your way through the tuple items by referring to their indexes.
#
# Remember to increase the index by 1 after each iteration.
#
# Example
#
# Print all items, using a while loop to go through all the index numbers:

# %%
jm = ("asd" ,"asdfsd" ,"sfnbsdfj" ,"xfndf" ,"xffdnj",62165125, "545151")

i = 0

while i < len(jm):
    print(jm[i])
    i = i+1
# Out:
# asd
# asdfsd
# sfnbsdfj
# xfndf
# xffdnj
# 62165125
# 545151

# %%
bc = ("asd" ,"asdfsd" ,"sfnbsdfj" ,"xfndf" ,"xffdnj",62165125, "545151")

i = 0

while i < len(bc):
    print(bc[i])
    i = i +1
# Out:
# asd
# asdfsd
# sfnbsdfj
# xfndf
# xffdnj
# 62165125
# 545151

# %%
mytuple = ('apple', 'banana', 'cherry')
i = 0
while i < len(mytuple):
  print(mytuple[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
abc = ("sdf" , "xfjn" ,"sdfbsjf")

i = 0

while i < len(abc):
    print(abc[i])
    i = i+1
# Out:
# sdf
# xfjn
# sdfbsjf

# %%
abc = ("sdf" , "xfjn" ,"sdfbsjf")

i = 0

while i < range(len(abc)):
    print(abc[i])
    i = i+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 abc = ("sdf" , "xfjn" ,"sdfbsjf")
#       3 i = 0
# ----> 5 while i < range(len(abc)):
#       6     print(abc[i])
#       7     i = i+1
#
# TypeError: '<' not supported between instances of 'int' and 'range'

# %% [markdown]
# https://www.w3schools.com/python/python_tuples_join.asp
#
# Python - Join Tuples
#
#
# To join two or more tuples you can use the + operator:

# %%
abc = ("sdf" , "xfjn" ,"sdfbsjf")
bcd = (55, 546, 6326, 5995)

cdm = abc + bcd

print(cdm)
# Out:
# ('sdf', 'xfjn', 'sdfbsjf', 55, 546, 6326, 5995)

# %%
mc = ("afdnsdj" , 5454 , 'sfjhdkj' , 5466555)

cv = ("sfnmksfnmks" , 54584848484545 , 'sfdbsdfjbnjd' , 565462165145544154)

ab = mc + cv

print(ab)
# Out:
# ('afdnsdj', 5454, 'sfjhdkj', 5466555, 'sfnmksfnmks', 54584848484545, 'sfdbsdfjbnjd', 565462165145544154)

# %% [markdown]
# Multiply Tuples
#
# If you want to multiply the content of a tuple a given number of times, you can use the * operator:

# %%
print("hello")
# Out:
# hello

# %%
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2

print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
mc = ("afdnsdj" , 5454 , 'sfjhdkj' , 5466555)

cv = ("sfnmksfnmks" , 54584848484545 , 'sfdbsdfjbnjd' , 565462165145544154)

ab = mc*2

bc = cv *2

print(ab)
# Out:
# ('afdnsdj', 5454, 'sfjhdkj', 5466555, 'afdnsdj', 5454, 'sfjhdkj', 5466555)

# %%
mc = ("afdnsdj" , 5454 , 'sfjhdkj' , 5466555)

cv = ("sfnmksfnmks" , 54584848484545 , 'sfdbsdfjbnjd' , 565462165145544154)

ab = mc*2

bc = cv *2

print(ab , bc)
# Out:
# ('afdnsdj', 5454, 'sfjhdkj', 5466555, 'afdnsdj', 5454, 'sfjhdkj', 5466555) ('sfnmksfnmks', 54584848484545, 'sfdbsdfjbnjd', 565462165145544154, 'sfnmksfnmks', 54584848484545, 'sfdbsdfjbnjd', 565462165145544154)

# %%
mc = ("afdnsdj" , 5454 , 'sfjhdkj' , 5466555)

cv = ("sfnmksfnmks" , 54584848484545 , 'sfdbsdfjbnjd' , 565462165145544154)

ab = mc*2

bc = cv *2

print(bc)
# Out:
# ('sfnmksfnmks', 54584848484545, 'sfdbsdfjbnjd', 565462165145544154, 'sfnmksfnmks', 54584848484545, 'sfdbsdfjbnjd', 565462165145544154)

# %% [markdown]
# https://www.w3schools.com/python/python_tuples_methods.asp
#
# Tuple Methods
#
# Python has two built-in methods that you can use on tuples.
#
# Method	Description
#
# count()	Returns the number of times a specified value occurs in a tuple
#
# index()	Searches the tuple for a specified value and returns the position of where it was found
#
#
# ![image.png](attachment:image.png)
