# %% [markdown]
# https://www.w3schools.com/python/python_functions.asp

# %% [markdown]
# Python Functions
#
# A function is a block of code which only runs when it is called.
#
# A function can return data as a result.
#
# A function helps avoiding code repetition.
#
# Creating a Function
#
# In Python, a function is defined using the def keyword, followed by a function name and parentheses:

# %%
def greet():
  print("Hello from a function")

# %%
def greet():
  print("Hello from a function")

greet()
# Out:
# Hello from a function

# %% [markdown]
# Calling a Function
#
# To call a function, write its name followed by parentheses:

# %%
def my_function():
  print("Hello from a function")

my_function()
# Out:
# Hello from a function

# %%
def yaswanth():
    print("I am ne enginer")

yaswanth()
# Out:
# I am ne enginer

# %% [markdown]
# You can call the same function multiple times:

# %%
def yaswanth():
    print("I am ne enginer")

yaswanth()
yaswanth()
yaswanth()
# Out:
# I am ne enginer
# I am ne enginer
# I am ne enginer

# %%
def yaswanth():
    print("I am ne enginer")

yaswanth()

# %% [markdown]
# Function Names
#
# Function names follow the same rules as variable names in Python:
#
# A function name must start with a letter or underscore
#
# A function name can only contain letters, numbers, and underscores
#
# Function names are case-sensitive (myFunction and myfunction are different)
#
# Example
#
# Valid function names:
#
# calculate_sum()
# _private_function()
# myFunction2()

# %%
def yaswanth():
    print("I am ne enginer")

def Yaswanth():
    print("abnbvhsjfsnk")

yaswanth()
Yaswanth()
# Out:
# I am ne enginer
# abnbvhsjfsnk

# %% [markdown]
# Why Use Functions?
#
# Imagine you need to convert temperatures from Fahrenheit to Celsius several times in your program. Without functions, you would have to write the same calculation code repeatedly:
#
# Example
#
# Without functions - repetitive code:

# %% [markdown]
# Example
#
# Without functions - repetitive code:

# %%
temp1 = 77
celsius1 = (temp1 - 32) * 5 / 9
print(celsius1)

temp2 = 95
celsius2 = (temp2 - 32) * 5 / 9
print(celsius2)

temp3 = 50
celsius3 = (temp3 - 32) * 5 / 9
print(celsius3)
# Out:
# 25.0
# 35.0
# 10.0

# %%
yas1 = 4515
abc = (yas1-5415)*5/9
print(abc)

yas2 = 546262
bcd = (yas2-546512) * 8/85/75
print(bcd)
# Out:
# -500.0
# -0.3137254901960784

# %% [markdown]
# With functions, you write the code once and reuse it:
#
# Example
#
# With functions - reusable code:

# %%
def fahrenheit_to_celsius(fahrenheit):
  return (fahrenheit - 32) * 5 / 9

print(fahrenheit_to_celsius(77))
print(fahrenheit_to_celsius(95))
print(fahrenheit_to_celsius(50))
# Out:
# 25.0
# 35.0
# 10.0

# %%
def yaswanth(alam):
    return(alam-30)*5/9

print(yaswanth(55))
print(yaswanth(85))
print(yaswanth(33))
# Out:
# 13.88888888888889
# 30.555555555555557
# 1.6666666666666667

# %%
def alam(test):
    return(test-89)*8/7
print(alam(65652165))
print(alam(1))
print(alam(0))
# Out:
# 75030944.0
# -100.57142857142857
# -101.71428571428571

# %%
def abc(bcd):
    return(bcd-987402)-2562+87894/19*65

print(abc(556125))
print(abc(5420))
print(abc(8))
# Out:
# -133149.0
# -683854.0
# -689266.0

# %% [markdown]
# Return Values
#
# Functions can send data back to the code that called them using the return statement.
#
# When a function reaches a return statement, it stops executing and sends the result back:

# %%
def get_greeting():
  return "Hello from a function"

message = get_greeting()
print(message)
# Out:
# Hello from a function

# %%
def mnc():
    return "A, B, C, D, E, F ,. 77,545151515154151"

gun = mnc()
print(gun)
# Out:
# A, B, C, D, E, F ,. 77,545151515154151

# %%
def mnc():
    return "A, B, C, D, E, F ,. 77,545151515154151"

mnc()
# Out:
# 'A, B, C, D, E, F ,. 77,545151515154151'

# %%
def yaswanth():
    return "Test I am an engineer"

cdn = yaswanth()
print(cdn)
# Out:
# Test I am an engineer

# %% [markdown]
# You can use the returned value directly:
#
# Example
#
#
# Using the return value directly:

# %%
def get_greeting():
  return "Hello from a function"

print(get_greeting())
# Out:
# Hello from a function

# %%
def yaswanth():
    return "Hi Hello I am an Enginer Yaswanth Alam ans the enbgioner n"

yaswanth()
# Out:
# 'Hi Hello I am an Enginer Yaswanth Alam ans the enbgioner n'

# %%
def yaswanth():
    return "Hi Hello I am an Enginer Yaswanth Alam ans the enbgioner n"

print(yaswanth())
# Out:
# Hi Hello I am an Enginer Yaswanth Alam ans the enbgioner n

# %% [markdown]
# If a function doesn't have a return statement, it returns None by default.

# %%
def yaswanth():
# Out:
#   Cell In[33], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %% [markdown]
# The pass Statement
#
# Function definitions cannot be empty. If you need to create a function placeholder without any code, use the pass statement:

# %%
def yaswanth():
    pass

# %%
def yaswanth():
# Out:
#   Cell In[36], line 1
#     def yaswanth():
#                    ^
# _IncompleteInputError: incomplete input

# %%
def yaswanth()
# Out:
#   Cell In[37], line 1
#     def yaswanth()
#                   ^
# SyntaxError: expected ':'

# %% [markdown]
# https://www.w3schools.com/python/python_arguments.asp
#
#
# Python Function Arguments
#
#
# Arguments
#
# Information can be passed into functions as arguments.
#
# Arguments are specified after the function name, inside the parentheses. You can add as many arguments as you want, just separate them with a comma.
#
# The following example has a function with one argument (fname). When the function is called, we pass along a first name, which is used inside the function to print the full name:

# %%
def my_function(fname):
  print(fname + " Refsnes")

my_function("Emil")
my_function("Tobias")
my_function("Linus")
# Out:
# Emil Refsnes
# Tobias Refsnes
# Linus Refsnes

# %%
def yasw(alam):
    print(alam + "I am network enginer")

yasw("51651")
yasw("hnasdfjsnfjks")
yasw("I am an the network + engioner + test andf he enginenr where cI ajd Jnaedj")
# Out:
# 51651I am network enginer
# hnasdfjsnfjksI am network enginer
# I am an the network + engioner + test andf he enginenr where cI ajd JnaedjI am network enginer

# %%
def alam(abc):
    print(abc + "kjsdfisjfifji + 6526262652 + jnsjfgnsdkgndkfmdkm")

alam("shdfbshfbsdj")
# Out:
# shdfbshfbsdjkjsdfisjfifji + 6526262652 + jnsjfgnsdkgndkfmdkm

# %%
def test(mnc):
    print(mnc + "shfbhsbfjsnbjn + jsghfuhsugdhnegijdenjk + 484541548484184848484 - 51548541541")

test("test + abcdefghijklmnopquestuvb")
test("545415848415418545818548")
# Out:
# test + abcdefghijklmnopquestuvbshfbhsbfjsnbjn + jsghfuhsugdhnegijdenjk + 484541548484184848484 - 51548541541
# 545415848415418545818548shfbhsbfjsnbjn + jsghfuhsugdhnegijdenjk + 484541548484184848484 - 51548541541

# %%
def test(mnc):
    print(mnc  "shfbhsbfjsnbjn + jsghfuhsugdhnegijdenjk + 484541548484184848484 - 51548541541")

test("test + abcdefghijklmnopquestuvb")
test("545415848415418545818548")
# Out:
#   Cell In[51], line 2
#     print(mnc  "shfbhsbfjsnbjn + jsghfuhsugdhnegijdenjk + 484541548484184848484 - 51548541541")
#                ^
# SyntaxError: invalid syntax

# %%
def test(mnc):
    print(mnc , "shfbhsbfjsnbjn + jsghfuhsugdhnegijdenjk + 484541548484184848484 - 51548541541")

test("test + abcdefghijklmnopquestuvb")
# Out:
# test + abcdefghijklmnopquestuvb shfbhsbfjsnbjn + jsghfuhsugdhnegijdenjk + 484541548484184848484 - 51548541541

# %%
def test(mnc):
    print("shfbhsbfjsnbjn + jsghfuhsugdhnegijdenjk + 484541548484184848484 - 51548541541" ,    mnc)

test("test + abcdefghijklmnopquestuvb")
# Out:
# shfbhsbfjsnbjn + jsghfuhsugdhnegijdenjk + 484541548484184848484 - 51548541541 test + abcdefghijklmnopquestuvb

# %% [markdown]
# Parameters vs Arguments
#
# The terms parameter and argument can be used for the same thing: information that are passed into a function.
#
# From a function's perspective:
#
# A parameter is the variable listed inside the parentheses in the function definition.
#
# An argument is the actual value that is sent to the function when it is called.

# %%
def my_function(name): # name is a parameter
  print("Hello", name)

my_function("Emil") # "Emil" is an argument
# Out:
# Hello Emil

# %%
def yaswanth(alam):
    print("abcdend" , alam)

yaswanth("zndfksnfksfmnk")
# Out:
# abcdend zndfksnfksfmnk

# %%
def alam(yaswanth):
    print(yaswanth , " 1 + 2 + 5 + 63412 + 216265 + 65652652 + 6526265 + 522165 + hsgdfysgfsdbhhj")

alam("sdfbgsfhbj")
# Out:
# sdfbgsfhbj  1 + 2 + 5 + 63412 + 216265 + 65652652 + 6526265 + 522165 + hsgdfysgfsdbhhj

# %% [markdown]
# Number of Arguments
#
# By default, a function must be called with the correct number of arguments.
#
# If your function expects 2 arguments, you must call it with exactly 2 arguments.
#
# Example
#
# This function expects 2 arguments, and gets 2 arguments::

# %%
def my_function(fname, lname):
  print(fname + " " + lname)

my_function("Emil", "Refsnes")
# Out:
# Emil Refsnes

# %%
def yasw(amc , abc):
    print(amc + " " + abc)

yasw("abfj","5415641")
# Out:
# abfj 5415641

# %% [markdown]
# If you try to call the function with the wrong number of arguments, you will get an error:
#
# Example
#
# This function expects 2 arguments, but gets only 1:

# %%
def yasw(amc , abc):
    print(amc + " " + abc)

yasw("abfj")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 4
#       1 def yasw(amc , abc):
#       2     print(amc + " " + abc)
# ----> 4 yasw("abfj")
#
# TypeError: yasw() missing 1 required positional argument: 'abc'

# %%
def alam(test,ubc):
    print(test + " " + ubc)
alam("sfbhsfjn","sdfhsfgjn+45615")
# Out:
# sfbhsfjn sdfhsfgjn+45615

# %% [markdown]
# Default Parameter Values
#
# You can assign default values to parameters. If the function is called without an argument, it uses the default value:

# %%
def my_function(name = "friend"):
  print("Hello", name)

my_function("Emil")
my_function("Tobias")
my_function()
my_function("Linus")
# Out:
# Hello Emil
# Hello Tobias
# Hello friend
# Hello Linus

# %%
def yaswanth(name = "alam"):
    print("abcefghijklmnop" , name)
yaswanth("test")
yaswanth()
# Out:
# abcefghijklmnop test
# abcefghijklmnop alam

# %%
def alam(test = "8451485151+sdfghsfjbndfj"):
    print(test, "jbndfjnsfknsdfkmjjn")

alam("sfbnsfjgnbdjf")
alam()
# Out:
# sfbnsfjgnbdjf jbndfjnsfknsdfkmjjn
# 8451485151+sdfghsfjbndfj jbndfjnsfknsdfkmjjn

# %%
def my_function(country = "Norway"):
  print("I am from", country)

my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")
# Out:
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil

# %% [markdown]
# Keyword Arguments
#
# You can send arguments with the key = value syntax.

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function(animal = "dog", name = "Buddy")
# Out:
# I have a dog
# My dog's name is Buddy

# %%
def yaswanth(test, abcd):
    print("I ah a " , test)
    print("Testing the bed wij ", abcd ,"sfnjnkermijrm")

yaswanth(test = "bdfsbadfj" , abcd = "najsdnjik 54265296526")
# Out:
# I ah a  bdfsbadfj
# Testing the bed wij  najsdnjik 54265296526 sfnjnkermijrm

# %% [markdown]
# This way, with keyword arguments, the order of the arguments does not matter.

# %%
def yaswanth(test, abcd):
    print("I ah a " , test)
    print("Testing the bed wij ", abcd ,"sfnjnkermijrm")

yaswanth(test = ["sdjfhsf"] , abcd = "najsdnjik 54265296526")
# Out:
# I ah a  ['sdjfhsf']
# Testing the bed wij  najsdnjik 54265296526 sfnjnkermijrm

# %%
def yaswanth(test, abcd):
    print("I ah a " , test)
    print("Testing the bed wij ", abcd ,"sfnjnkermijrm")

yaswanth(["sdjfhsf"] , "najsdnjik 54265296526")
# Out:
# I ah a  ['sdjfhsf']
# Testing the bed wij  najsdnjik 54265296526 sfnjnkermijrm

# %%
def yas(mnc , klm):
    print("Enginer and the network with" , mnc)
    print("My name" , mnc , "shndfuihndfgudhnujd" , klm)

yas(125, 896)
# Out:
# Enginer and the network with 125
# My name 125 shndfuihndfgudhnujd 896

# %%
def yas(mnc , klm):
    print("Enginer and the network with" , mnc)
    print("My name" , mnc , "shndfuihndfgudhnujd" , klm)

yas("hgsyfbdeh", "jhbjixnfdfjhifgk")
# Out:
# Enginer and the network with hgsyfbdeh
# My name hgsyfbdeh shndfuihndfgudhnujd jhbjixnfdfjhifgk

# %% [markdown]
# This way, with keyword arguments, the order of the arguments does not matter.

# %%
def yas(pon , king):
    print("I am an eginer with", pon)
    print("Netwiork engijhnerjs is the LUB which s" , king)

yas("sdfnbsfhd",{54515151})
# Out:
# I am an eginer with sdfnbsfhd
# Netwiork engijhnerjs is the LUB which s {54515151}

# %%
def yas(pon , king):
    print("I am an eginer with", pon)
    print("Netwiork engijhnerjs" , pon , " is the LUB which s" , king)

yas("sdfnbsfhd",{54515151})
# Out:
# I am an eginer with sdfnbsfhd
# Netwiork engijhnerjs sdfnbsfhd  is the LUB which s {54515151}

# %% [markdown]
# The phrase Keyword Arguments is often shortened to kwargs in Python documentation.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Positional Arguments
#
# When you call a function with arguments without using keywords, they are called positional arguments.
#
# Positional arguments must be in the correct order:

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function("dog", "Buddy")
# Out:
# I have a dog
# My dog's name is Buddy

# %%
def yas(man, owl):
    print("I am enginn e" , man , "with 8 eyars of expoa ")
    print("owl is the teethand " , owl , man , " the mango of the")

yas(546545645, "yaswanth Alam")
# Out:
# I am enginn e 546545645 with 8 eyars of expoa
# owl is the teethand  yaswanth Alam 546545645  the mango of the

# %% [markdown]
# The order matters with positional arguments:
#
# Example
#
# Switching the order changes the result:

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function("Buddy", "dog")
# Out:
# I have a Buddy
# My Buddy's name is dog

# %% [markdown]
# Mixing Positional and Keyword Arguments
#
# You can mix positional and keyword arguments in a function call.
#
# However, positional arguments must come before keyword arguments:

# %%
def yas(test , net, yak):
    print("I have an ", test , "betejs jxnfgjk", net , "oxford dictionary" , yak)

yas("How are you ?" , net = 89 , yak = "ALAM Is the Enginner ")
# Out:
# I have an  How are you ? betejs jxnfgjk 89 oxford dictionary ALAM Is the Enginner

# %%
def my_function(animal, name, age):
  print("I have a", age, "year old", animal, "named", name)

my_function("dog", name = "Buddy", age = 5)
# Out:
# I have a 5 year old dog named Buddy

# %% [markdown]
# Passing Different Data Types
#
# You can send any data type as an argument to a function (string, number, list, dictionary, etc.).
#
# The data type will be preserved inside the function:
#
# Example
#
# Sending a list as an argument:

# %%
def my_function(fruits):
  for fruit in fruits:
    print(fruit)

my_fruits = ["apple", "banana", "cherry"]
my_function(my_fruits)
# Out:
# apple
# banana
# cherry

# %%
def quit(rose):
    for i in rose:
        print(i)

hen = ["king" , "FAMILY" , "Tiger"]

quit(hen)
# Out:
# king
# FAMILY
# Tiger

# %%
def to(ro):
    for i in ro:
        print(i)

eagle = ["tjdnf" ,"shdvshfb","541651451"]
to(eagle)
# Out:
# tjdnf
# shdvshfb
# 541651451

# %% [markdown]
# Example
#
# Sending a dictionary as an argument:

# %%
def my_function(person):
  print("Name:", person["name"])
  print("Age:", person["age"])

my_person = {"name": "Emil", "age": 25}
my_function(my_person)
# Out:
# Name: Emil
# Age: 25

# %%
def yas(ink):
    print("lion: ", ink["jk"])
    print("tiger: ", ink["ril"])

hut={"jk": "sdjfbjs", "ril":85465415}
yas(hut)
# Out:
# lion:  sdjfbjs
# tiger:  85465415

# %%
def yu(895):
    pass
# Out:
#   Cell In[24], line 1
#     def yu(895):
#            ^
# SyntaxError: invalid syntax

# %%
def 89(2563):
pass
# Out:
#   Cell In[25], line 1
#     def 89(2563):
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Example
#
# Sending a dictionary as an argument:

# %%
def my_function(person):
  print("Name:", person["name"])
  print("Age:", person["age"])

my_person = {"name": "Emil", "age": 25}
my_function(my_person)
# Out:
# Name: Emil
# Age: 25

# %%
def owl(lion):
    print("ring" , lion["jk"])
    print("hen" , lion["js"])

jog = {"jk":"roiul" , "js" : "temper"}
owl(jog)
# Out:
# ring roiul
# hen temper

# %% [markdown]
# Return Values
#
# Functions can return values using the return statement:

# %%
def yas(x, y):
    return(x+y)
yas(9,10)
# Out:
# 19

# %%
def yas(x, y):
    return(x+y)

inl = yas(89,6262)
print(inl)
# Out:
# 6351

# %% [markdown]
# Returning Different Data Types
#
# Functions can return any data type, including lists, tuples, dictionaries, and more.
#
# Example
#
# A function that returns a list:

# %%
def my_function():
  return ["apple", "banana", "cherry"]

fruits = my_function()
print(fruits[0])
print(fruits[1])
print(fruits[2])
# Out:
# apple
# banana
# cherry

# %%
def ring():
    return["hen","monkey","lion"]

ear = ring()
print(ear[0])
print(ear[1])
print(ear[2])
# Out:
# hen
# monkey
# lion

# %%
def ring():
    return["hen","monkey","lion"]

ear = ring()
print(ear[0])
print(ear[1])
print(ear[2])
print(ear[3])
# Out:
# hen
# monkey
# lion
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 8
#       6 print(ear[1])
#       7 print(ear[2])
# ----> 8 print(ear[3])
#
# IndexError: list index out of range

# %%
def ring():
    return["hen","monkey","lion"]

print(ring[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 4
#       1 def ring():
#       2     return["hen","monkey","lion"]
# ----> 4 print(ring[0])
#
# TypeError: 'function' object is not subscriptable

# %%
def ring():
    return["hen","monkey","lion"]

print(ring()[0])
print(ring()[1])
print(ring()[2])
# Out:
# hen
# monkey
# lion

# %% [markdown]
# Example
#
# A function that returns a tuple:

# %%
def my_function():
  return (10, 20)

x, y = my_function()
print("x:", x)
print("y:", y)
# Out:
# x: 10
# y: 20

# %%
def tel():
    return(9,10)

a, b = tel()
print("x:", a)
print("y:", b)
# Out:
# x: 9
# y: 10

# %%
def quit():
    return(7,15)

j, k = quit()
print("x" , j)
print("l" , k)
# Out:
# x 7
# l 15

# %% [markdown]
# Positional-Only Arguments
#
# You can specify that a function can have ONLY positional arguments.
#
# To specify positional-only arguments, add , / after the arguments:

# %%
def my_function(name, /):
  print("Hello", name)

my_function("Emil")
# Out:
# Hello Emil

# %%
def alam(pen, /):
    print("skmnfkdmfkd", pen)

alam("singing")
# Out:
# skmnfkdmfkd singing

# %%
def alam(pen):
    print("skmnfkdmfkd", pen)

alam("singing")
# Out:
# skmnfkdmfkd singing

# %% [markdown]
# Without the , / you are actually allowed to use keyword arguments even if the function expects positional arguments:

# %%
def my_function(name):
  print("Hello", name)

my_function(name = "Emil")
# Out:
# Hello Emil

# %%
def alam(pen):
    print("skmnfkdmfkd", pen)

alam("singing")
# Out:
# skmnfkdmfkd singing

# %% [markdown]
# With , /, you will get an error if you try to use keyword arguments:

# %%
def my_function(name, /):
  print("Hello", name)

my_function(name = "Emil")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 4
#       1 def my_function(name, /):
#       2   print("Hello", name)
# ----> 4 my_function(name = "Emil")
#
# TypeError: my_function() got some positional-only arguments passed as keyword arguments: 'name'

# %%
def alam(ink):
    print("sdhbfsfkgnsfkmsojiosmdfoksj+ 5454154", ink)

alam("yaswanth")
# Out:
# sdhbfsfkgnsfkmsojiosmdfoksj+ 5454154 yaswanth

# %%
def alam(ink, /):
    print("sdhbfsfkgnsfkmsojiosmdfoksj+ 5454154", ink)

alam(ink="yaswanth")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 4
#       1 def alam(ink, /):
#       2     print("sdhbfsfkgnsfkmsojiosmdfoksj+ 5454154", ink)
# ----> 4 alam(ink="yaswanth")
#
# TypeError: alam() got some positional-only arguments passed as keyword arguments: 'ink'

# %% [markdown]
# Keyword-Only Arguments
#
# To specify that a function can have only keyword arguments, add *, before the arguments:

# %%
def my_function(*, name):
  print("Hello", name)

my_function(name = "Emil")
# Out:
# Hello Emil

# %%
def alam(*, ink):
    print("sdhbfsfkgnsfkmsojiosmdfoksj+ 5454154", ink)

alam(ink="yaswanth")
# Out:
# sdhbfsfkgnsfkmsojiosmdfoksj+ 5454154 yaswanth

# %%
def ring(*, mango):
    print("jsbdfksfk+854541541",mango)

ring(mango="845415415+sdfbhjndfk+yaswanth Alam is the network ")
# Out:
# jsbdfksfk+854541541 845415415+sdfbhjndfk+yaswanth Alam is the network

# %% [markdown]
# Without *,, you are allowed to use positional arguments even if the function expects keyword arguments:

# %%
def ring(mango):
    print("jsbdfksfk+854541541",mango)

ring(mango="845415415+sdfbhjndfk+yaswanth Alam is the network ")
# Out:
# jsbdfksfk+854541541 845415415+sdfbhjndfk+yaswanth Alam is the network

# %% [markdown]
# With *,, you will get an error if you try to use positional arguments:

# %%
def ring(*, mango):
    print("jsbdfksfk+854541541",mango)

ring("845415415+sdfbhjndfk+yaswanth Alam is the network ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 4
#       1 def ring(*, mango):
#       2     print("jsbdfksfk+854541541",mango)
# ----> 4 ring("845415415+sdfbhjndfk+yaswanth Alam is the network ")
#
# TypeError: ring() takes 0 positional arguments but 1 was given

# %% [markdown]
# Combining Positional-Only and Keyword-Only
#
# You can combine both argument types in the same function.
#
# Arguments before / are positional-only, and arguments after * are keyword-only:

# %%
def my_function(a, b, /, *, c, d):
  return a + b + c + d

result = my_function(5, 10, c = 15, d = 20)
print(result)
# Out:
# 50

# %% [markdown]
# https://www.w3schools.com/python/python_args_kwargs.asp
#
#
# Python *args and **kwargs
#
# By default, a function must be called with the correct number of arguments.
#
# However, sometimes you may not know how many arguments that will be passed into your function.
#
# *args and **kwargs allow functions to accept a unknown number of arguments.
#
#
# Arbitrary Arguments - *args
#
# If you do not know how many arguments will be passed into your function, add a * before the parameter name.
#
# This way, the function will receive a tuple of arguments and can access the items accordingly:
#
# ![image.png](attachment:image.png)
#
#
#
# Arbitrary Arguments are often shortened to *args in Python documentation.

# %% [markdown]
# Example:
#
# Using *args to accept any number of arguments:

# %%
def my_function(*kids):
  print("The youngest child is " + kids[2])

my_function("Emil", "Tobias", "Linus")
# Out:
# The youngest child is Linus

# %%
def ring(*use):
    print("The value of n is the number and the " + use)
ring("jnsdf","snfbdfj","sdjfbxfjn")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 def ring(*use):
#       2     print("The value of n is the number and the " + use)
# ----> 3 ring("jnsdf","snfbdfj","sdjfbxfjn")
#
# Cell In[67], line 2, in ring(*use)
#       1 def ring(*use):
# ----> 2     print("The value of n is the number and the " + use)
#
# TypeError: can only concatenate str (not "tuple") to str

# %%
def ring(*use):
    print("The value of n is the number and the " + use[1])
ring("jnsdf","snfbdfj","sdjfbxfjn")
# Out:
# The value of n is the number and the snfbdfj

# %%
def ring(*use):
    print("The value of n is the number and the " + use[2])
ring("jnsdf","snfbdfj","sdjfbxfjn")
# Out:
# The value of n is the number and the sdjfbxfjn

# %%
def ring(*use):
    print("The value of n is the number and the " + use[])
ring("jnsdf","snfbdfj","sdjfbxfjn")
# Out:
#   Cell In[70], line 2
#     print("The value of n is the number and the " + use[])
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
def youth(*ear):
    print("The num,ber and the value sis the compute of ", ear[2])

youth("ear","ihbsdjhsdf","xcjbnlollkl+54151")
# Out:
# The num,ber and the value sis the compute of  xcjbnlollkl+54151

# %% [markdown]
# What is *args?
#
# The *args parameter allows a function to accept any number of positional arguments.
#
# Inside the function, args becomes a tuple containing all the passed arguments:
#
# Example
#
# Accessing individual arguments from *args:

# %%
def my_function(*args):
  print("Type:", type(args))
  print("First argument:", args[0])
  print("Second argument:", args[1])
  print("All arguments:", args)

my_function("Emil", "Tobias", "Linus")
# Out:
# Type: <class 'tuple'>
# First argument: Emil
# Second argument: Tobias
# All arguments: ('Emil', 'Tobias', 'Linus')

# %%
def qon(*args):
    print("Type", type(args))
    print("cat", args[0])
    print("dog",args[1])
    print("elephanet",args[2])
qon("abcdef","mnop","aeiou")
# Out:
# Type <class 'tuple'>
# cat abcdef
# dog mnop
# elephanet aeiou

# %%
def teeth(*nose):
    print("Type is the  : ", type(nose))
    print("The name is", nose[0])
    print("Youi are the best", nose[1])
    print("I am an engineer and the ", nose[2])
teeth("sdfbjsf","gun","hill")
# Out:
# Type is the  :  <class 'tuple'>
# The name is sdfbjsf
# Youi are the best gun
# I am an engineer and the  hill

# %% [markdown]
# Using *args with Regular Arguments
#
# You can combine regular parameters with *args.
#
# Regular parameters must come before *args:

# %%
def my_function(greeting, *names):
  for name in names:
    print(greeting, name)

my_function("Hello", "Emil", "Tobias", "Linus")
# Out:
# Hello Emil
# Hello Tobias
# Hello Linus

# %% [markdown]
# In this example, "Hello" is assigned to greeting, and the rest are collected in names.

# %%
def alam(network, *test):
    for i in test:
        print(network, i)

alam("king", "naveen", "alam", "navya")
# Out:
# king naveen
# king alam
# king navya

# %%
def nani(yash, *naveen):
    for i in naveen:
        print(yash, i)
nani("Navya","test","alam","how arte you", "Who are you")
# Out:
# Navya test
# Navya alam
# Navya how arte you
# Navya Who are you

# %%
def nani(yash, *naveen):
    for i in naveen:
        print(i, yash)
nani("Navya","test","alam","how arte you", "Who are you")
# Out:
# test Navya
# alam Navya
# how arte you Navya
# Who are you Navya

# %% [markdown]
# Practical Example with *args
#
#
# *args is useful when you want to create flexible functions:
#
# Example
#
#
# A function that calculates the sum of any number of values:

# %%
def my_function(*numbers):
  total = 0
  for num in numbers:
    total += num
  return total

print(my_function(1, 2, 3))
print(my_function(10, 20, 30, 40))
print(my_function(5))
# Out:
# 6
# 100
# 5

# %%
def alam(*up):
    test = 0
    for i in up:
        test+=i
        return test

print(alam(5,8,1))
# Out:
# 5

# %% [markdown]
# Indentation is very very important

# %%
def alam(*up):
    test = 0
    for i in up:
        test+=i
    return test

print(alam(5,8,1))
# Out:
# 14

# %%
def ring(*ugly):
    test=0
    for i in ugly:
        test+=i
    return test
print(ring(7,8,9,2,54,21,5515))
# Out:
# 5616

# %%
def ring(*ugly):
    #test=0
    for i in ugly:
        return(i)
print(ring(7,8,9,2,54,21,5515))
# Out:
# 7

# %% [markdown]
# ✔ What happens?
#
# Again, *ugly becomes (7, 8, 9, 2, 54, 21, 5515)
#
# The loop starts…
#
# BUT return(i) exits the function immediately on the first iteration.
#
# Only the first element (7) is returned.
#
# The rest of the loop never runs.

# %%
def ring(*ugly):
    #test=0
    for i in ugly:
        print(i)
print(ring(7,8,9,2,54,21,5515))
# Out:
# 7
# 8
# 9
# 2
# 54
# 21
# 5515
# None

# %% [markdown]
# ✔ What happens?
#
# *ugly collects all arguments into a tuple: (7, 8, 9, 2, 54, 21, 5515)
#
# The loop prints each value one by one.
#
# There is no return statement, so Python returns None automatically.

# %%
def ring(*ugly):
    test=0
    for i in ugly:
        test+=i
    print(test)
print(ring(7,8,9,2,54,21,5515))
# Out:
# 5616
# None

# %%
def ring(*ugly):
    test=0
    for i in ugly:
        test+=i
        print(test)
print(ring(7,8,9,2,54,21,5515))
# Out:
# 7
# 15
# 24
# 26
# 80
# 101
# 5616
# None

# %%
def ring(*ugly):
    test=0
    for i in ugly:
        test+=i
        return(test)
print(ring(7,8,9,2,54,21,5515))
# Out:
# 7

# %%
def ring(*ugly):
    test=0
    for i in ugly:
        test+=i
    return(test)
print(ring(7,8,9,2,54,21,5515))
# Out:
# 5616

# %% [markdown]
# Example
#
# Finding the maximum value:

# %%
def my_function(*numbers):
  if len(numbers) == 0:
    return None
  max_num = numbers[0]
  for num in numbers:
    if num > max_num:
      max_num = num
  return max_num

print(my_function(3, 7, 2, 9, 1))
# Out:
# 9

# %%
def alam(*yaswanth):
    if len(yaswanth) == 0:
        return None
    max = yaswanth[0]
    for i in yaswanth:
        if i > max:
            max = i
    return max

print(alam(0))
# Out:
# 0

# %%
def alam(*yaswanth):
    if len(yaswanth) == 0:
        return None
    max = yaswanth[0]
    for i in yaswanth:
        if i > max:
            max = i
    return max

print(alam())
# Out:
# None

# %%
def alam(*yaswanth):
    if len(yaswanth) == 0:
        return None
    max = yaswanth[0]
    for i in yaswanth:
        if i > max:
            max = i
    return max

print(alam(1,8,215,6526265,0))
# Out:
# 6526265

# %% [markdown]
# Arbitrary Keyword Arguments - **kwargs
#
#
# If you do not know how many keyword arguments will be passed into your function, add two asterisks ** before the parameter name.
#
# This way, the function will receive a dictionary of arguments and can access the items accordingly:
#
#
# Example
#
#
# Using **kwargs to accept any number of keyword arguments:

# %%
def my_function(**kid):
  print("His last name is " + kid["lname"])

my_function(fname = "Tobias", lname = "Refsnes")
# Out:
# His last name is Refsnes

# %%
def alam(**kwargs):
    print("The name is alam " + kwargs["test"])

alam(lion = "hbdfjhsfn", test = "he")
# Out:
# The name is alam he

# %%
def yas(**alam):
    print("The name is the alam and the yaswanth" + alam["use"])

yas(use = "56652" )
# Out:
# The name is the alam and the yaswanth56652

# %%
def yas(**alam):
    print("The name is the alam and the yaswanth" + alam)

yas(use = "56652" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 4
#       1 def yas(**alam):
#       2     print("The name is the alam and the yaswanth" + alam)
# ----> 4 yas(use = "56652" )
#
# Cell In[109], line 2, in yas(**alam)
#       1 def yas(**alam):
# ----> 2     print("The name is the alam and the yaswanth" + alam)
#
# TypeError: can only concatenate str (not "dict") to str

# %%
def yas(**alam):
    print("The name is the alam and the yaswanth" + alam("use"))

yas(use = "56652" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 4
#       1 def yas(**alam):
#       2     print("The name is the alam and the yaswanth" + alam("use"))
# ----> 4 yas(use = "56652" )
#
# Cell In[106], line 2, in yas(**alam)
#       1 def yas(**alam):
# ----> 2     print("The name is the alam and the yaswanth" + alam("use"))
#
# TypeError: 'dict' object is not callable

# %%
def tip(**war):
    print("My name is yaswwanthg Alam and IO am the network eginner ", war["house"])

tip(house = "jhmkkm")
# Out:
# My name is yaswwanthg Alam and IO am the network eginner  jhmkkm

# %% [markdown]
# https://www.w3schools.com/python/python_args_kwargs.asp#:~:text=in%20Python%20documentation.-,What%20is%20**kwargs%3F,-The%20**kwargs%20parameter
#
# Arbitrary Keyword Arguments are often shortened to **kwargs in Python documentation.
#
# What is **kwargs?
#
# The **kwargs parameter allows a function to accept any number of keyword arguments.
#
# Inside the function, kwargs becomes a dictionary containing all the keyword arguments
#
# Example
#
# Accessing values from **kwargs:

# %%
def my_function(**myvar):
  print("Type:", type(myvar))
  print("Name:", myvar["name"])
  print("Age:", myvar["age"])
  print("All data:", myvar)

my_function(name = "Tobias", age = 30, city = "Bergen")
# Out:
# Type: <class 'dict'>
# Name: Tobias
# Age: 30
# All data: {'name': 'Tobias', 'age': 30, 'city': 'Bergen'}

# %%
def alam(**yash):
    print("Type", type(yash))
    print("Engineer", yash["eng"])
    print("manager", yash["house"])
    print("get", yash)

alam(eng = "ajnjsdfs", house = "845151454")
# Out:
# Type <class 'dict'>
# Engineer ajnjsdfs
# manager 845151454
# get {'eng': 'ajnjsdfs', 'house': '845151454'}

# %%
def alam(**yash):
    print("Type", type(yash))
    print("Engineer", yash["eng"])
    print("manager", yash["house"])
    print("get", yash)

alam(eng = "ajnjsdfs", house = "845151454")
# Out:
# Type <class 'dict'>
# Engineer ajnjsdfs
# manager 845151454
# get {'eng': 'ajnjsdfs', 'house': '845151454'}

# %%
def owl(**hunt):
    print("Type", type(hunt))
    print("Value", hunt)

owl(bowl = "sjdfhsjdfn", jug = "8458485458")
# Out:
# Type <class 'dict'>
# Value {'bowl': 'sjdfhsjdfn', 'jug': '8458485458'}

# %%
def owl(**hunt):
    print("Type", type(hunt))
    print("Value", hunt)
    print("User", hunt["bowl"])
    print("Magic", hunt["jug"])

owl(bowl = "sjdfhsjdfn", jug = "8458485458")
# Out:
# Type <class 'dict'>
# Value {'bowl': 'sjdfhsjdfn', 'jug': '8458485458'}
# User sjdfhsjdfn
# Magic 8458485458

# %% [markdown]
# Using **kwargs with Regular Arguments
#
# You can combine regular parameters with **kwargs.
#
# Regular parameters must come before **kwargs:

# %%
def my_function(username, **details):
  print("Username:", username)
  print("Additional details:")
  for key, value in details.items():
    print("  ", key + ":", value)

my_function("emil123", age = 25, city = "Oslo", hobby = "coding")
# Out:
# Username: emil123
# Additional details:
#    age: 25
#    city: Oslo
#    hobby: coding

# %%
def alam(test , **house):
    print("Mango", test)
    print("The NExt values in the dictiponarty are the noted onesd with the key of ")
    for key , value in house.items():
        print("", key+ ":" , value)


alam("youth", age= 8955, lion="animal", gun=626551454, 89="teeth")
# Out:
#   Cell In[127], line 8
#     alam("youth", age= 8955, lion="animal", gun=626551454, 89="teeth")
#                                                            ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %% [markdown]
# Python variable names must start with a letter or underscore, not a digit.

# %%
def alam(test , **house):
    print("Mango", test)
    print("The NExt values in the dictiponarty are the noted onesd with the key of ")
    for key , value in house.items():
        print("", key+ ":" , value)


alam("youth", age= 8955, lion="animal", gun=626551454, abcd="teeth")
# Out:
# Mango youth
# The NExt values in the dictiponarty are the noted onesd with the key of
#  age: 8955
#  lion: animal
#  gun: 626551454
#  abcd: teeth

# %%
def alam(test , **house):
    print("Mango", test)
    print("The NExt values in the dictiponarty are the noted onesd with the key of ")
    for key , value in house.items():
        print("", key+ ":" , value)


alam("youth", age= 8955, lion="animal", gun=626551454, _89="teeth")
# Out:
# Mango youth
# The NExt values in the dictiponarty are the noted onesd with the key of
#  age: 8955
#  lion: animal
#  gun: 626551454
#  _89: teeth

# %%
def alam(test , **house):
    print("Mango", test)
    print("The NExt values in the dictiponarty are the noted onesd with the key of ")
    for key , value in house.items():
        print("", key+ ":" , value)

fan = {"89" : "goat"}

alam("youth", age= 8955, lion="animal", gun=626551454, **fan)
# Out:
# Mango youth
# The NExt values in the dictiponarty are the noted onesd with the key of
#  age: 8955
#  lion: animal
#  gun: 626551454
#  89: goat

# %% [markdown]
# Option 1: Use a dictionary and unpack it

# %%
def alam(test , **house):
    print("Mango", test)
    print("The NExt values in the dictiponarty are the noted onesd with the key of ")
    for key , value in house.items():
        print("    ", key ,  ":" , value)

fan = {"89" : "goat"}

alam("youth", age= 8955, lion="animal", gun=626551454, **fan)
# Out:
# Mango youth
# The NExt values in the dictiponarty are the noted onesd with the key of
#      age : 8955
#      lion : animal
#      gun : 626551454
#      89 : goat

# %%
def alam(test , **house):
    print("Mango", test)
    print("The NExt values in the dictiponarty are the noted onesd with the key of ")
    for key , value in house.items():
        print("", key ,  ":" , value)

fan = {"89" : "goat"}

alam("youth", age= 8955, lion="animal", gun=626551454, **fan)
# Out:
# Mango youth
# The NExt values in the dictiponarty are the noted onesd with the key of
#  age : 8955
#  lion : animal
#  gun : 626551454
#  89 : goat

# %%
def alam(test , **house):
    print("Mango", test)
    print("The NExt values in the dictiponarty are the noted onesd with the key of ")
    for key , value in house.items():
        print("", key ,  "   ::   " , value)

fan = {"89" : "goat"}

alam("youth", age= 8955, lion="animal", gun=626551454, **fan)
# Out:
# Mango youth
# The NExt values in the dictiponarty are the noted onesd with the key of
#  age    ::    8955
#  lion    ::    animal
#  gun    ::    626551454
#  89    ::    goat

# %% [markdown]
# Combining *args and **kwargs
#
# You can use both *args and **kwargs in the same function.
#
# The order must be:
#
#     1.regular parameters
#
#     2.*args
#
#     3.**kwargs

# %%
def my_function(title, *args, **kwargs):
  print("Title:", title)
  print("Positional arguments:", args)
  print("Keyword arguments:", kwargs)

my_function("User Info", "Emil", "Tobias", age = 25, city = "Oslo")
# Out:
# Title: User Info
# Positional arguments: ('Emil', 'Tobias')
# Keyword arguments: {'age': 25, 'city': 'Oslo'}

# %% [markdown]
# Unpacking Arguments
#
# The * and ** operators can also be used when calling functions to unpack (expand) a list or dictionary into separate arguments.
#
# Unpacking Lists with *
#
# If you have values stored in a list, you can use * to unpack them into individual arguments:
#
# Example
#
# Using * to unpack a list into arguments:

# %%
def my_function(a, b, c):
  return a + b + c

numbers = [1, 2, 3]
result = my_function(*numbers)
print(result)
# Out:
# 6

# %%
def yas(x,y,z):
    return x+y+z

alam = [4,8,6]
ref = yas(*alam)

print(ref)
# Out:
# 18

# %%
def ink(r,t,u):
    return r+t-u

mtr = {59654,545,8}
hut = ink(*mtr)
print(hut)
# Out:
# -59101

# %% [markdown]
# Unpacking Dictionaries with **
#
# If you have keyword arguments stored in a dictionary, you can use ** to unpack them:
#
# Example
#
# Using ** to unpack a dictionary into keyword arguments:

# %%
def my_function(fname, lname):
  print("Hello", fname, lname)

person = {"fname": "Emil", "lname": "Refsnes"}
my_function(**person)
# Out:
# Hello Emil Refsnes

# %%
def my_function(fname, lname):
  print("Hello", fname, lname)

person = {"fnam": "Emil", "lnam": "Refsnes"}
my_function(**person)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2   print("Hello", fname, lname)
#       4 person = {"fnam": "Emil", "lnam": "Refsnes"}
# ----> 5 my_function(**person)
#
# TypeError: my_function() got an unexpected keyword argument 'fnam'. Did you mean 'fname'?

# %%
def alam(lion, tiger):
    print("I am tjhe king of jungle", lion, tiger)

kid = {"lion" : "mnokhgsdf", "tiger" : 5841562151451}
ji = alam(**kid)
print(ji)
# Out:
# I am tjhe king of jungle mnokhgsdf 5841562151451
# None

# %%
def alam(lion, tiger):
    print("I am tjhe king of jungle", lion, tiger)

kid = {"lion" : "mnokhgsdf", "tiger" : 5841562151451}
alam(**kid)
# Out:
# I am tjhe king of jungle mnokhgsdf 5841562151451

# %%
def ring(hen, duck):
    print("I am the animal and tjhe bird", hen , duck)

cdn = {"hen":"I am and chciekn", "duck":"I am an water animal and live water"}
ring(**cdn)
# Out:
# I am the animal and tjhe bird I am and chciekn I am an water animal and live water

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# Remember: Use * and ** in function definitions to collect arguments, and use them in function calls to unpack arguments.

# %% [markdown]
# https://www.w3schools.com/python/python_scope.asp
#
#
# Python Scope
#
# Scope
#
# A variable is only available from inside the region it is created. This is called scope.
#
# Local Scope
#
#
# A variable created inside a function belongs to the local scope of that function, and can only be used inside that function.

# %% [markdown]
# Example
#
# A variable created inside a function is available inside that function:

# %%
def myfunc():
  x = 300
  print(x)

myfunc()
# Out:
# 300

# %%
def alam():
    x=52156515
    print(x)

alam()
# Out:
# 52156515

# %%
def yas():
    y=5222
    z=960212
    x=5456215
    k=x+y-z
    print(k)
yas()
# Out:
# 4501225

# %% [markdown]
# Function Inside Function
#
# As explained in the example above, the variable x is not available outside the function, but it is available for any function inside the function:
#
# Example
#
# The local variable can be accessed from a function within the function:

# %%
def myfunc():
  x = 300
  def myinnerfunc():
    print(x)
  myinnerfunc()

myfunc()
# Out:
# 300

# %%
def alam():
    x=1000
    def yasinner():
        print(x)
    yasinner()

alam()
# Out:
# 1000

# %%
def alam():
    x=1000
    def yasinner():
        print(x)
    #yasinner()

alam()

# %%
def alam():
    x=1000
    print(x)
    def yasinner():
        print(x)
    #yasinner()

alam()
# Out:
# 1000

# %%
def alam():
    x=1000
    print(x)
    def yasinner():
        print(x)
    yasinner()

alam()
# Out:
# 1000
# 1000

# %%
def alam():
    x=1000
    print(x)
    def yasinner():
        y=50
        print(x,y)
    yasinner()

alam()
# Out:
# 1000
# 1000 50

# %%
def alam():
    x=1000
    print(x)
    print(y)
    def yasinner():
        y=50
        print(x,y)
    yasinner()

alam()
# Out:
# 1000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 10
#       7         print(x,y)
#       8     yasinner()
# ---> 10 alam()
#
# Cell In[21], line 4, in alam()
#       2 x=1000
#       3 print(x)
# ----> 4 print(y)
#       5 def yasinner():
#       6     y=50
#
# NameError: name 'y' is not defined

# %% [markdown]
# Global Scope
#
# A variable created in the main body of the Python code is a global variable and belongs to the global scope.
#
# Global variables are available from within any scope, global and local.
#
# Example
#
# A variable created outside of a function is global and can be used by anyone:

# %%
x = 300

def myfunc():
  print(x)

myfunc()

print(x)
# Out:
# 300
# 300

# %%
y = 5000

def alam():
    print(y)

alam()
# Out:
# 5000

# %%
y = 5000

def alam():
    print(y)

alam()
print(y)
# Out:
# 5000
# 5000

# %%
y = 5000

def alam():
    print(y)
    def test():
        print(y)
    test()

alam()
print(y)
# Out:
# 5000
# 5000
# 5000

# %%
y = 5000

def alam():
    z=9855
    print(y)
    def test():
        print(y,z)
    test()

alam()
print(y)
# Out:
# 5000
# 5000 9855
# 5000

# %%
y = 5000

def alam():
    print(y)
    z=9855
    def test():
        print(y,z)
    test()

alam()
print(y)
# Out:
# 5000
# 5000 9855
# 5000

# %% [markdown]
# Naming Variables
#
# If you operate with the same variable name inside and outside of a function, Python will treat them as two separate variables, one available in the global scope (outside the function) and one available in the local scope (inside the function):
#
# Example
#
# The function will print the local x, and then the code will print the global x:

# %%
x = 300

def myfunc():
  x = 200
  print(x)

myfunc()

print(x)
# Out:
# 200
# 300

# %%
y = "sfgjdf"
def test():
    y = "shbdfjsf"
    print(y)
test()
print(y)
# Out:
# shbdfjsf
# sfgjdf

# %% [markdown]
# Global Keyword
#
# If you need to create a global variable, but are stuck in the local scope, you can use the global keyword.
#
# The global keyword makes the variable global.
#
# Example
#
#
# If you use the global keyword, the variable belongs to the global scope:

# %%
def myfunc():
  global x
  x = 300

myfunc()

print(x)
# Out:
# 300

# %%
def you():
    global x
    x= "sdhbfjsfn"

you()
print(x)
# Out:
# sdhbfjsfn

# %%
def you():
    global x
    x= "sdhbfjsfn"

you()

# %%
def you():
    global x
    x= "sdhbfjsfn"
    print(x)

you()
# Out:
# sdhbfjsfn

# %%
def win():
    global q
    q=54652562565
    print(q)

win()
# Out:
# 54652562565

# %% [markdown]
# Also, use the global keyword if you want to make a change to a global variable inside a function.
#
# Example
#
# To change the value of a global variable inside a function, refer to the variable by using the global keyword:

# %%
a = 544652156

def rose():
    global a
    a = 100

rose()
print(a)
# Out:
# 100

# %% [markdown]
# Nonlocal Keyword
#
# The nonlocal keyword is used to work with variables inside nested functions.
#
# The nonlocal keyword makes the variable belong to the outer function.
#
# Example
#
# If you use the nonlocal keyword, the variable will belong to the outer function:

# %%
def myfunc1():
  x = "Jane"
  def myfunc2():
    nonlocal x
    x = "hello"
  myfunc2()
  return x

print(myfunc1())
# Out:
# hello

# %%
def test():
    x = ",moneky"
    def test1():
        nonlocal x
        x = "crocdi;e"
    test1()
    return x

print(test())
# Out:
# crocdi;e

# %%
def test():
    x = ",moneky"
    def test1():
        #nonlocal x
        x = "crocdi;e"
    test1()
    return x

print(test())
# Out:
# ,moneky

# %%
def quin():
    e = "alam"
    def rou():
        nonlocal e
        e = "yaswanth_AlAM"
    return e
    rou()
print(quin())
# Out:
# alam

# %%
def quin():
    e = "alam"
    def rou():
        nonlocal e
        e = "yaswanth_AlAM"
    rou()
    return e
print(quin())
# Out:
# yaswanth_AlAM

# %% [markdown]
# The LEGB Rule
#
# Python follows the LEGB rule when looking up variable names, and searches for them in this order:
#
# Local - Inside the current function
#
# Enclosing - Inside enclosing functions (from inner to outer)
#
# Global - At the top level of the module
#
# Built-in - In Python's built-in namespace
#
#
# Example
#
# Understanding the LEGB rule:

# %%
x = "global"

def outer():
  x = "enclosing"
  def inner():
    x = "local"
    print("Inner:", x)
  inner()
  print("Outer:", x)

outer()
print("Global:", x)
# Out:
# Inner: local
# Outer: enclosing
# Global: global

# %%
x = 300
def myfunc():
  x = 200
myfunc()
print(x)
# Out:
# 300
