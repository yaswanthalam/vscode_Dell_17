# %% [markdown]
# https://www.w3schools.com/python/python_output.asp

# %%
print("hello World!")
# Out:
# hello World!

# %%
print("I am learning python")
print("Python is very important for netwokring")
print("Pythionb is the best")
# Out:
# I am learning python
# Python is very important for netwokring
# Pythionb is the best

# %% [markdown]
# Ther should be either double quotes or single quotes for an string

# %%
print("Hello")
print('hei')
# Out:
# Hello
# hei

# %%
print(hi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(hi)
#
# NameError: name 'hi' is not defined

# %% [markdown]
# end=" " will copy the print in the same line instead of new line.

# %%
print("Hi", end =" ")
print("hi")
# Out:
# Hi hi

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print(3)
print(54546525.)
print("5455414")
# Out:
# 3
# 54546525.0
# 5455414

# %%
print(3+6)
# Out:
# 9

# %%
print(545485+5452-6526)
# Out:
# 544411

# %%
print("I am an network engineer", 25 , "years old")
# Out:
# I am an network engineer 25 years old

# %%
print("hi",54515,"hgvbsdhfsbhgrs")
# Out:
# hi 54515 hgvbsdhfsbhgrs
