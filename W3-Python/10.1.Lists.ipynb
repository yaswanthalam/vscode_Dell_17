# %% [markdown]
# https://www.w3schools.com/python/python_lists_sort.asp
#
#
# Sort List Alphanumerically
#
# List objects have a sort() method that will sort the list alphanumerically, ascending, by default:

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
yaswanth = ["abc" , "ajnxnjf" , "akxjfkd" ,"jhdgbnj" ,"jkik" , "oioieirg" , "wyteuyryuwr" , "545565" ,"545415" , "221202"]

yaswanth.sort()
print(yaswanth)
# Out:
# ['221202', '545415', '545565', 'abc', 'ajnxnjf', 'akxjfkd', 'jhdgbnj', 'jkik', 'oioieirg', 'wyteuyryuwr']

# %%
alam = ["snfjs" ,"dfgnk" "xnbjnd" ,"eirietj" ,"kcmgkdf" , "6545151" , "45415" , '54620' , "98778595" , "2120202"]

alam.sort()

print(alam)
# Out:
# ['2120202', '45415', '54620', '6545151', '98778595', 'dfgnkxnbjnd', 'eirietj', 'kcmgkdf', 'snfjs']

# %%
alam = ["snfjs" ,"dfgnk" "xnbjnd" ,"eirietj" ,"kcmgkdf" , "6545151" , "45415" , '54620' , "98778595" , "2120202" , 5485 , 52150]

alam.sort()

print(alam)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 alam = ["snfjs" ,"dfgnk" "xnbjnd" ,"eirietj" ,"kcmgkdf" , "6545151" , "45415" , '54620' , "98778595" , "2120202" , 5485 , 52150]
# ----> 3 alam.sort()
#       5 print(alam)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort()
print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %%
alam = [ 51,562,56,52,21,0,21,5,152,5,21,2120]
alam.sort()
print(alam)
# Out:
# [0, 5, 5, 21, 21, 21, 51, 52, 56, 152, 562, 2120]

# %% [markdown]
# Sort Descending
#
# To sort descending, use the keyword argument reverse = True:
#
#
# Example
#
#
# Sort the list descending:

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort(reverse = True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
alam = ["orange" , "apple" ,"ant" , "xnfjk" , "dnfjdnm" , "wjrtirwj"]
alam.sort(reverse=True)
print(alam)
# Out:
# ['xnfjk', 'wjrtirwj', 'orange', 'dnfjdnm', 'apple', 'ant']

# %%
alam = ["orange" , "apple" ,"ant" , "xnfjk" , "dnfjdnm" , "wjrtirwj"]
alam.sort(reverse=False)
print(alam)
# Out:
# ['ant', 'apple', 'dnfjdnm', 'orange', 'wjrtirwj', 'xnfjk']

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort(reverse = True)
print(thislist)
# Out:
# [100, 82, 65, 50, 23]

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort(reverse = False)
print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %% [markdown]
# Customize Sort Function
#
# You can also customize your own function by using the keyword argument key = function.
#
# The function will return a number that will be used to sort the list (the lowest number first):
#
#
# Example
#
# Sort the list based on how close the number is to 50:

# %%
def alam(n):
    return abs(n - 50)

al = [100 , 55 , 88 , 212020 , 988959 , 878410 , 2120]

al.sort(key = alam)

print(al)
# Out:
# [55, 88, 100, 2120, 212020, 878410, 988959]

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]

thislist.sort(key = myfunc)

print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %%
def yas(n):
    return alam(n - 10)

ant = [100 , 89 , 77 , 220 , 12545 , 989569 , 4510]
ant.sort(key = yas)
print(ant)
# Out:
# [77, 89, 100, 220, 4510, 12545, 989569]

# %% [markdown]
# Customize Sort Function
#
# You can also customize your own function by using the keyword argument key = function.
#
# The function will return a number that will be used to sort the list (the lowest number first):
#
#
# Example
#
# Sort the list based on how close the number is to 50:

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)
print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %%
def alam(n):
    return abs(n-50)

yas = [545,552,21,33,623,20,10,20,30]
yas.sort(key=alam)
print(yas)
# Out:
# [33, 30, 21, 20, 20, 10, 545, 552, 623]

# %%
def alam(n):
    return abs(n-30)

yas = [545,552,21,33,623,20,10,20,30]
yas.sort(key=alam)
print(yas)
# Out:
# [30, 33, 21, 20, 20, 10, 545, 552, 623]

# %%
def alam(n):
    return abs(n-30)

yas = [545,552,21,33,623,20,10,20,30]
print(yas)
yas.sort(key=alam)
print(yas)
# Out:
# [545, 552, 21, 33, 623, 20, 10, 20, 30]
# [30, 33, 21, 20, 20, 10, 545, 552, 623]

# %% [markdown]
# Case Insensitive Sort
#
# By default the sort() method is case sensitive, resulting in all capital letters being sorted before lower case letters:
#
# Example
#
# Case sensitive sorting can give an unexpected result:

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]

thislist.sort()

print(thislist)
# Out:
# ['Kiwi', 'Orange', 'banana', 'cherry']

# %%
yas = ["alam", "abc ","sbjsafnj" ,"sfgbcjhb","tiituirty"]

yas.sort()

print(yas)
# Out:
# ['abc ', 'alam', 'sbjsafnj', 'sfgbcjhb', 'tiituirty']

# %% [markdown]
# Luckily we can use built-in functions as key functions when sorting a list.
#
# So if you want a case-insensitive sort function, use str.lower as a key function:

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]

thislist.sort(key = str.lower)

print(thislist)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %%
alam = ["sfgnbdj","srfgbdj","wieywuytu","xnfjd", "test" ,"ant","apple" ,"ball"]
alam.sort(key = str.lower)
print(alam)
# Out:
# ['ant', 'apple', 'ball', 'sfgnbdj', 'srfgbdj', 'test', 'wieywuytu', 'xnfjd']

# %% [markdown]
# Reverse Order
#
# What if you want to reverse the order of a list, regardless of the alphabet?
#
# The reverse() method reverses the current sorting order of the elements.
#
# Example
#
# Reverse the order of the list items:

# %%
alam = ["sfgnbdj","srfgbdj","wieywuytu","xnfjd", "test" ,"ant","apple" ,"ball"]
alam.reverse()
print(alam)
# Out:
# ['ball', 'apple', 'ant', 'test', 'xnfjd', 'wieywuytu', 'srfgbdj', 'sfgnbdj']

# %% [markdown]
# https://www.w3schools.com/python/python_lists_copy.asp
#
# Python - Copy Lists
#
#
# Copy a List
#
# You cannot copy a list simply by typing list2 = list1, because: list2 will only be a reference to list1, and changes made in list1 will automatically also be made in list2.
#
# Use the copy() method
#
# You can use the built-in List method copy() to copy a list.

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
abc = ["abc" , "ansjdfn","geik" , "xvkdfm" , "sfgnjkoow" , "werjiwr" , "596256"]

xyz = abc.copy()
print(xyz)
# Out:
# ['abc', 'ansjdfn', 'geik', 'xvkdfm', 'sfgnjkoow', 'werjiwr', '596256']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
abc = ["abc" , "ansjdfn","geik" , "xvkdfm" , "sfgnjkoow" , "werjiwr" , "596256"]

xyz = list(abc)
print(xyz)
# Out:
# ['abc', 'ansjdfn', 'geik', 'xvkdfm', 'sfgnjkoow', 'werjiwr', '596256']

# %%
amc = ["asbf","sfnjdf","mkv","54612",6562,21202,5489451520210]

abc = list(amc)
print(abc)
# Out:
# ['asbf', 'sfnjdf', 'mkv', '54612', 6562, 21202, 5489451520210]

# %% [markdown]
# Use the slice Operator
# You can also make a copy of a list by using the : (slice) operator.
#
# Example
# Make a copy of a list with the : operator:

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
amc = ["asbf","sfnjdf","mkv","54612",6562,21202,5489451520210]

abc = amc[:]
print(abc)
# Out:
# ['asbf', 'sfnjdf', 'mkv', '54612', 6562, 21202, 5489451520210]

# %% [markdown]
# https://www.w3schools.com/python/python_lists_join.asp
#
# Join Two Lists
#
# There are several ways to join, or concatenate, two or more lists in Python.
#
# One of the easiest ways are by using the + operator.

# %%
lst1 = ["a", "b" , "c"]
lst2 = [1,522,896]

lst3 = lst1 + lst2

print(lst3)
# Out:
# ['a', 'b', 'c', 1, 522, 896]

# %% [markdown]
# Another way to join two lists is by appending all the items from list2 into list1, one by one:
#
# Example
# Append list2 into list1:

# %%
lst1 = ["a", "b" , "c"]
lst2 = [1,522,896]

for x in lst2:
    lst1.append(x)

print(lst1)
# Out:
# ['a', 'b', 'c', 1, 522, 896]

# %%
abc = ["and","xfvn","sjwir","vfmdkm"]
xyz = [54515,221,555]

for x in xyz:
    abc.append(x)

print(abc)
# Out:
# ['and', 'xfvn', 'sjwir', 'vfmdkm', 54515, 221, 555]

# %%
abc = ["and","xfvn","sjwir","vfmdkm"]
xyz = [54515,221,555]

m = abc + xyz
print(m)
# Out:
# ['and', 'xfvn', 'sjwir', 'vfmdkm', 54515, 221, 555]

# %% [markdown]
# Or you can use the extend() method, where the purpose is to add elements from one list to another list:
#
# Example
#
# Use the extend() method to add list2 at the end of list1:

# %%
abc = ["and","xfvn","sjwir","vfmdkm"]
xyz = [54515,221,555]

abc.extend(xyz)

print(abc)
# Out:
# ['and', 'xfvn', 'sjwir', 'vfmdkm', 54515, 221, 555]

# %%
lst1 = ["a", "b" , "c"]
lst2 = [1,522,896]

lst1.extend(lst2)

print(lst1)
# Out:
# ['a', 'b', 'c', 1, 522, 896]

# %% [markdown]
# https://www.w3schools.com/python/python_lists_methods.asp
#
# List Methods
#
# Python has a set of built-in methods that you can use on lists.
#
# Method	Description
# append()	Adds an element at the end of the list
# clear()	Removes all the elements from the list
# copy()	Returns a copy of the list
# count()	Returns the number of elements with the specified value
# extend()	Add the elements of a list (or any iterable), to the end of the current list
# index()	Returns the index of the first element with the specified value
# insert()	Adds an element at the specified position
# pop()	Removes the element at the specified position
# remove()	Removes the item with the specified value
# reverse()	Reverses the order of the list
# sort()	Sorts the list
#
#
# ![image.png](attachment:image.png)
