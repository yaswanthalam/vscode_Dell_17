# %% [markdown]
# https://www.w3schools.com/python/python_sets_loop.asp
#
# Loop Items
#
# You can loop through the set items by using a for loop:
#
# Example:
#
#
# Loop through the set, and print the values:

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# cherry
# apple
# banana

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

for i in abc:
    print(i)
# Out:
# False
# alam
# mnc
# alam
# 5451256
# yaswanth
# 12354

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

for i in abc:
    print(abc)
# Out:
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'}
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'}
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'}
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'}
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'}
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'}
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

for i in abc:
    print(abc, i)
# Out:
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'} False
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'} alam
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'} mnc
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'} alam
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'} 5451256
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'} yaswanth
# {False, 'alam', 'mnc', 'alam ', 5451256, 'yaswanth', '12354'} 12354

# %%
for x in {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}:
    print(x)
# Out:
# False
# yaswanth
# alam
# mnc
# alam
# 5451256
# 12354

# %% [markdown]
# https://www.w3schools.com/python/python_sets_join.asp
#
#
# Python - Join Sets
#
# Join Sets
#
# There are several ways to join two or more sets in Python.
#
# The union() and update() methods joins all items from both sets.
#
# The intersection() method keeps ONLY the duplicates.
#
# The difference() method keeps the items from the first set that are not in the other set(s).
#
# The symmetric_difference() method keeps all items EXCEPT the duplicates.

# %% [markdown]
# Union
#
# The union() method returns a new set with all items from both sets.
#
# Example
#
# Join set1 and set2 into a new set:

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 'b', 'c', 'a'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = { "5454154" , "sshusfn" , "mnc"}

nc = abc.union(cdn)

print(nc)
# Out:
# {False, 'sshusfn', 'yaswanth', '5454154', 'alam', 'mnc', 'alam ', 5451256, '12354'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = { "5454154" , "sshusfn" , "mnc"}

#nc = abc.union(cdn)
cd = cdn.union(abc)

print(nc)
# Out:
# {False, 'sshusfn', 'yaswanth', '5454154', 'alam', 'mnc', 'alam ', 5451256, '12354'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = { "5454154" , "sshusfn" , "mnc"}

nc = abc.union(cdn)
cd = cdn.union(abc)

print(cd)
print(nc)
# Out:
# {False, '12354', 'alam', 'sshusfn', 'mnc', 'alam ', 5451256, 'yaswanth', '5454154'}
# {False, '12354', 'alam', '5454154', 'mnc', 'alam ', 'sshusfn', 5451256, 'yaswanth'}

# %% [markdown]
# You can use the | operator instead of the union() method, and you will get the same result.

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = { "5454154" , "sshusfn" , "mnc"}

cd = cdn|abc

print(cd)
# Out:
# {False, '12354', 'alam', 'sshusfn', 'mnc', 'alam ', 5451256, 'yaswanth', '5454154'}

# %% [markdown]
# Join Multiple Sets
#
# All the joining methods and operators can be used to join multiple sets.
#
# When using a method, just add more sets in the parentheses, separated by commas:
#
# Example
#
# Join multiple sets with the union() method:

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = { "5454154" , "sshusfn" , "mnc"}

bcd = {"asdfhsj" , "xgfndfj" , 5654562, 2120, "sdfjhsdnmks"}

cd = bcd.union(abc, cdn)

print(cd)
# Out:
# {False, 5654562, '12354', 'alam', 2120, '5454154', 'mnc', 'alam ', 'sshusfn', 'asdfhsj', 'xgfndfj', 5451256, 'sdfjhsdnmks', 'yaswanth'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1.union(set2, set3, set4)
print(myset)
# Out:
# {1, 2, 3, 'apple', 'Elena', 'a', 'John', 'cherry', 'b', 'bananas', 'c'}

# %% [markdown]
# When using the | operator, separate the sets with more | operators:
#
# Example
#
# Use | to join two sets:

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = { "5454154" , "sshusfn" , "mnc"}

bcd = {"asdfhsj" , "xgfndfj" , 5654562, 2120, "sdfjhsdnmks"}

cd = abc | cdn | bcd

print(cd)
# Out:
# {False, 5654562, '12354', 'alam', '5454154', 2120, 'mnc', 'alam ', 'sshusfn', 'asdfhsj', 'xgfndfj', 5451256, 'sdfjhsdnmks', 'yaswanth'}

# %% [markdown]
# Join a Set and a Tuple
#
# The union() method allows you to join a set with other data types, like lists or tuples.
#
# The result will be a set.

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = ["5454154" , "sshusfn" , "mnc"]

#bcd = {"asdfhsj" , "xgfndfj" , 5654562, 2120, "sdfjhsdnmks"}

cd = abc.union(cdn)

print(cd)
# Out:
# {False, 'alam', 'sshusfn', '5454154', 'yaswanth', '12354', 'mnc', 'alam ', 5451256}

# %%
x = {"a", "b", "c"}
y = (1, 2, 3)

z = x.union(y)
print(z)
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %% [markdown]
# Note: The  | operator only allows you to join sets with sets, and not with other data types like you can with the  union() method.

# %% [markdown]
# Update
#
# The update() method inserts all items from one set into another.
#
# The update() changes the original set, and does not return a new set.
#
#
# Example
#
# The update() method inserts the items in set2 into set1:

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}

set1.update(set2)
print(set1)
# Out:
# {1, 2, 'b', 3, 'c', 'a'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = {"5454154" , "sshusfn" , "mnc"}

#bcd = {"asdfhsj" , "xgfndfj" , 5654562, 2120, "sdfjhsdnmks"}

abc.update(cdn)
print(abc)
# Out:
# {False, '12354', 'alam', '5454154', 'mnc', 'alam ', 'sshusfn', 5451256, 'yaswanth'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = {"5454154" , "sshusfn" , "mnc"}

#bcd = {"asdfhsj" , "xgfndfj" , 5654562, 2120, "sdfjhsdnmks"}

cdn.update(abc)
print(cdn)
# Out:
# {False, '12354', 'alam', 'sshusfn', 'mnc', 'alam ', 5451256, 'yaswanth', '5454154'}

# %% [markdown]
# cdn is with list and noted by [ ] but also update function works

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = ["5454154" , "sshusfn" , "mnc"]

#bcd = {"asdfhsj" , "xgfndfj" , 5654562, 2120, "sdfjhsdnmks"}

abc.update(cdn)
print(abc)
# Out:
# {False, 'alam', 'sshusfn', '5454154', 'yaswanth', '12354', 'mnc', 'alam ', 5451256}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

cdn = ["5454154" , "sshusfn" , "mnc"]

#bcd = {"asdfhsj" , "xgfndfj" , 5654562, 2120, "sdfjhsdnmks"}

cdn.update(abc)
print(cdn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 7
#       3 cdn = ["5454154" , "sshusfn" , "mnc"]
#       5 #bcd = {"asdfhsj" , "xgfndfj" , 5654562, 2120, "sdfjhsdnmks"}
# ----> 7 cdn.update(abc)
#       8 print(cdn)
#
# AttributeError: 'list' object has no attribute 'update'

# %% [markdown]
# Note: Both union() and update() will exclude any duplicate items.

# %% [markdown]
# Intersection
#
# Keep ONLY the duplicates
#
# The intersection() method will return a new set, that only contains the items that are present in both sets.

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1}

gf = abc.intersection(cdn)

print(gf)
# Out:
# {1, 'mnc'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

gf = abc.intersection(cdn)

print(gf)
# Out:
# {0, 1, 'mnc'}

# %% [markdown]
# You can use the & operator instead of the intersection() method, and you will get the same result.

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1}

gf = abc & cdn

print(gf)
# Out:
# {1, 'mnc'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

gf = abc&cdn

print(gf)
# Out:
# {0, 1, 'mnc'}

# %% [markdown]
# Note: The & operator only allows you to join sets with sets, and not with other data types like you can with the intersection() method.
#
# The intersection_update() method will also keep ONLY the duplicates, but it will change the original set instead of returning a new set.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2)
print(set1)
# Out:
# {'apple'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

abc.intersection_update(cdn)

print(abc)
# Out:
# {0, 1, 'mnc'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

cdn.intersection_update(abc)

print(cdn)
# Out:
# {0, 1, 'mnc'}

# %% [markdown]
# The values True and 1 are considered the same value. The same goes for False and 0.
#
# Example
#
# Join sets that contains the values True, False, 1, and 0, and see what is considered as duplicates:

# %%
set1 = {"apple", 1, "banana", 0, "cherry"}
set2 = {False, "google", "microsoft", "apple", True}

set3 = set1.intersection(set2)
print(set3)
# Out:
# {False, True, 'apple'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

no = abc.intersection(cdn)

print(no)
# Out:
# {0, 1, 'mnc'}

# %% [markdown]
# Difference.
#
# The difference() method will return a new set that will contain only the items from the first set that are not present in the other set.
#
# Example
#
# Keep all items from set1 that are not in set2:

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2)

print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set2.difference(set1)

print(set3)
# Out:
# {'microsoft', 'google'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

no = abc.difference(cdn)

print(no)
# Out:
# {'12354', 'alam', 'alam ', 5451256, 'yaswanth'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

no = cdn.difference(abc)

print(no)
# Out:
# {'sshusfn', '5454154'}

# %% [markdown]
# You can use the - operator instead of the difference() method, and you will get the same result.
#
#
# Note: The - operator only allows you to join sets with sets, and not with other data types like you can with the difference() method.

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

no = abc - cdn

print(no)
# Out:
# {'12354', 'alam', 'alam ', 5451256, 'yaswanth'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

no = cdn - abc

print(no)
# Out:
# {'sshusfn', '5454154'}

# %% [markdown]
# The difference_update() method will also keep the items from the first set that are not in the other set, but it will change the original set instead of returning a new set.
#
#
# Example
#
# Use the difference_update() method to keep the items that are not present in both sets:

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

abc.difference_update(cdn)

print(abc)
# Out:
# {'12354', 'alam', 'alam ', 5451256, 'yaswanth'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

cdn.difference_update(abc)

print(abc)
# Out:
# {False, True, '12354', 'alam', 'mnc', 'alam ', 5451256, 'yaswanth'}

# %%
set1 = {"apple", "banana" , "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.difference_update(set2)
print(set1)
# Out:
# {'banana', 'cherry'}

# %%
set1 = {"apple", "banana" , "cherry"}
set2 = {"google", "microsoft", "apple"}

set2.difference_update(set1)
print(set2)
# Out:
# {'microsoft', 'google'}

# %% [markdown]
# Symmetric Differences
#
# The symmetric_difference() method will keep only the elements that are NOT present in both sets.
#
# Example
#
# Keep the items that are not present in both sets:

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

de = abc.symmetric_difference(cdn)

print(de)
# Out:
# {'12354', 'alam', 'sshusfn', 'alam ', 5451256, 'yaswanth', '5454154'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

de = cdn.symmetric_difference(abc)

print(de)
# Out:
# {'12354', 'alam', '5454154', 'alam ', 'sshusfn', 5451256, 'yaswanth'}

# %% [markdown]
# You can use the ^ operator instead of the symmetric_difference() method, and you will get the same result.
#
# Note: The ^ operator only allows you to join sets with sets, and not with other data types like you can with the symmetric_difference() method.
#
# The symmetric_difference_update() method will also keep all but the duplicates, but it will change the original set instead of returning a new set.
#
# Example
#
# Use the symmetric_difference_update() method to keep the items that are not present in both sets:

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

de = abc ^ cdn

print(de)
# Out:
# {'12354', 'alam', 'sshusfn', 'alam ', 5451256, 'yaswanth', '5454154'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

de = cdn ^ abc

print(de)
# Out:
# {'12354', 'alam', '5454154', 'alam ', 'sshusfn', 5451256, 'yaswanth'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

abc.symmetric_difference_update(cdn)

print(abc)
# Out:
# {'12354', 'alam', '5454154', 'alam ', 'sshusfn', 5451256, 'yaswanth'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True}

cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

cdn.symmetric_difference_update(abc)

print(cdn)
# Out:
# {'12354', 'alam', 'sshusfn', 'alam ', 5451256, 'yaswanth', '5454154'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.symmetric_difference_update(set2)

print(set1)
# Out:
# {'banana', 'google', 'cherry', 'microsoft'}

# %% [markdown]
# https://www.w3schools.com/python/python_frozenset.asp
#
# Python frozenset
#
# frozenset is an immutable version of a set.
#
# Like sets, it contains unique, unordered, unchangeable elements.
#
# Unlike sets, elements cannot be added or removed from a frozenset.
#
#
# Creating a frozenset
#
# Use the frozenset() constructor to create a frozenset from any iterable.

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'banana', 'apple', 'cherry'})
# <class 'frozenset'>

# %%
abc = frozenset({"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0 , True})

print(abc)
print(type(abc))
# Out:
# frozenset({False, True, '12354', 'alam', 'mnc', 'alam ', 5451256, 'yaswanth'})
# <class 'frozenset'>

# %%
cdn = {"5454154" , "sshusfn" , "mnc", 1 , 0}

print(cdn)
print(type(cdn))
# Out:
# {0, 1, 'sshusfn', 'mnc', '5454154'}
# <class 'set'>

# %%
cdn = frozenset({"5454154" , "sshusfn" , "mnc", 1 , 0})

print(cdn)
print(type(cdn))
# Out:
# frozenset({0, 1, 'sshusfn', 'mnc', '5454154'})
# <class 'frozenset'>

# %% [markdown]
# Frozenset Methods
#
# Being immutable means you cannot add or remove elements. However, frozensets support all non-mutating operations of sets.
#
# Method	Shortcut	Description
# copy()	 	Returns a shallow copy
# difference()	-	Returns a new frozenset with the difference
# intersection()	&	Returns a new frozenset with the intersection
# isdisjoint()	 	Returns whether two frozensets have an intersection
# issubset()	<= / <	Returns True if this frozenset is a (proper) subset of another
# issuperset()	>= / >	Returns True if this frozenset is a (proper) superset of another
# symmetric_difference()	^	Returns a new frozenset with the symmetric differences
# union()	|	Returns a new frozenset containing the union
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.w3schools.com/python/python_sets_methods.asp
#
# Set Methods
#
# Python has a set of built-in methods that you can use on sets.
#
# Method	Shortcut	Description
# add()	 	Adds an element to the set
# clear()	 	Removes all the elements from the set
# copy()	 	Returns a copy of the set
# difference()	-	Returns a set containing the difference between two or more sets
# difference_update()	-=	Removes the items in this set that are also included in another, specified set
# discard()	 	Remove the specified item
# intersection()	&	Returns a set, that is the intersection of two other sets
# intersection_update()	&=	Removes the items in this set that are not present in other, specified set(s)
# isdisjoint()	 	Returns whether two sets have a intersection or not
# issubset()	<=	Returns True if all items of this set is present in another set
#  	<	Returns True if all items of this set is present in another, larger set
# issuperset()	>=	Returns True if all items of another set is present in this set
#  	>	Returns True if all items of another, smaller set is present in this set
# pop()	 	Removes an element from the set
# remove()	 	Removes the specified element
# symmetric_difference()	^	Returns a set with the symmetric differences of two sets
# symmetric_difference_update()	^=	Inserts the symmetric differences from this set and another
# union()	|	Return a set containing the union of sets
# update()	|=	Update the set with the union of this set and others
#
#
#
# ![image.png](attachment:image.png)
