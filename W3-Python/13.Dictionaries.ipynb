# %% [markdown]
# https://www.w3schools.com/python/python_dictionaries.asp
#
#
# Python Dictionaries

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# Dictionary
#
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
#
# Dictionaries are written with curly brackets, and have keys and values:
#
# Example:
#
# Create and print a dictionary:

# %%
yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe"}

print(yas)
# Out:
# {'abc': 4478487478, 'cdn': 'boy', 54: 45, 'he': 'henighe'}

# %% [markdown]
# If we give same key values with duplicates then they will be ignored.  Multiple or duplicate key values will be taken only once

# %%
yas = {"abc":4478487478, "abc":"boy" , 54:45 , "he":"henighe"}

print(yas)
# Out:
# {'abc': 'boy', 54: 45, 'he': 'henighe'}

# %% [markdown]
# Duplicate values are allowed but duplicate keys are not allowed

# %%
yas = {"abc":4478487478 , 151: 45, 54:45 , "he":"henighe"}

print(yas)
# Out:
# {'abc': 4478487478, 151: 45, 54: 45, 'he': 'henighe'}

# %% [markdown]
# Dictionary Items
#
# Dictionary items are ordered, changeable, and do not allow duplicates.
#
# Dictionary items are presented in key:value pairs, and can be referred to by using the key name.
#
# Print the "brand" value of the dictionary:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict["brand"])
# Out:
# Ford

# %%
yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe"}

print(yas["abc"])
# Out:
# 4478487478

# %%
yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe"}

print(yas["cdn"])
# Out:
# boy

# %%
yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe"}

print(yas[54])
# Out:
# 45

# %% [markdown]
# 45 is the value. the [] is only fetching and looking at the key only.

# %%
yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe"}

print(yas[45])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe"}
# ----> 3 print(yas[45])
#
# KeyError: 45

# %% [markdown]
# Ordered or Unordered?
#
#
# When we say that dictionaries are ordered, it means that the items have a defined order, and that order will not change.
#
# Unordered means that the items do not have a defined order, you cannot refer to an item by using an index.
#
#
#
# Changeable
#
# Dictionaries are changeable, meaning that we can change, add or remove items after the dictionary has been created.
#
#
#
#
# Duplicates Not Allowed
#
# Dictionaries cannot have two items with the same key:

# %% [markdown]
# **
# Dictionaries cannot have two items with the same key **

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248}

mnc = {"abc" : 845248, "cmr" : "coyrope" , 54 : 5421626 , "jndjfs":"sjhdfjsn"}

print(yas)
# Out:
# {'abc': 845248, 'cdn': 'boy', 54: 45, 'he': 'henighe'}

# %% [markdown]
# Dictionary Length
#
# To determine how many items a dictionary has, use the len() function:
#
# Example
#
# Print the number of items in the dictionary:

# %%
yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248}

mnc = {"abc" : 845248, "cmr" : "coyrope" , 54 : 5421626 , "jndjfs":"sjhdfjsn"}

print(len(yas))
# Out:
# 4

# %%
yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248}

mnc = {"abc" : 845248, "cmr" : "coyrope" , 54 : 5421626 , "jndjfs":"sjhdfjsn"}

print(len(yas))
print(len(mnc))
print(type(yas))
print(type(mnc))
# Out:
# 4
# 4
# <class 'dict'>
# <class 'dict'>

# %% [markdown]
# Dictionary Items - Data Types
#
# The values in dictionary items can be of any data type:
#
# Example
#
#
# String, int, boolean, and list data types:

# %%
yas = {"abc":4478487478, "cdn":"boy" , 54:45 , "he":"henighe" , "abc" : 845248 , 65464854: "jshfuhsdf" , 484: 564151 , "abx" : ["shnfjs" , "sfdnsfj", 6545615 , 512052152] , "asjnvsj" : {"xbfv", 5462165 , 12558151, "shfjnsfjndfjn"}}


print(yas)
print(type(yas))
# Out:
# {'abc': 845248, 'cdn': 'boy', 54: 45, 'he': 'henighe', 65464854: 'jshfuhsdf', 484: 564151, 'abx': ['shnfjs', 'sfdnsfj', 6545615, 512052152], 'asjnvsj': {'shfjnsfjndfjn', 'xbfv', 5462165, 12558151}}
# <class 'dict'>

# %%
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

print(thisdict)

print(type(thisdict))
# Out:
# {'brand': 'Ford', 'electric': False, 'year': 1964, 'colors': ['red', 'white', 'blue']}
# <class 'dict'>

# %% [markdown]
# The dict() Constructor
#
# It is also possible to use the dict() constructor to make a dictionary.
#
# Example
#
# Using the dict() method to make a dictionary:

# %%
yas = dict(abc = "asdbhsb" , 4515 = 54502015215, ajhdfjnds= "zdnjksnkm")

print(yas)
# Out:
#   Cell In[29], line 1
#     yas = dict(abc = "asdbhsb" , 4515 == 54502015215, ajhdfjnds= "zdnjksnkm")
#                                                                             ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# If you want to use dict(), keys must be valid variable names

# %%
yas = dict(abc = "asdbhsb" , xfj = 54502015215, ajhdfjnds= "zdnjksnkm")

#mnc = {"abc" : 845248, "cmr" : "coyrope" , 54 : 5421626 , "jndjfs":"sjhdfjsn"}

print(yas)
# Out:
# {'abc': 'asdbhsb', 'xfj': 54502015215, 'ajhdfjnds': 'zdnjksnkm'}

# %%
thisdict = dict(name = "John", age = 36, country = "Norway")

print(thisdict)
# Out:
# {'name': 'John', 'age': 36, 'country': 'Norway'}

# %%
yas = {"sgbs" :"sfgjhuguje" , 545415145: "skfjdk" , 54515 : 5626265, "sfbhsbjsdf" :546512205415}

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54515: 5626265, 'sfbhsbjsdf': 546512205415}

# %% [markdown]
# Python Collections (Arrays)
#
# There are four collection data types in the Python programming language:
#
#
# List is a collection which is ordered and changeable. Allows duplicate members.
#
#
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
#
#
# Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
#
#
# Dictionary is a collection which is ordered** and changeable. No duplicate members.

# %% [markdown]
# https://www.w3schools.com/python/python_dictionaries_access.asp
#
#
# Python - Access Dictionary Items
#
#
# Accessing Items
#
# You can access the items of a dictionary by referring to its key name, inside square brackets:
#
#
# Example:
#
#
# Get the value of the "model" key:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = thisdict["model"]
print(x)
# Out:
# Mustang

# %%
yas = {"sgbs" :"sfgjhuguje" , 545415145: "skfjdk" , 54 : 5626265, "sfbhsbjsdf" :546512205415}

y = yas["sgbs"]
z = yas[54]
print(yas)
print(y)
print(z)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'sfbhsbjsdf': 546512205415}
# sfgjhuguje
# 5626265

# %% [markdown]
# There is also a method called get() that will give you the same result:
#
# Example
#
# Get the value of the "model" key:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = thisdict.get("model")
print(x)
# Out:
# Mustang

# %%
yas = {"sgbs" :"sfgjhuguje" , 545415145: "skfjdk" , 54 : 5626265, "sfbhsbjsdf" :546512205415}

y = yas.get(54)
z = yas.get("sgbs")
print(y)
print(z)
# Out:
# 5626265
# sfgjhuguje

# %% [markdown]
# Get Keys
#
# The keys() method will return a list of all the keys in the dictionary.
#
# Example
#
# Get a list of the keys:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = thisdict.keys()

print(x)
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
yas = {"sgbs" :"sfgjhuguje" , 545415145: "skfjdk" , 54 : 5626265, "sfbhsbjsdf" :546512205415}

y = yas.keys()
print(y)
# Out:
# dict_keys(['sgbs', 545415145, 54, 'sfbhsbjsdf'])

# %%
yas = {"sgbs" :"sfgjhuguje" , 545415145: "skfjdk" , 54 : 5626265, "sfbhsbjsdf" :546512205415}

y = yas.values()
print(y)
# Out:
# dict_values(['sfgjhuguje', 'skfjdk', 5626265, 546512205415])

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = thisdict.values()

print(x)
# Out:
# dict_values(['Ford', 'Mustang', 1964])

# %% [markdown]
# The list of the keys is a view of the dictionary, meaning that any changes done to the dictionary will be reflected in the keys list.
#
# Example
#
# Add a new item to the original dictionary, and see that the keys list gets updated as well:

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.keys()

print(x) #before the change

print(car)

car["color"] = "white"

print(x) #after the change

print(car)
# Out:
# dict_keys(['brand', 'model', 'year'])
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
# dict_keys(['brand', 'model', 'year', 'color'])
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'white'}

# %%
yas = {"sgbs" :"sfgjhuguje" , 545415145: "skfjdk" , 54 : 5626265, "sfbhsbjsdf" :546512205415}

yas["color"] = "White"

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'sfbhsbjsdf': 546512205415, 'color': 'White'}

# %%
yas = {"sgbs" :"sfgjhuguje" , 545415145: "skfjdk" , 54 : 5626265, "sfbhsbjsdf" :546512205415}

print(yas)

yas["color"] = "White"

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'sfbhsbjsdf': 546512205415}
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'sfbhsbjsdf': 546512205415, 'color': 'White'}

# %%
yas = {"sgbs" :"sfgjhuguje" , 545415145: "skfjdk" , 54 : 5626265, "sfbhsbjsdf" :546512205415}

yas["color"] = "White"

yas[545454] = 5454562646565465454564545454

yas["yaswanth"] = "test and network engineer"

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'sfbhsbjsdf': 546512205415, 'color': 'White', 545454: 5454562646565465454564545454, 'yaswanth': 'test and network engineer'}

# %% [markdown]
# Get Values
#
# The values() method will return a list of all the values in the dictionary.
#
# Example
#
# Get a list of the values:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = thisdict.values()

print(x)
# Out:
# dict_values(['Ford', 'Mustang', 1964])

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'sfbhsbjsdf': 546512205415, 'color': 'White', 545454: 5454562646565465454564545454, 'yaswanth': 'test and network engineer'}

y = yas.keys()
z= yas.values()
print(y)
print(z)
# Out:
# dict_keys(['sgbs', 545415145, 54, 'sfbhsbjsdf', 'color', 545454, 'yaswanth'])
# dict_values(['sfgjhuguje', 'skfjdk', 5626265, 546512205415, 'White', 5454562646565465454564545454, 'test and network engineer'])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.values()

print(x) #before the change

car["color"] = "red"

print(x) #after the change
# Out:
# dict_values(['Ford', 'Mustang', 1964])
# dict_values(['Ford', 'Mustang', 1964, 'red'])

# %% [markdown]
# Get Items
# The items() method will return each item in a dictionary, as tuples in a list.
#
# Example
# Get a list of the key:value pairs

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'sfbhsbjsdf': 546512205415, 'color': 'White', 545454: 5454562646565465454564545454, 'yaswanth': 'test and network engineer'}

y = yas.items()
#z= yas.values()
print(y)
# Out:
# dict_items([('sgbs', 'sfgjhuguje'), (545415145, 'skfjdk'), (54, 5626265), ('sfbhsbjsdf', 546512205415), ('color', 'White'), (545454, 5454562646565465454564545454), ('yaswanth', 'test and network engineer')])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.items()

print(x) #before the change

car["color"] = "red"

print(x) #after the change
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964), ('color', 'red')])

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

y = yas.items()
print(y)

yas["Hello"] = "Hi I am the best engioneer"

print(y)
# Out:
# dict_items([('sgbs', 'sfgjhuguje'), (545415145, 'skfjdk'), (54, 5626265), ('yaswanth', 'test and network engineer')])
# dict_items([('sgbs', 'sfgjhuguje'), (545415145, 'skfjdk'), (54, 5626265), ('yaswanth', 'test and network engineer'), ('Hello', 'Hi I am the best engioneer')])

# %% [markdown]
# Check if Key Exists
#
# To determine if a specified key is present in a dictionary use the in keyword:
#
# Example
#
# Check if "model" is present in the dictionary:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
if "model" in thisdict:
  print("Yes, 'model' is one of the keys in the thisdict dictionary")
# Out:
# Yes, 'model' is one of the keys in the thisdict dictionary

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

if 54 in yas:
    print("Yes, the number 54 present in yas")
# Out:
# Yes, the number 54 present in yas

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

if 'sgbs=' in yas:
    print("Yes, the number 54 present in yas")

else:
    print("The number was not present ")
# Out:
# The number was not present

# %% [markdown]
# Use the get method to print the value

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

print(yas.get('sgbs'))
# Out:
# sfgjhuguje

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

print(yas[54])
print(yas['sgbs'])
# Out:
# 5626265
# sfgjhuguje

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

print(yas['yaswanth'])
#print(yas['sgbs'])
# Out:
# test and network engineer

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

print(yas)

yas["yaswanth"] = "I am an network automation enginerr"

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'I am an network automation enginerr'}

# %% [markdown]
# https://www.w3schools.com/python/python_dictionaries_change.asp
#
#
# Python - Change Dictionary Items
#
# Change Values
#
# You can change the value of a specific item by referring to its key name:
#
# Example:
#
#
# Change the "year" to 2018:

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

yas['sgbs'] = 4565122302515162130541501524151

print(yas)
# Out:
# {'sgbs': 4565122302515162130541501524151, 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

# %% [markdown]
# Update Dictionary
#
# The update() method will update the dictionary with the items from the given argument.
#
# The argument must be a dictionary, or an iterable object with key:value pairs.
#
# Example
#
# Update the "year" of the car by using the update() method:

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

yas.update({54 : "I am the best"})

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 'I am the best', 'yaswanth': 'test and network engineer'}

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

print(yas)

yas.update({"test" : 4848484854})

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer', 'test': 'abc'}
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer', 'test': 4848484854}

# %% [markdown]
# https://www.w3schools.com/python/python_dictionaries_add.asp
#
#
# Python - Add Dictionary Items
#
# Adding Items
#
# Adding an item to the dictionary is done by using a new index key and assigning a value to it:
#
# Example

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}


yas["Mind"] = "gshfdbsfjsdnfj + 54512"

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer', 'test': 'abc', 'Mind': 'gshfdbsfjsdnfj + 54512'}

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["color"] = "red"
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %% [markdown]
# Update Dictionary
#
# The update() method will update the dictionary with the items from a given argument. If the item does not exist, the item will be added.
#
# The argument must be a dictionary, or an iterable object with key:value pairs.
#
# Example
#
# Add a color item to the dictionary by using the update() method:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"color": "red"})

print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

yas.update({"sfnsj" :"sgfbjdf"})

yas.update({"network" : "Intenet"})

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer', 'test': 'abc', 'sfnsj': 'sgfbjdf', 'network': 'Intenet'}

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

yas["hgbzhdfbs"] = 51521521

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer', 'test': 'abc', 'hgbzhdfbs': 51521521}

# %% [markdown]
# https://www.w3schools.com/python/python_dictionaries_remove.asp
#
# Python - Remove Dictionary Items
#
# Removing Items
#
# There are several methods to remove items from a dictionary:
#
#
# Ex:
#
# The pop() method removes the item with the specified key name:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

yas.pop("sgbs")

print(yas)
# Out:
# {545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer', 'test': 'abc'}

# %% [markdown]
# Example
#
# The popitem() method removes the last inserted item

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

yas.popitem()

#yas.popitem()

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer'}

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

yas.popitem()

yas.popitem()

print(yas)
# Out:
# {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265}

# %% [markdown]
# Example
#
# The del keyword removes the item with the specified key name:

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

yas.pop("sgbs")

print(yas)
# Out:
# {545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer', 'test': 'abc'}

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

del yas["sgbs"]

print(yas)
# Out:
# {545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer', 'test': 'abc'}

# %% [markdown]
# Example
#
# The del keyword can also delete the dictionary completely:

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

del yas

print(yas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 5
#       1 yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}
#       3 del yas
# ----> 5 print(yas)
#
# NameError: name 'yas' is not defined

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

del yas[]

print(yas)
# Out:
#   Cell In[106], line 3
#     del yas[]
#             ^
# SyntaxError: invalid syntax

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict
print(thisdict) #this will cause an error because "thisdict" no longer exists.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 7
#       1 thisdict =	{
#       2   "brand": "Ford",
#       3   "model": "Mustang",
#       4   "year": 1964
#       5 }
#       6 del thisdict
# ----> 7 print(thisdict) #this will cause an error because "thisdict" no longer exists.
#
# NameError: name 'thisdict' is not defined

# %% [markdown]
# Example
#
# The clear() method empties the dictionary.
#
# the clear will empty all the key value pairs but it wil not return any error.

# %%
yas = {'sgbs': 'sfgjhuguje', 545415145: 'skfjdk', 54: 5626265, 'yaswanth': 'test and network engineer' , "test" : "abc"}

yas.clear()

print(yas)
# Out:
# {}
