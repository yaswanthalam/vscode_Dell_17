# %% [markdown]
# https://www.w3schools.com/python/python_string_formatting.asp
#
#
# F-String was introduced in Python 3.6, and is now the preferred way of formatting strings.
#
# Before Python 3.6 we had to use the format() method.

# %% [markdown]
# Example:
#
# Create an f-string:

# %%
txt = f"The price is 49 dollars"
print(txt)
# Out:
# The price is 49 dollars

# %%
txt1 = "The price is 46 dollars"
print(txt1)
# Out:
# The price is 46 dollars

# %%
txt1 = f"The price is 46 dollars"
print(txt1)
# Out:
# The price is 46 dollars

# %% [markdown]
# Placeholders and Modifiers
#
# To format values in an f-string, add placeholders {}, a placeholder can contain variables, operations, functions, and modifiers to format the value.
#
# Example
#
# Add a placeholder for the price variable:

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
tmi = 6265251

uin = f"The value is {tmi} less than the value of "

print(uin)
# Out:
# The value is 6265251 less than the value of

# %% [markdown]
# A placeholder can also include a modifier to format the value.
#
# A modifier is included by adding a colon : followed by a legal formatting type, like .2f which means fixed point number with 2 decimals:
#
# Example
#
#
# Display the price with 2 decimals:

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
rin = 5415415

hon = f"The value of the nu,ber ois l.ess tjan {rin:.2f}  the test in the njmber is vakm"

print(hon)
# Out:
# The value of the nu,ber ois l.ess tjan 5415415.00  the test in the njmber is vakm

# %%
rin = 5415415

hon = f"The value of the nu,ber ois l.ess tjan {rin:.5f}  the test in the njmber is vakm"

print(hon)
# Out:
# The value of the nu,ber ois l.ess tjan 5415415.00000  the test in the njmber is vakm

# %%
rin = 5415415

hon = f"The value of the nu,ber ois l.ess tjan {rin:.15f}  the test in the njmber is vakm"

print(hon)
# Out:
# The value of the nu,ber ois l.ess tjan 5415415.000000000000000  the test in the njmber is vakm

# %% [markdown]
# You can also format a value directly without keeping it in a variable:
#
# Example
#
# Display the value 95 with 2 decimals:

# %%
txt = f"The price is {95:.2f} dollars"
print(txt)
# Out:
# The price is 95.00 dollars

# %% [markdown]
# Perform Operations in F-Strings
#
# You can perform Python operations inside the placeholders.
#
# You can do math operations:
#
# Example
#
#
# Perform a math operation in the placeholder, and return the result:

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %%
tin = f"The value is the number and the {85+922} using the number and the value"

print(tin)
# Out:
# The value is the number and the 1007 using the number and the value

# %%
win = 852

xin = f"The number is the value and the ink is the {win} network of the automatiom"

print(xin)
# Out:
# The number is the value and the ink is the 852 network of the automatiom

# %%
win = 852

xin = f"The number is the value and the ink is the {win+4515} network of the automatiom"

print(xin)
# Out:
# The number is the value and the ink is the 5367 network of the automatiom

# %%
win = 852

xin = f"The number is the value and the ink is the {win:.2f} network of the automatiom"

print(xin)
# Out:
# The number is the value and the ink is the 852.00 network of the automatiom

# %%
win = 852

xin = f"The number is the value and the ink is the {win:.12f} network of the automatiom"

print(xin)
# Out:
# The number is the value and the ink is the 852.000000000000 network of the automatiom

# %%
win = 852
xin = f"The number is the value and the ink is the {win+6526656} network of the automatiom"

print(xin)
# Out:
# The number is the value and the ink is the 6527508 network of the automatiom

# %%
win = 852
xin = f"The number is the value and the ink is the {win*52} network of the automatiom"

print(xin)
# Out:
# The number is the value and the ink is the 44304 network of the automatiom

# %%
win = 852
xin = f"The number is the value and the ink is the {win-52} network of the automatiom"

print(xin)
# Out:
# The number is the value and the ink is the 800 network of the automatiom

# %% [markdown]
# You can perform math operations on variables:
#
# Example
#
#
# Add taxes before displaying the price:

# %%
price = 59
tax = 0.25
txt = f"The price is {price + (price * tax)} dollars"
print(txt)
# Out:
# The price is 73.75 dollars

# %%
eio = 54
kui = 8962

fuio = f"The value of the numbers are {eio+kui} how are you"
print(fuio)
# Out:
# The value of the numbers are 9016 how are you

# %%
eio = 54
kui = 8962

fuio = f"The value of the numbers are {eio*(eio+kui)} how are you"
print(fuio)
# Out:
# The value of the numbers are 486864 how are you

# %% [markdown]
# You can perform if...else statements inside the placeholders:
#
# Example
#
#
# Return "Expensive" if the price is over 50, otherwise return "Cheap":

# %%
price = 49
txt = f"It is very {'Expensive' if price>50 else 'Cheap'}"

print(txt)
# Out:
# It is very Cheap

# %% [markdown]
# Execute Functions in F-Strings
#
# You can execute functions inside the placeholder:
#
# Example
#
# Use the string method upper()to convert a value into upper case letters:

# %%
fruit = "apples"
txt = f"I love {fruit.upper()}"
print(txt)
# Out:
# I love APPLES

# %%
din = "yaswanth"

sin = f"I am an network enginner {din.upper()}"

print(sin)
# Out:
# I am an network enginner YASWANTH

# %% [markdown]
# The function does not have to be a built-in Python method, you can create your own functions and use them:
#
# Example
#
# Create a function that converts feet into meters:

# %%
def myconverter(x):
  return x * 0.3048

txt = f"The plane is flying at a {myconverter(30000)} meter altitude"
print(txt)
# Out:
# The plane is flying at a 9144.0 meter altitude

# %% [markdown]
# More Modifiers
#
# At the beginning of this chapter we explained how to use the .2f modifier to format a number into a fixed point number with 2 decimals.
#
# There are several other modifiers that can be used to format values:
#
# Example
#
# Use a comma as a thousand separator:

# %%
price = 59000
txt = f"The price is {price:,} dollars"
print(txt)
# Out:
# The price is 59,000 dollars

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
