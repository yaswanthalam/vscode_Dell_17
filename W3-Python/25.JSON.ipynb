# %% [markdown]
# https://www.w3schools.com/python/python_json.asp
#
#
# Python JSON
#
#
# JSON is a syntax for storing and exchanging data.
#
# JSON is text, written with JavaScript object notation.
#
# JSON in Python
#
# Python has a built-in package called json, which can be used to work with JSON data.

# %% [markdown]
# Parse JSON - Convert from JSON to Python
#
# If you have a JSON string, you can parse it by using the json.loads() method.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Example
#
#
# Convert from JSON to Python:

# %%
import json

# some JSON:
x = '{ "name":"John", "age":30, "city":"New York"}'

# parse x:
y = json.loads(x)

# the result is a Python dictionary:
print(y["age"])
# Out:
# 30

# %%
import json

y = '{"yaswanth":"alam", "age":"5151", "city":"Chittoor"}'

s = json.loads(y)

print(s["yaswanth"])
# Out:
# alam

# %%
import json

y = '{"yaswanth":"alam", "age":"5151", "city":"Chittoor"}'

s = json.loads(y)

print(s["age"])
# Out:
# 5151

# %%
import json

z = '{"yaswanth":"alam", "age":"5151", "city":"Chittoor+kotha"}'

sne = json.loads(z)

print(sne["city"])
# Out:
# Chittoor+kotha

# %% [markdown]
# Convert from Python to JSON
#
# If you have a Python object, you can convert it into a JSON string by using the json.dumps() method.
#
# Example
#
# Convert from Python to JSON:

# %%
import json

# a Python object (dict):
x = {
  "name": "John",
  "age": 30,
  "city": "New York"
}

# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "city": "New York"}

# %%
import json

z = {"yaswanth":"alam", "age":"5151", "city":"Chittoor+kotha"}

sne = json.dumps(z)

print(sne)
# Out:
# {"yaswanth": "alam", "age": "5151", "city": "Chittoor+kotha"}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Example
#
#
# Convert Python objects into JSON strings, and print the values:

# %%
import json

print(json.dumps({"name": "John", "age": 30}))
print(json.dumps(["apple", "bananas"]))
print(json.dumps(("apple", "bananas")))
print(json.dumps("hello"))
print(json.dumps(42))
print(json.dumps(31.76))
print(json.dumps(True))
print(json.dumps(False))
print(json.dumps(None))
# Out:
# {"name": "John", "age": 30}
# ["apple", "bananas"]
# ["apple", "bananas"]
# "hello"
# 42
# 31.76
# true
# false
# null

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Example
#
#
# Convert a Python object containing all the legal data types:

# %%
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "married": true, "divorced": false, "children": ["Ann", "Billy"], "pets": null, "cars": [{"model": "BMW 230", "mpg": 27.5}, {"model": "Ford Edge", "mpg": 24.1}]}

# %%
import json 

yiwer = {
    "yaswanth" : "alam",
    "age" : 56526526,
    "married":True,
    "divorced":False,
    "Children":("Ann","Benste"),
    "pets":None,
    "cars":[
        {"yaswanth":"alam", "age":"5151", "city":"Chittoor+kotha"}
    ]
}

yi = json.dumps(yiwer)
print(yi)
# Out:
# {"yaswanth": "alam", "age": 56526526, "married": true, "divorced": false, "Children": ["Ann", "Benste"], "pets": null, "cars": [{"yaswanth": "alam", "age": "5151", "city": "Chittoor+kotha"}]}

# %% [markdown]
# Format the Result
#
# The example above prints a JSON string, but it is not very easy to read, with no indentations and line breaks.
#
# The json.dumps() method has parameters to make it easier to read the result:
#
# Example
#
# Use the indent parameter to define the numbers of indents:

# %%
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

# use four indents to make it easier to read the result:
print(json.dumps(x, indent=4))
# Out:
# {
#     "name": "John",
#     "age": 30,
#     "married": true,
#     "divorced": false,
#     "children": [
#         "Ann",
#         "Billy"
#     ],
#     "pets": null,
#     "cars": [
#         {
#             "model": "BMW 230",
#             "mpg": 27.5
#         },
#         {
#             "model": "Ford Edge",
#             "mpg": 24.1
#         }
#     ]
# }

# %%
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

# use four indents to make it easier to read the result:
print(json.dumps(x, indent=10))
# Out:
# {
#           "name": "John",
#           "age": 30,
#           "married": true,
#           "divorced": false,
#           "children": [
#                     "Ann",
#                     "Billy"
#           ],
#           "pets": null,
#           "cars": [
#                     {
#                               "model": "BMW 230",
#                               "mpg": 27.5
#                     },
#                     {
#                               "model": "Ford Edge",
#                               "mpg": 24.1
#                     }
#           ]
# }

# %%
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

# use four indents to make it easier to read the result:
print(json.dumps(x, indent=5))
# Out:
# {
#      "name": "John",
#      "age": 30,
#      "married": true,
#      "divorced": false,
#      "children": [
#           "Ann",
#           "Billy"
#      ],
#      "pets": null,
#      "cars": [
#           {
#                "model": "BMW 230",
#                "mpg": 27.5
#           },
#           {
#                "model": "Ford Edge",
#                "mpg": 24.1
#           }
#      ]
# }

# %% [markdown]
# You can also define the separators, default value is (", ", ": "), which means using a comma and a space to separate each object, and a colon and a space to separate keys from values:
#
# Example
#
# Use the separators parameter to change the default separator:

# %%
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

# use . and a space to separate objects, and a space, a = and a space to separate keys from their values:
print(json.dumps(x, indent=4, separators=(". ", " = ")))
# Out:
# {
#     "name" = "John".
#     "age" = 30.
#     "married" = true.
#     "divorced" = false.
#     "children" = [
#         "Ann".
#         "Billy"
#     ].
#     "pets" = null.
#     "cars" = [
#         {
#             "model" = "BMW 230".
#             "mpg" = 27.5
#         }.
#         {
#             "model" = "Ford Edge".
#             "mpg" = 24.1
#         }
#     ]
# }

# %% [markdown]
# Order the Result
#
# The json.dumps() method has parameters to order the keys in the result:
#
# Example
#
# Use the sort_keys parameter to specify if the result should be sorted or not:

# %%
import json

x = {
  "name": "John",
  "age": 30,
  "married": True,
  "divorced": False,
  "children": ("Ann","Billy"),
  "pets": None,
  "cars": [
    {"model": "BMW 230", "mpg": 27.5},
    {"model": "Ford Edge", "mpg": 24.1}
  ]
}

# sort the result alphabetically by keys:
print(json.dumps(x, indent=4, sort_keys=True))
# Out:
# {
#     "age": 30,
#     "cars": [
#         {
#             "model": "BMW 230",
#             "mpg": 27.5
#         },
#         {
#             "model": "Ford Edge",
#             "mpg": 24.1
#         }
#     ],
#     "children": [
#         "Ann",
#         "Billy"
#     ],
#     "divorced": false,
#     "married": true,
#     "name": "John",
#     "pets": null
# }
