# %% [markdown]
# https://www.w3schools.com/python/python_inheritance.asp
#
#
# ![image.png](attachment:image.png)

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

#Use the Person class to create an object, and then execute the printname method:

x = Person("John", "Doe")
x.printname()
# Out:
# John Doe

# %%
class cisco:
    def __init__(self, chasis, cable):
        self.chasis = chasis
        self.cable = cable 
    def juniper(self):
        print(self.chasis, self.cable)

int = cisco("macsec", "LLDP")
int.juniper()
# Out:
# macsec LLDP

# %%
class arista:
    def __init__(self, lacp, lldp):
        self.lacp = lacp 
        self.lldp = lldp 

    def ocs(self):
        print(self.lacp , self.lldp)

bgp = arista("isis", "level-1")
bgp.ocs()
# Out:
# isis level-1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  pass

x = Student("Mike", "Olsen")
x.printname()
# Out:
# Mike Olsen

# %%
class arista:
    def __init__(self, lacp, lldp):
        self.lacp = lacp 
        self.lldp = lldp 

    def ocs(self):
        print(self.lacp , self.lldp)

class macsec(arista):
    pass

bgp = macsec("isis", "level-1")
bgp.ocs()
# Out:
# isis level-1

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# To keep the inheritance of the parent's __init__() function, add a call to the parent's __init__() function:

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, fname, lname):
    Person.__init__(self, fname, lname)

x = Student("Mike", "Olsen")
x.printname()
# Out:
# Mike Olsen

# %%
class arista:
    def __init__(self, lacp, lldp):
        self.lacp = lacp 
        self.lldp = lldp 

    def ocs(self):
        print(self.lacp , self.lldp)

class macsec(arista):
    def __init__(self, port, channel):
        arista.__init__(self, port, channel)

bgp = macsec("isis", "level-1")
bgp.ocs()
# Out:
# isis level-1

# %% [markdown]
# arista.__init__(self, por, channel) -- chnaged the name of port to por and observed the behaviour

# %%
class arista:
    def __init__(self, lacp, lldp):
        self.lacp = lacp 
        self.lldp = lldp 

    def ocs(self):
        print(self.lacp , self.lldp)

class macsec(arista):
    def __init__(self, port, channel):
        arista.__init__(self, por, channel)

bgp = macsec("isis", "level-1")
bgp.ocs()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 13
#      10     def __init__(self, port, channel):
#      11         arista.__init__(self, por, channel)
# ---> 13 bgp = macsec("isis", "level-1")
#      14 bgp.ocs()
#
# Cell In[9], line 11, in macsec.__init__(self, port, channel)
#      10 def __init__(self, port, channel):
# ---> 11     arista.__init__(self, por, channel)
#
# NameError: name 'por' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)

x = Student("Mike", "Olsen")
x.printname()
# Out:
# Mike Olsen

# %%
class arista:
    def __init__(self, lacp, lldp):
        self.lacp = lacp 
        self.lldp = lldp 

    def ocs(self):
        print(self.lacp , self.lldp)

class macsec(arista):
    def __init__(self, port, channel):
        super().__init__(port, channel)

bgp = macsec("isis", "level-1")
bgp.ocs()
# Out:
# isis level-1

# %%
class network:
    def __init__(self, auto , car):
        self.auto = auto 
        self.car = car

    def magic(self):
        print(self.auto , self.car)


class traffic(network):
    def __init__(self, xia , chasis):
        super().__init__(xia, chasis)

rack = traffic("lacp, bundle ether , port- channel " , "lldp neighbors")
rack.magic()
# Out:
# lacp, bundle ether , port- channel  lldp neighbors

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class network:
    def __init__(self, auto , car):
        self.auto = auto 
        self.car = car

    def magic(self):
        print(self.auto , self.car)

rack = network("lacp, bundle ether , port- channel " , "lldp neighbors")
rack.magic()
# Out:
# lacp, bundle ether , port- channel  lldp neighbors

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, fname, lname):
    super().__init__(fname, lname)
    self.graduationyear = 2019

x = Student("Mike", "Olsen")
print(x.graduationyear)
# Out:
# 2019

# %%
class network:
    def __init__(self, auto , car):
        self.auto = auto 
        self.car = car

    def magic(self):
        print(self.auto , self.car)


class traffic(network):
    def __init__(self, xia , chasis):
        super().__init__(xia, chasis)
        self.ports = 10

rack = traffic("lacp, bundle ether , port- channel " , "lldp neighbors")
print(rack.ports)
# Out:
# 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, fname, lname, year):
    super().__init__(fname, lname)
    self.graduationyear = year

x = Student("Mike", "Olsen", 2019)
print(x.graduationyear)
# Out:
# 2019

# %%
class network:
    def __init__(self, auto , car):
        self.auto = auto 
        self.car = car

    def magic(self):
        print(self.auto , self.car)


class traffic(network):
    def __init__(self, xia , chasis , port):
        super().__init__(xia, chasis)
        self.ports = port

rack = traffic("lacp, bundle ether , port- channel " , "lldp neighbors" , 955565)
print(rack.ports)
# Out:
# 955565

# %%
class exp:
    def __init__(self, gateway, circuit):
        self.gateway = gateway
        self.circuit = circuit 

    def msee(self):
        print(self.gateway , self.circuit)

class connection(exp):
    def __init__(self, primary, secondary):
        super().__init__(primary, secondary)
        self.bgp = 12076

ce = connection("PE router is the provide edge", "CE is the customer edge")
print(ce.bgp)
# Out:
# 12076

# %%
class exp:
    def __init__(self, gateway, circuit):
        self.gateway = gateway
        self.circuit = circuit 

    def msee(self):
        print(self.gateway , self.circuit)

class connection(exp):
    def __init__(self, primary, secondary, asn):
        super().__init__(primary, secondary)
        self.bgp = asn

ce = connection("PE router is the provide edge", "CE is the customer edge" , 12076)
print(ce.bgp)
# Out:
# 12076

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, fname, lname, year):
    super().__init__(fname, lname)
    self.graduationyear = year

  def welcome(self):
    print("Welcome", self.firstname, self.lastname, "to the class of", self.graduationyear)

x = Student("Mike", "Olsen", 2024)
x.welcome()
# Out:
# Welcome Mike Olsen to the class of 2024

# %%
class exp:
    def __init__(self, gateway, circuit):
        self.gateway = gateway
        self.circuit = circuit 

    def msee(self):
        print(self.gateway , self.circuit)

class connection(exp):
    def __init__(self, primary, secondary, asn):
        super().__init__(primary, secondary)
        self.bgp = asn
    
    def serviceprovider(self):
        print("comcast", self.gateway, self.circuit, "is the service provider for", self.bgp)

ce = connection("PE router is the provide edge", "CE is the customer edge" , 12076)
ce.serviceprovider()
# Out:
# comcast PE router is the provide edge CE is the customer edge is the service provider for 12076

# %%
def serviceprovider(self):
        print("comcast", self.gateway, self.circuit, "is the service provider for", self.bgp)

# %%
def serviceprovider(self):
# Out:
#   Cell In[16], line 1
#     def serviceprovider(self):
#                               ^
# _IncompleteInputError: incomplete input

# %%
def serviceprovider(self):
    pass
