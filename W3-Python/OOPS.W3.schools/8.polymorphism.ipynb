# %% [markdown]
# https://www.w3schools.com/python/python_polymorphism.asp
#
#
# ![image.png](attachment:image.png)

# %%
x = "Hello World!"

print(len(x))
# Out:
# 12

# %%
alam = "yaswanth"

print(len(alam))
# Out:
# 8

# %%
alam = "yaswa  nth"

print(len(alam))
# Out:
# 10

# %% [markdown]
# Spaces are also considered as an character in  the string

# %%
sai = "yaswanth alam"
print(len(sai))
# Out:
# 13

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mytuple = ("apple", "banana", "cherry")

print(len(mytuple))
# Out:
# 3

# %%
load_balancer = ("vip", "DIP", "healthprobes")

print(len(load_balancer))
# Out:
# 3

# %%
load_balancer = ["vip", "DIP", "healthprobes"]

print(len(load_balancer))
# Out:
# 3

# %%
load_balancer = {"vip", "DIP", "healthprobes"}

print(len(load_balancer))
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
loadbalancer = {
    "external" : "Public",
    "Internal" : "Private",
    "health_probes" : "168.63.129.16"
}

print(len(loadbalancer))
# Out:
# 3

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(len(thisdict))
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Drive!")

class Boat:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Sail!")

class Plane:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747")     #Create a Plane object

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Drive!
# Sail!
# Fly!

# %%
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Drive!")
    print(self.brand)

class Boat:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Sail!", self.brand)

class Plane:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747")     #Create a Plane object

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Drive!
# Ford
# Sail! Ibiza
# Fly!

# %%
class firewall:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("Higher price, more features such as tunneling and packet captures and tls, dns features")

class nva:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("NVA is an third party software solution that was provided microsoft to host those softwares in the azure VM's with the underlying build of linux or ubunut as OS")


class sdwan:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("THis is similar to VWAN and was hosted in the NVA's as well in the azure VWAN environmnet. ")


hash = firewall("load balacning", "load distribution") 
ipbased = nva("multipe_frontends", "multipe back ends" )
portbased = sdwan("Hostred in vwan", "Hosted in nva")

for i in (hash, ipbased, portbased):
    print(i)

# %%
class firewall:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("Higher price, more features such as tunneling and packet captures and tls, dns features")

class nva:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("NVA is an third party software solution that was provided microsoft to host those softwares in the azure VM's with the underlying build of linux or ubunut as OS")


class sdwan:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("THis is similar to VWAN and was hosted in the NVA's as well in the azure VWAN environmnet. ")


hash = firewall("load balacning", "load distribution") 
ipbased = nva("multipe_frontends", "multipe back ends" )
portbased = sdwan("Hostred in vwan", "Hosted in nva")

for i in (hash, ipbased, portbased):
    i.premium()
# Out:
# Higher price, more features such as tunneling and packet captures and tls, dns features
# NVA is an third party software solution that was provided microsoft to host those softwares in the azure VM's with the underlying build of linux or ubunut as OS
# THis is similar to VWAN and was hosted in the NVA's as well in the azure VWAN environmnet.

# %%
class firewall:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("Higher price, more features such as tunneling and packet captures and tls, dns features")

class nva:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("NVA is an third party software solution that was provided microsoft to host those softwares in the azure VM's with the underlying build of linux or ubunut as OS")


class sdwan:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("THis is similar to VWAN and was hosted in the NVA's as well in the azure VWAN environmnet. ")


hash = firewall("load balacning", "load distribution") 
ipbased = nva("multipe_frontends", "multipe back ends" )
portbased = sdwan("Hostred in vwan", "Hosted in nva")

for i in (hash, ipbased, portbased):
    i.premium()
    print(i)
# Out:
# Higher price, more features such as tunneling and packet captures and tls, dns features
# ...
# NVA is an third party software solution that was provided microsoft to host those softwares in the azure VM's with the underlying build of linux or ubunut as OS
# ...
# THis is similar to VWAN and was hosted in the NVA's as well in the azure VWAN environmnet.
# ...

# %%
class firewall:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("Higher price, more features such as tunneling and packet captures and tls, dns features")

class nva:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("NVA is an third party software solution that was provided microsoft to host those softwares in the azure VM's with the underlying build of linux or ubunut as OS")


class sdwan:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("THis is similar to VWAN and was hosted in the NVA's as well in the azure VWAN environmnet. ")
        print(self.manager , self.scaling)


hash = firewall("load balacning", "load distribution") 
ipbased = nva("multipe_frontends", "multipe back ends" )
portbased = sdwan("Hostred in vwan", "Hosted in nva")

for i in (hash, ipbased, portbased):
    i.premium()
# Out:
# Higher price, more features such as tunneling and packet captures and tls, dns features
# NVA is an third party software solution that was provided microsoft to host those softwares in the azure VM's with the underlying build of linux or ubunut as OS
# THis is similar to VWAN and was hosted in the NVA's as well in the azure VWAN environmnet.
# Hostred in vwan Hosted in nva

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Vehicle:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Move!")

class Car(Vehicle):
  pass

class Boat(Vehicle):
  def move(self):
    print("Sail!")

class Plane(Vehicle):
  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang") #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747") #Create a Plane object

for x in (car1, boat1, plane1):
  print(x.brand)
  print(x.model)
  x.move()
# Out:
# Ford
# Mustang
# Move!
# Ibiza
# Touring 20
# Sail!
# Boeing
# 747
# Fly!

# %%
class firewall:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("Higher price, more features such as tunneling and packet captures and tls, dns features")

class nva:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("NVA is an third party software solution that was provided microsoft to host those softwares in the azure VM's with the underlying build of linux or ubunut as OS")


class sdwan:
    def __init__(self, manager, scaling):
        self.manager = manager 
        self.scaling = scaling

    def premium(self):
        print("THis is similar to VWAN and was hosted in the NVA's as well in the azure VWAN environmnet. ")
        print(self.manager , self.scaling)


hash = firewall("load balacning", "load distribution") 
ipbased = nva("multipe_frontends", "multipe back ends" )
portbased = sdwan("Hostred in vwan", "Hosted in nva")

for i in (hash, ipbased, portbased):
    print(i.manager)
    print(i.scaling)
    i.premium()
# Out:
# load balacning
# load distribution
# Higher price, more features such as tunneling and packet captures and tls, dns features
# multipe_frontends
# multipe back ends
# NVA is an third party software solution that was provided microsoft to host those softwares in the azure VM's with the underlying build of linux or ubunut as OS
# Hostred in vwan
# Hosted in nva
# THis is similar to VWAN and was hosted in the NVA's as well in the azure VWAN environmnet.
# Hostred in vwan Hosted in nva

# %% [markdown]
# ![image.png](attachment:image.png)
