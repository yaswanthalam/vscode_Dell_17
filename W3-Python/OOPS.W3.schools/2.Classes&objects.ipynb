# %% [markdown]
# https://www.w3schools.com/python/python_classes.asp
#
#
# ![image.png](attachment:image.png)

# %%
class Myclass:
    x =5

print(Myclass)
# Out:
# <class '__main__.Myclass'>

# %%
class yaswanth:
    x=545
print(yaswanth)
# Out:
# <class '__main__.yaswanth'>

# %%
class alam:
    x=545
print(alam)
# Out:
# <class '__main__.alam'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class MyClass:
  x = 5

p1 = MyClass()
print(p1.x)
# Out:
# 5

# %%
class yaswanth:
    f = 5152
max = yaswanth()
print(max.f)
# Out:
# 5152

# %%
class yaswanth:
    f = 5152   # class variable

max = yaswanth()   # create an object of the class
print(max.f)       # accessing the class variable through the object
# Out:
# 5152

# %% [markdown]
# If you want each object to have its own value, use __init__:

# %%
class yaswanth:
    def __init__(self, value):
        self.f = value

max = yaswanth(5152)
print(max.f)
# Out:
# 5152

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfunc(self):
    print("Hello my name is " + self.name)

p1 = Person("John", 36)

del p1

print(p1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 13
#       9 p1 = Person("John", 36)
#      11 del p1
# ---> 13 print(p1)
#
# NameError: name 'p1' is not defined

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfunc(self):
    print("Hello my name is " + self.name)

p1 = Person("John", 36)

print(p1)
# Out:
# <__main__.Person object at 0x0000024B36185E80>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class MyClass:
  x = 5

p1 = MyClass()
p2 = MyClass()
p3 = MyClass()

print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# 5
# 5
# 5

# %%
class yaswanth:
    f = 8522

p4 = yaswanth()
p5 = yaswanth()
p6 = yaswanth()

print(p4.f)
print(p5.f)
print(p6.f)
# Out:
# 8522
# 8522
# 8522

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:
  pass

# having an empty class definition like this, would raise an error without the pass statement
