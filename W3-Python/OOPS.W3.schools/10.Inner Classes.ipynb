# %% [markdown]
# https://www.w3schools.com/python/python_class_inner.asp
#
#
# ![image.png](attachment:image.png)

# %%
class Outer:
  def __init__(self):
    self.name = "Outer Class"

  class Inner:
    def __init__(self):
      self.name = "Inner Class"

    def display(self):
      print("This is the inner class")

outer = Outer()
print(outer.name)
# Out:
# Outer Class

# %%
class Arista:
    def __init__(self):
        self.arista = "Main usedf for date center devices in T0, T1, T2 places"

    class Juniper:
        def __init__(self):
            self.arista = "The devices are flexible and can handle AI workloads"
            
        def cisco(self):
            print("They are first established devices and very famous and widely used devices")


network = Arista()
print(network.arista)
# Out:
# Main usedf for date center devices in T0, T1, T2 places

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Outer:
  def __init__(self):
    self.name = "Outer"

  class Inner:
    def __init__(self):
      self.name = "Inner"

    def display(self):
      print("Hello from inner class")

outer = Outer()
inner = outer.Inner()
inner.display()
# Out:
# Hello from inner class

# %%
class Arista:
    def __init__(self):
        self.arista = "Main usedf for date center devices in T0, T1, T2 places"

    class Juniper:
        def __init__(self):
            self.arista = "The devices are flexible and can handle AI workloads"
            
        def cisco(self):
            print("They are first established devices and very famous and widely used devices")


network = Arista()
devices = network.Juniper()
devices.cisco()
# Out:
# They are first established devices and very famous and widely used devices

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Outer:
  def __init__(self):
    self.name = "Emil"

  class Inner:
    def __init__(self, outer):
      self.outer = outer

    def display(self):
      print(f"Outer class name: {self.outer.name}")

outer = Outer()
inner = outer.Inner(outer)
inner.display()
# Out:
# Outer class name: Emil

# %%
class Arista:
    def __init__(self):
        self.arista = "Main usedf for date center devices in T0, T1, T2 places"

    class Juniper:
        def __init__(self, ptx100):
            self.ptx100 = ptx100
        def cisco(self):
            print(f"They are first established devices and very famous and widely used devices")

lldp = Arista()
macsec = lldp.Juniper(lldp)
macsec.cisco()
# Out:
# They are first established devices and very famous and widely used devices

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model
    self.engine = self.Engine()

  class Engine:
    def __init__(self):
      self.status = "Off"

    def start(self):
      self.status = "Running"
      print("Engine started")

    def stop(self):
      self.status = "Off"
      print("Engine stopped")

  def drive(self):
    if self.engine.status == "Running":
      print(f"Driving the {self.brand} {self.model}")
    else:
      print("Start the engine first!")

car = Car("Toyota", "Corolla")
car.drive()
car.engine.start()
car.drive()
# Out:
# Start the engine first!
# Engine started
# Driving the Toyota Corolla

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Computer:
  def __init__(self):
    self.cpu = self.CPU()
    self.ram = self.RAM()

  class CPU:
    def process(self):
      print("Processing data...")

  class RAM:
    def store(self):
      print("Storing data...")

computer = Computer()
computer.cpu.process()
computer.ram.store()
# Out:
# Processing data...
# Storing data...
