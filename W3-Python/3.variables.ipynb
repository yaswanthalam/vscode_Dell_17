# %% [markdown]
# https://www.w3schools.com/python/python_variables.asp

# %%
x=5
y="yaswanth"
print(x)
print(y)
# Out:
# 5
# yaswanth

# %%
x="hiu"
x="hello"

print(x)
# Out:
# hello

# %%
x="sbdfhs"
x=5454
x='shjsfgs'
print(x)
# Out:
# shjsfgs

# %%
x="sbdfhs"
x=5454

print(x)
# Out:
# 5454

# %%
x=str(3)
y=int(545145.456526)
z=float(5)
print(x,y,z)
# Out:
# 3 545145 5.0

# %%
x=str(3)
y=int(545145.456526)
z=float(5)
print(x)
print(y)
print(z)
# Out:
# 3
# 545145
# 5.0

# %%
x=5
y=56265.565262
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
x=6+8j
print(type(x))
# Out:
# <class 'complex'>

# %%
x="jo"
print(x)

y='sfjhsdjf'
print(y)
# Out:
# jo
# sfjhsdjf

# %%
a=4
A=5
print(a)
print(A)
# Out:
# 4
# 5

# %% [markdown]
# https://www.w3schools.com/python/python_variables_names.asp
#
#
#
# Variable Names
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume).
#
# Rules for Python variables:
#
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (age, Age and AGE are three different variables)
# A variable name cannot be any of the Python keywords.

# %%
var=54
v_r=5415
_var=5451
myVar=4551
MYVAR=545
myvar2=55

print(var, v_r, _var, myVar, MYVAR, myvar2)
# Out:
# 54 5415 5451 4551 545 55

# %%
2myvar = "John"
my-var = "John"
my var = "John"
# Out:
#   Cell In[13], line 1
#     2myvar = "John"
#     ^
# SyntaxError: invalid decimal literal

# %%
myVariableName ="Yaswanth"
print(myVariableName)
# Out:
# Yaswanth

# %% [markdown]
# https://www.w3schools.com/python/python_variables_multiple.asp

# %%
x=y=z=5515,8445,564
print(x)
print(y)
print(z)
# Out:
# (5515, 8445, 564)
# (5515, 8445, 564)
# (5515, 8445, 564)

# %%
x,y,z=5515,8445,564
print(x)
print(y)
print(z)
# Out:
# 5515
# 8445
# 564

# %%
x=y=z='Yaswanth'
print(x,y,z)
# Out:
# Yaswanth Yaswanth Yaswanth

# %%
x=y=z='Yaswanth'
print(x)
print(y)
print(z)
# Out:
# Yaswanth
# Yaswanth
# Yaswanth

# %%
x=["Hi","Hello","Test"]

y,z,u=x

print(y)
print(z)
print(u)
# Out:
# Hi
# Hello
# Test

# %% [markdown]
# Tuple
#
# Tuple is mutable.

# %%
x=["Hi","Hello","Test"]

y,z,u=x

print(y)
print(z)
print(u)
print(x)
# Out:
# Hi
# Hello
# Test
# ['Hi', 'Hello', 'Test']

# %% [markdown]
# List
#
# List are immutable

# %%
x=("Hi","Hello","Test")

y,z,u=x

print(y)
print(z)
print(u)
print(x)
# Out:
# Hi
# Hello
# Test
# ('Hi', 'Hello', 'Test')

# %% [markdown]
# Set is an un-ordered defined collection and it will print values in un-ordered fashin which is faster

# %%
x={"Hi","Hello","Test"}

y,z,u=x

print(y)
print(z)
print(u)
print(x)
# Out:
# Hello
# Test
# Hi
# {'Hello', 'Test', 'Hi'}

# %% [markdown]
# https://www.w3schools.com/python/python_variables_output.asp

# %%
x="Python is awesome"
print(x)
# Out:
# Python is awesome

# %%
x="hsbg"
y="shdfbg"
z="sjbfjs"
print(x,y,z)
# Out:
# hsbg shdfbg sjbfjs

# %%
x="hsbg "
y="shdfbg "
z="sjbfjs "
print(x+y+z)
# Out:
# hsbg shdfbg sjbfjs

# %%
x="hsbg"
y="shdfbg"
z="sjbfjs"
print(x+y+z)
# Out:
# hsbgshdfbgsjbfjs

# %%
x=5
y=10

print(x+y)
# Out:
# 15

# %%
x=5
y="Yaswanth"
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 x=5
#       2 y="Yaswanth"
# ----> 3 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x=5
y="Yaswanth"
print(x,y)
# Out:
# 5 Yaswanth

# %% [markdown]
# https://www.w3schools.com/python/python_variables_global.asp
#
#
# Global Variables
# Variables that are created outside of a function (as in all of the examples in the previous pages) are known as global variables.
#
# Global variables can be used by everyone, both inside of functions and outside.

# %%
x="yaswanth"

def alam():
    print("My name is " + x)

alam()
# Out:
# My name is yaswanth

# %%
y=545151

def yaswanth():
    print("The number is " + y)

yaswanth()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 6
#       3 def yaswanth():
#       4     print("The number is " + y)
# ----> 6 yaswanth()
#
# Cell In[34], line 4, in yaswanth()
#       3 def yaswanth():
# ----> 4     print("The number is " + y)
#
# TypeError: can only concatenate str (not "int") to str

# %%
y="hello" 
def yaswanth():
    print("The number is " + y)

yaswanth()
# Out:
# The number is hello

# %%
x="Yaswanth"

def alam():
    x="Hi"
    print("Python is  " + x)

alam()

print("My name is " + x)
# Out:
# Python is  Hi
# My name is Yaswanth

# %%
alam="Yaswanth "

def hi():
    alam='jsbfjsngj'
    print("the name is " + alam)
hi()   

print("the name is " + alam)
# Out:
# the name is jsbfjsngj
# the name is Yaswanth

# %%
alam="Yaswanth "

def hi()
    alam='jsbfjsngj'
    print("the name is " + alam)
hi()   

print("the name is " + alam)
# Out:
#   Cell In[42], line 3
#     def hi()
#             ^
# SyntaxError: expected ':'

# %% [markdown]
# The global Keyword
# Normally, when you create a variable inside a function, that variable is local, and can only be used inside that function.
#
# To create a global variable inside a function, you can use the global keyword.

# %%
def alam():
    global x
    x="fantastsic"
alam()


print("The name is " + x)
# Out:
# The name is fantastsic

# %%
def alam():
    global x
    x="fantastsic"
    print(x)
alam()

print("I am the  "  +  x)
# Out:
# fantastsic
# I am the  fantastsic

# %%
x="Alam"

def alam():
    global x
    x="Good"

alam()

print("i am the " +  x)
# Out:
# i am the Good

# %%
x="Alam"

def alam():
    print("The name is " + x)

alam()

print("i am the " +  x)
# Out:
# The name is Alam
# i am the Alam
