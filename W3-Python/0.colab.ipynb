# %%
print("hello")
# Out:
# hello

# %%
print("test")
# Out:
# test

# %%
def yas():
    print("Hello")

yas()
yas()
# Out:
# Hello
# Hello

# %%
print("hello")
# Out:
# hello

# %%
def yas(alam):
    return(alam - 52)*89-78+262-85692165

print(yas(1414))
print(yas(515215))
# Out:
# -85570763
# -39842474

# %%
def yas(alam):
    return(alam - 52)*89-78+262-85692165

print(yas(1))
# Out:
# -85696520

# %%
def yas(alam):
    return(alam - 52)*89-78+262-85692165

print(yas())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       1 def yas(alam):
#       2     return(alam - 52)*89-78+262-85692165
# ----> 4 print(yas())
#
# TypeError: yas() missing 1 required positional argument: 'alam'

# %%
def abc(vc):
    print(vc , "hgbsdfuhsbhj")

abc("sdfbbndj")
abc(1452)
# Out:
# sdfbbndj hgbsdfuhsbhj
# 1452 hgbsdfuhsbhj

# %%
def abc(vc):
    print("hgbsdfuhsbhj", vc)

abc("sdfbbndj")
abc(1452)
# Out:
# hgbsdfuhsbhj sdfbbndj
# hgbsdfuhsbhj 1452

# %%
def abc(vc):
    print("hgbsdfuhsbhj" +  vc)

abc("sdfbbndj")
# Out:
# hgbsdfuhsbhjsdfbbndj

# %%
def yas(test, alam):
    print(test , " ", alam)

yas("sdfkhfs","sfghdfj")
# Out:
# sdfkhfs   sfghdfj

# %%
def yas(test, alam):
    print(test , " ", alam)

yas("sdfkhfs")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 def yas(test, alam):
#       2     print(test , " ", alam)
# ----> 4 yas("sdfkhfs")
#
# TypeError: yas() missing 1 required positional argument: 'alam'

# %%
def uv(kl = "yaswanth"):
    print("orange" , kl) 

uv("5451")
uv()
# Out:
# orange 5451
# orange yaswanth

# %%
def uv(kl = "yaswanth"):
    print("orange" , kl) 

uv("5451")
uv()
# Out:
# orange 5451
# orange yaswanth
