# %% [markdown]
# https://www.w3schools.com/python/python_strings.asp
#
#
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello".
#
# You can display a string literal with the print() function:

# %%
print("Hello")
print('Hello')
# Out:
# Hello
# Hello

# %%
print("I am yas'wanth")
# Out:
# I am yas'wanth

# %%
print("Hello 'hi")
# Out:
# Hello 'hi

# %%
print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')
# Out:
# It's alright
# He is called 'Johnny'
# He is called "Johnny"

# %%
a="Hello"
print(a)
# Out:
# Hello

# %% [markdown]
# Multiline Strings
# You can assign a multiline string to a variable by using three quotes:
#
#
# Multi line strings can be written either with the single quotes or double quotes
#
#
# '''  _____________'''
#
# """ ________________"""

# %%
a =""" 

Yaswanth 

A 

Networking 


Python 

AUtomation 

"""

print(a)
# Out:
#
#
# Yaswanth
#
# A
#
# Networking
#
#
# Python
#
# AUtomation

# %%
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
a='''sjnjsfs
sndjkfgb



sfgjnsdjndg



sgfnsfj'''


print(a)
# Out:
# sjnjsfs
# sndjkfgb
#
#
#
# sfgjnsdjndg
#
#
#
# sgfnsfj

# %% [markdown]
# Strings are Arrays
# Like many other popular programming languages, strings in Python are arrays of unicode characters.
#
# However, Python does not have a character data type, a single character is simply a string with a length of 1.
#
# Square brackets can be used to access elements of the string.

# %%
a="Hello World"

print(a[1])
# Out:
# e

# %%
a='yasantg'
print(a[5])
# Out:
# t

# %%
a='yasantg'
print(a[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 a='yasantg'
# ----> 2 print(a[10])
#
# IndexError: string index out of range

# %%
a='yasantg'
print(a[-5])
# Out:
# s

# %%
a='yasantg'
print(a[-15])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 a='yasantg'
# ----> 2 print(a[-15])
#
# IndexError: string index out of range

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %% [markdown]
# String Length
# To get the length of a string, use the len() function.

# %%
a="Hello 'world'"

print(len(a))

print(a[10])
# Out:
# 13
# l

# %% [markdown]
# Check String
# To check if a certain phrase or character is present in a string, we can use the keyword in.

# %%
al="I am an network automation engineer and learn python"

print("network" in al)
# Out:
# True

# %%
txt = "The best things in life are free!"
print("free" in tx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 txt = "The best things in life are free!"
# ----> 2 print("free" in tx)
#
# NameError: name 'tx' is not defined

# %%
txt = "The best things in life are free!"
print("free" in txt)
# Out:
# True

# %%
txt = "The best things in life are free!"
print("home" in txt)
# Out:
# False

# %%
txt = "The best things in life are free!"
print("fre" in txt)
# Out:
# True

# %%
txt =" I am network automation engineer"

if "network" in txt:
    print("Yes, It is correct")
# Out:
# Yes, It is correct

# %%
txt =" I am network automation engineer"

if "new" in txt:
    print("Yes, It is correct")
else:
    print("It is false")
# Out:
# It is false

# %%
txt ="I am network automation enginer"

print("network" not in txt)
# Out:
# False

# %%
txt ="I am network automation enginer"

print("new" not in txt)
# Out:
# True

# %%
txt =" UI am network automation engineer"

if "network" not in txt:
    print("It is correct")

# %%
txt =" UI am network automation engineer"

if "network" not in txt:
    print("It is correct")
else:
    print(" It is false")
# Out:
#  It is false

# %%
txt =" UI am network automation engineer"

if "new" not in txt:
    print("It is correct")
# Out:
# It is correct

# %% [markdown]
# https://www.w3schools.com/python/python_strings_slicing.asp
#
# Slicing
# You can return a range of characters by using the slice syntax.
#
# Specify the start index and the end index, separated by a colon, to return a part of the string.

# %%
a="Yassawanth"

print(a[1:5])
# Out:
# assa

# %%
a="Yassawanth"

print(a[:5])
# Out:
# Yassa

# %%
a="Yassawanth"

print(a[5:])
# Out:
# wanth

# %%
a="Yassawanth"

print(a[-1:-3])

# %%
a="Yassawanth"

print(a[-5:-3])
# Out:
# wa

# %%
"yaswanth".upper()
# Out:
# 'YASWANTH'

# %% [markdown]
# https://www.w3schools.com/python/python_strings_modify.asp

# %% [markdown]
# Upper case

# %%
a='yaswanth'
print(a.upper())
# Out:
# YASWANTH

# %%
a='yaswanthg "automation"'
print(a.upper())
# Out:
# YASWANTHG "AUTOMATION"

# %% [markdown]
# Lower Case

# %%
a="HELLO, 'JNFJNJF"

print(a.lower())
# Out:
# hello, 'jnfjnjf

# %% [markdown]
# Remove Whitespace
# Whitespace is the space before and/or after the actual text, and very often you want to remove this space.
#
# Example
# The strip() method removes any whitespace from the beginning or the end:

# %%
a="yaswabtg   'alam'"

print(a.strip())
# Out:
# yaswabtg   'alam'

# %%
a="        yaswabtg'alam'            "

print(a.strip())
# Out:
# yaswabtg'alam'

# %% [markdown]
# Replace String
#
# The replace() method replaces a string with another string:

# %%
a="yaswanth"
print(a.replace("a","s"))
# Out:
# ysswsnth

# %%
a="yaswanth"
print(a.replace("H","s"))
# Out:
# yaswanth

# %%
a="yaswanth"
print(a.replace("s","H"))
# Out:
# yaHwanth

# %% [markdown]
# Split String
# The split() method returns a list where the text between the specified separator becomes the list items.
#
#
# Example
# The split() method splits the string into substrings if it finds instances of the separator:

# %%
a = "Hello, World!"
b = a.split(",")
print(b)
# Out:
# ['Hello', ' World!']

# %%
a = "Hello, World!"
print(a.split(","))
# Out:
# ['Hello', ' World!']

# %%
b="yaswanth , alam!@"

print(b.split(","))
# Out:
# ['yaswanth ', ' alam!@']

# %%
b="I am network automation enginer , and learning python is best "

print(b.split(","))
# Out:
# ['I am network automation enginer ', ' and learning python is best ']

# %%
b="I am network automation enginer , and learning python is best "

print(b.split("and"))
# Out:
# ['I am network automation enginer , ', ' learning python is best ']

# %% [markdown]
# https://www.w3schools.com/python/python_strings_concatenate.asp
#
#
# Python - String Concatenation

# %%
a="yaswanth"
b="alam"

c=a+b

print(c)
# Out:
# yaswanthalam

# %%
a="yaswanth"
b="alam"

c=a-b

print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 4
#       1 a="yaswanth"
#       2 b="alam"
# ----> 4 c=a-b
#       6 print(c)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
a="yaswanth"
b="alam"

c=a*b

print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 4
#       1 a="yaswanth"
#       2 b="alam"
# ----> 4 c=a*b
#       6 print(c)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
a='hi'
b='yaswanth'
print(a+b)
# Out:
# hiyaswanth

# %% [markdown]
# Example
# To add a space between them, add a " ":

# %%
a='yaswanth'
b='alam'

c=a+' '+b

print(c)
# Out:
# yaswanth alam

# %% [markdown]
# https://www.w3schools.com/python/python_strings_format.asp
#
#
# Python - Format - Strings

# %%
age=541854584

b="I am the network enginer " + age

print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 age=541854584
# ----> 3 b="I am the network enginer " + age
#       5 print(b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age="854541515"

b="I am the network enginer " + age

print(b)
# Out:
# I am the network enginer 854541515

# %%
age="sjhfgujdnju"

b="I am the network enginer " + age

print(b)
# Out:
# I am the network enginer sjhfgujdnju

# %% [markdown]
# F-Strings
# F-String was introduced in Python 3.6, and is now the preferred way of formatting strings.
#
# To specify a string as an f-string, simply put an f in front of the string literal, and add curly brackets {} as placeholders for variables and other operations.

# %%
age = 36
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %%
age=545485485

a=f"I am netwiork enginer with , the years of work and {age}"

print(a)
# Out:
# I am netwiork enginer with , the years of work and 545485485

# %%
b=5415145

a=f"I am an enginner , {b},enginner with wotk and {b}"

print(b)
print(id(b))
print(a)
print(id(a))
# Out:
# 5415145
# 1528682149936
# I am an enginner , 5415145,enginner with wotk and 5415145
# 1528683168688

# %% [markdown]
# Placeholders and Modifiers
# A placeholder can contain variables, operations, functions, and modifiers to format the value.

# %%
price = 59

a=f"The network enginn er and the wpork ,enginer work {price}"

print(a)
# Out:
# The network enginn er and the wpork ,enginer work 59

# %% [markdown]
# A placeholder can include a modifier to format the value.
#
# A modifier is included by adding a colon : followed by a legal formatting type, like .2f which means fixed point number with 2 decimals:

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
a=515

b=f"The network engin er {a:.2f}"

print(b)
# Out:
# The network engin er 515.00

# %%
b=48514541


a=f"I am the netwokr wengi  and the eng  {b : .5f}"

print(a)
# Out:
# I am the netwokr wengi  and the eng   48514541.00000

# %%
txt = f"I am an enginer and {20*58} hefheb"
print(txt)
# Out:
# I am an enginer and 1160 hefheb

# %%
a=int(input("Enter the number for a "))
b=int(input("Enter the numbver for b"))

c=f"the network is enginner {a*b}, the name is "

print(c)
# Out:
# the network is enginner 6105, the name is

# %%
a=int(input("Enter the number for a "))
b=int(input("Enter the numbver for b"))

c=f"the network is enginner {a*b}, the name is "

print(c)
# Out:
# the network is enginner 4, the name is

# %%
print(f"The value of the sums is {5+8}")
# Out:
# The value of the sums is 13

# %% [markdown]
# https://www.w3schools.com/python/python_strings_escape.asp
#
#
# Escape Character
#
# To insert characters that are illegal in a string, use an escape character.
#
# An escape character is a backslash \ followed by the character you want to insert.
#
# An example of an illegal character is a double quote inside a string that is surrounded by double quotes:

# %%
txt = "We are the so-called "Vikings" from the north."
# Out:
#   Cell In[83], line 1
#     txt = "We are the so-called "Vikings" from the north."
#                                  ^
# SyntaxError: invalid syntax

# %%
a="The bnynber of the anme "enter" the name iodf "
print(a)
# Out:
#   Cell In[84], line 1
#     a="The bnynber of the anme "enter" the name iodf "
#                                 ^
# SyntaxError: invalid syntax

# %%
a="The bnynber of the anme \"enter\" the name iodf "
print(a)
# Out:
# The bnynber of the anme "enter" the name iodf

# %%
a="my name is yaswanth \"alam\" the network engineer"
print(a)
# Out:
# my name is yaswanth "alam" the network engineer

# %%
b='The network \"the enginner\" enginner '
print(b)
# Out:
# The network "the enginner" enginner

# %%
c=" The network is \'enginner and the\' the enginer "
print(c)
# Out:
#  The network is 'enginner and the' the enginer

# %% [markdown]
# Escape Characters
# Other escape characters used in Python:
#
# Code	Result
# \'	Single Quote
# \\	Backslash
# \n	New Line
# \r	Carriage Return
# \t	Tab
# \b	Backspace
# \f	Form Feed
# \ooo	Octal value
# \xhh	Hex value

# %%
txt = 'It\'s alright.'
print(txt)
# Out:
# It's alright.

# %%
a='alam \'ala'
print(a)
# Out:
# alam 'ala

# %%
txt = "This will insert one \\ (backslash)."
print(txt)
# Out:
# This will insert one \ (backslash).

# %%
txt = "Hello\nWorld!"
print(txt)
# Out:
# Hello
# World!

# %%
a="I am yaswanth \n alam"
print(a)
# Out:
# I am yaswanth
#  alam

# %%
txt = "Hello\rWorld!"
print(txt)
# Out:
# World!

# %%
txt = "Hello\tWorld!"
print(txt)
# Out:
# Hello	World!

# %%
#This example erases one character (backspace):
txt = "Hello \bWorld!"
print(txt)
# Out:
# HelloWorld!

# %%
#A backslash followed by three integers will result in a octal value:
txt = "\110\145\154\154\157"
print(txt)
# Out:
# Hello

# %%
#A backslash followed by an 'x' and a hex number represents a hex value:
txt = "\x48\x65\x6c\x6c\x6f"
print(txt)
# Out:
# Hello

# %% [markdown]
# https://www.w3schools.com/python/python_strings_methods.asp
#
#
#
# String Methods
# Python has a set of built-in methods that you can use on strings.
#
#
# Note: All string methods return new values. They do not change the original string.
#
#
# Method	Description
# capitalize()	Converts the first character to upper case
# casefold()	Converts string into lower case
# center()	Returns a centered string
# count()	Returns the number of times a specified value occurs in a string
# encode()	Returns an encoded version of the string
# endswith()	Returns true if the string ends with the specified value
# expandtabs()	Sets the tab size of the string
# find()	Searches the string for a specified value and returns the position of where it was found
# format()	Formats specified values in a string
# format_map()	Formats specified values in a string
# index()	Searches the string for a specified value and returns the position of where it was found
# isalnum()	Returns True if all characters in the string are alphanumeric
# isalpha()	Returns True if all characters in the string are in the alphabet
# isascii()	Returns True if all characters in the string are ascii characters
# isdecimal()	Returns True if all characters in the string are decimals
# isdigit()	Returns True if all characters in the string are digits
# isidentifier()	Returns True if the string is an identifier
# islower()	Returns True if all characters in the string are lower case
# isnumeric()	Returns True if all characters in the string are numeric
# isprintable()	Returns True if all characters in the string are printable
# isspace()	Returns True if all characters in the string are whitespaces
# istitle()	Returns True if the string follows the rules of a title
# isupper()	Returns True if all characters in the string are upper case
# join()	Joins the elements of an iterable to the end of the string
# ljust()	Returns a left justified version of the string
# lower()	Converts a string into lower case
# lstrip()	Returns a left trim version of the string
# maketrans()	Returns a translation table to be used in translations
# partition()	Returns a tuple where the string is parted into three parts
# replace()	Returns a string where a specified value is replaced with a specified value
# rfind()	Searches the string for a specified value and returns the last position of where it was found
# rindex()	Searches the string for a specified value and returns the last position of where it was found
# rjust()	Returns a right justified version of the string
# rpartition()	Returns a tuple where the string is parted into three parts
# rsplit()	Splits the string at the specified separator, and returns a list
# rstrip()	Returns a right trim version of the string
# split()	Splits the string at the specified separator, and returns a list
# splitlines()	Splits the string at line breaks and returns a list
# startswith()	Returns true if the string starts with the specified value
# strip()	Returns a trimmed version of the string
# swapcase()	Swaps cases, lower case becomes upper case and vice versa
# title()	Converts the first character of each word to upper case
# translate()	Returns a translated string
# upper()	Converts a string into upper case
# zfill()	Fills the string with a specified number of 0 values at the beginning
