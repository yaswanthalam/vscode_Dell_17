# %% [markdown]
# https://www.w3schools.com/python/python_sets.asp
#
#
# Python Sets
#
#
# Set
#
# Sets are used to store multiple items in a single variable.
#
# Set is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Tuple, and Dictionary, all with different qualities and usage.
#
# A set is a collection which is unordered, unchangeable*, and unindexed.
#
#
#
# * Note: Set items are unchangeable, but you can remove items and add new items.
#
#
# Sets are written with curly brackets.

# %% [markdown]
# print("hello)

# %%
print("hello")
# Out:
# hello

# %%
print("hwnren')
# Out:
#   Cell In[3], line 1
#     print("hwnren')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
abc = {"ajkfmnkjfs" , "sdfjnfjd" , "sfgjxjknk" , 6546456 , "4545145"} 
print(abc)
# Out:
# {'ajkfmnkjfs', 'sfgjxjknk', 6546456, 'sdfjnfjd', '4545145'}

# %% [markdown]
# Note: Sets are unordered, so you cannot be sure in which order the items will appear.
#
#
# Set Items
#
# Set items are unordered, unchangeable, and do not allow duplicate values.
#
#
# Unordered
#
# Unordered means that the items in a set do not have a defined order.
#
# Set items can appear in a different order every time you use them, and cannot be referred to by index or key.
#
#
# Unchangeable
#
# Set items are unchangeable, meaning that we cannot change the items after the set has been created.
#
# Once a set is created, you cannot change its items, but you can remove items and add new items.

# %% [markdown]
# Duplicates Not Allowed
#
# Sets cannot have two items with the same value.

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 }

print(abc)
# Out:
# {'mnc', '12354', 5451256, 'yaswanth', 'alam '}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc"}

print(abc)
# Out:
# {'mnc', '12354', 'alam', 5451256, 'yaswanth', 'alam '}

# %% [markdown]
# Note: The values True and 1 are considered the same value in sets, and are treated as duplicates:
#
# Example
#
# True and 1 is considered the same value:

# %%
thisset = {"apple", "banana", "cherry", True, 1, 2}

print(thisset)
# Out:
# {True, 2, 'cherry', 'apple', 'banana'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , True, 1, 2, false, False}

print(abc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , True, 1, 2, false, False}
#       3 print(abc)
#
# NameError: name 'false' is not defined

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , True, 1, 2, "false", False}

print(abc)
# Out:
# {'mnc', True, 2, False, '12354', 'alam', 'false', 'yaswanth', 'alam ', 5451256}

# %% [markdown]
# Note: The values False and 0 are considered the same value in sets, and are treated as duplicates:

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

print(abc)
# Out:
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}

# %% [markdown]
# Get the Length of a Set
#
# To determine how many items a set has, use the len() function.
#
# Example
#
# Get the number of items in a set:

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

print(len(abc))
# Out:
# 7

# %% [markdown]
# Set Items - Data Types
#
# Set items can be of any data type:
#
# Example
#
# String, int and boolean data types:

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}

print(set1)
print(set2)
print(set3)
# Out:
# {'apple', 'cherry', 'banana'}
# {1, 3, 5, 7, 9}
# {False, True}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

mnc = { 1 , 52 , 89 , 3 , 5 , 5, 3}

cdm = {True, False, True}

print(abc)
print(mnc)
print(cdm)
# Out:
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}
# {1, 3, 52, 5, 89}
# {False, True}

# %% [markdown]
# A set can contain different data types:
#
# Example
#
# A set with strings, integers and boolean values:

# %%
set1 = {"abc", 34, True, 40, "male"}

print(set1)
# Out:
# {True, 34, 'male', 'abc', 40}

# %% [markdown]
# type()
#
# From Python's perspective, sets are defined as objects with the data type 'set':

# %%
set1 = {"abc", 34, True, 40, "male"}

print(type(set1))
# Out:
# <class 'set'>

# %% [markdown]
# The set() Constructor
#
# It is also possible to use the set() constructor to make a set.
#
# Example
#
# Using the set() constructor to make a set:

# %%
thisset = set(("apple", "banana", "cherry")) # note the double round-brackets
print(thisset)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
set1 = set(("abc", 34, True, 40, "male"))

print(set1)
# Out:
# {True, 34, 'male', 'abc', 40}

# %%
abc = set(("yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0))
print(abc)
# Out:
# {'mnc', False, '12354', 'alam', 'yaswanth', 'alam ', 5451256}

# %% [markdown]
# Python Collections (Arrays)
#
# There are four collection data types in the Python programming language:
#
# List is a collection which is ordered and changeable. Allows duplicate members.
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
# Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
# Dictionary is a collection which is ordered** and changeable. No duplicate members.

# %% [markdown]
# Length function to see number of items in the set

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
print(len(abc))
# Out:
# 7

# %% [markdown]
# https://www.w3schools.com/python/python_sets_access.asp
#
# Access Items
#
# You cannot access items in a set by referring to an index or a key.
#
# But you can loop through the set items using a for loop, or ask if a specified value is present in a set, by using the in keyword.

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

for i in abc:
    print(i)
# Out:
# mnc
# False
# 12354
# alam
# 5451256
# yaswanth
# alam

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

for i in abc:
    print(abc)
# Out:
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

print("mnc" in abc)
# Out:
# True

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

print("mnc" not in abc)
# Out:
# False

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

print("mn" not in abc)
# Out:
# True

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

print("mn/" not in abc)
# Out:
# True

# %% [markdown]
# Change Items
#
#
# Once a set is created, you cannot change its items, but you can add new items.

# %%
fruits = {"apple", "banana", "cherry"}
if "apple" in fruits:
  print("Yes, apple is a fruit!")
# Out:
# Yes, apple is a fruit!

# %% [markdown]
# https://www.w3schools.com/python/python_sets_add.asp
#
#
# Python - Add Set Items
#
# Add Items
#
# Once a set is created, you cannot change its items, but you can add new items.
#
# To add one item to a set use the add() method.

# %% [markdown]
# Example:
#
#
# Add an item to a set, using the add() method:

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")

print(thisset)
# Out:
# {'orange', 'apple', 'cherry', 'banana'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

abc.add("How are you ?")

print(abc)
# Out:
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'How are you ?', 'alam '}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

abc.add("jshdfjsnfisdfjidfj", "How are you ?")

print(abc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
# ----> 3 abc.add("jshdfjsnfisdfjidfj", "How are you ?")
#       5 print(abc)
#
# TypeError: set.add() takes exactly one argument (2 given)

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}

abc.add( "How are you ?")

abc.add("WHo are")

print(abc)
# Out:
# {'mnc', False, 'alam', 'WHo are', 'alam ', '12354', 'yaswanth', 'How are you ?', 5451256}

# %% [markdown]
# Add Sets
#
# To add items from another set into the current set, use the update() method.
#
# Example
#
# Add elements from tropical into thisset:

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset)
# Out:
# {'apple', 'cherry', 'mango', 'banana', 'papaya', 'pineapple'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
cdn =  {"king", "ban" , "xn" , "tur"}

cdn.update(abc)
print(cdn)
print(abc)
# Out:
# {'mnc', False, '12354', 'alam', 'xn', 'yaswanth', 'alam ', 'tur', 'king', 5451256, 'ban'}
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
cdn =  {"king", "ban" , "xn" , "tur"}

mbr = abc+cdn

print(mbr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
#       2 cdn =  {"king", "ban" , "xn" , "tur"}
# ----> 4 mbr = abc+cdn
#       6 print(mbr)
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %% [markdown]
# Add Any Iterable
#
#
# The object in the update() method does not have to be a set, it can be any iterable object (tuples, lists, dictionaries etc.).

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'apple', 'cherry', 'kiwi', 'orange', 'banana'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
cdn =  {"king", "ban" , "xn" , "tur"}

abc.update(cdn)

print(abc)
# Out:
# {'mnc', False, '12354', 'alam', 'xn', 'yaswanth', 'alam ', 'tur', 'king', 5451256, 'ban'}

# %% [markdown]
# https://www.w3schools.com/python/python_sets_remove.asp
#
#
# Remove Set Items
#
#
# Remove Item
#
# To remove an item in a set, use the remove(), or the discard() method.
#
#
# Example
#
# Remove "banana" by using the remove() method:

# %%
thisset = {"apple", "banana", "cherry"}

thisset.remove("banana")

print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
abc.remove("alam")
print(abc)
# Out:
# {'mnc', False, '12354', 5451256, 'yaswanth', 'alam '}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
abc.remove("alam")
abc.remove("12354")
print(abc)
# Out:
# {'mnc', False, 5451256, 'yaswanth', 'alam '}

# %% [markdown]
# Note: If the item to remove does not exist, remove() will raise an error.

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
abc.remove("aam")
print(abc)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 2
#       1 abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
# ----> 2 abc.remove("aam")
#       3 print(abc)
#
# KeyError: 'aam'

# %% [markdown]
# Example
#
# Remove "banana" by using the discard() method:
#
# Discard doesn't throw any error if the item is not present in the set, but remove will throw an error.

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
abc.discard("12354")
print(abc)
# Out:
# {'mnc', False, 'alam', 5451256, 'yaswanth', 'alam '}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
abc.discard("154")
print(abc)
# Out:
# {'mnc', False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}

# %% [markdown]
# You can also use the pop() method to remove an item, but this method will remove a random item, so you cannot be sure what item that gets removed.
#
# The return value of the pop() method is the removed item.
#
# Example
#
# Remove a random item by using the pop() method:

# %%
thisset = {"apple", "banana", "cherry"}

x = thisset.pop()

print(x) #removed item

print(thisset) #the set after removal
# Out:
# apple
# {'cherry', 'banana'}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
c = abc.pop()
print(c)
print(abc)
# Out:
# mnc
# {False, '12354', 'alam', 5451256, 'yaswanth', 'alam '}

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
dc = abc.pop()
fr = abc.pop()
print(dc, fr)
print(abc)
# Out:
# mnc False
# {'12354', 'alam', 5451256, 'yaswanth', 'alam '}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.clear()

print(thisset)
# Out:
# set()

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
abc.clear()
print(abc)
# Out:
# set()

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
d = abc.clear()
print(d)
print(abc)
# Out:
# None
# set()

# %% [markdown]
# Example
#
# The del keyword will delete the set completely:
#
# It will also throw an error as below after deleting all items in the set. The clear command will not send any error even after removing all items.

# %%
abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
del abc
print(abc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 3
#       1 abc = {"yaswanth" , "alam " , "mnc" , "12354" , 5451256 , "alam" , "mnc" , False , 0}
#       2 del abc
# ----> 3 print(abc)
#
# NameError: name 'abc' is not defined

# %%
thisset = {"apple", "banana", "cherry"}

del thisset

print(thisset) #this will raise an error because the set no longer exists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 5
#       1 thisset = {"apple", "banana", "cherry"}
#       3 del thisset
# ----> 5 print(thisset) #this will raise an error because the set no longer exists
#
# NameError: name 'thisset' is not defined
