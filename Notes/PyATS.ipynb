# %%
print("Helldsfro")
# Out:
# Helldsfro

# %% [markdown]
#             video 1

# %% [markdown]
# https://youtu.be/PDXk3TW1fYk?si=JCLRQkgcBdC9VQZu
#
#
# ![image.png](attachment:image.png)
#
#
#
#
# https://developer.cisco.com/docs/pyats-getting-started/
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)
#
#
# ![image-4.png](attachment:image-4.png)
#
#
#
# Network engineer key benefits
#
#
# Connect to devices and make sure that they are up, running and pingable.
#
# Retrieve information about the network state.
#
# Take before and after snapshots of the network, and then compare them.
#
# Parse device output and store a snapshot, and then automatically run the same commands at specified time intervals to compare the current and previous states.
#
# Use an available test case to verify a stable network topology after an image upgrade, for example.
#
# Perform typical actions such as Reload Devices, Perform Switchover, ShutNoShutBgp, and ConfigUnconfigOspf.
#
#
#
#
#
# https://developer.cisco.com/docs/pyats-getting-started/
#
#
#
# ![image-5.png](attachment:image-5.png)
#
#
# Test Ecosystem Architecture
#
# The following diagram shows a high-level view of the pyATS test automation ecosystem architecture, and demonstrating component and feature relationships.
#
#
#
#     Python Turtorial:
#     https://docs.python.org/3.7/tutorial/
#
#
# System and Software
# pyATS and the pyATS Library are written in Python. You don’t need to know Python, but your system must have one of the following Python versions installed:
#
# Python 3.7.x
#
# Python 3.8.x
#
# Python 3.9.x
#
# Python 3.10.x
#
#
#
#
#
# https://github.com/CiscoTestAutomation
#
# ![image-6.png](attachment:image-6.png)
#
#
# https://github.com/CiscoTestAutomation/pyats
#
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
#         CCNA Devnet Labs PyATS for testing

# %% [markdown]
# https://developer.cisco.com/learning/search/?contentType=lab&page=1&products=pyATS
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# https://developer.cisco.com/learning/labs/intro-to-pyats/devices/
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# https://developer.cisco.com/learning/labs/intro-to-pyats/network-snapshot/
#
#
# ![image.png](attachment:image.png)
#
# https://pubhub.devnetcloud.com/media/genie-feature-browser/docs/#/models
#
# ![image-2.png](attachment:image-2.png)
