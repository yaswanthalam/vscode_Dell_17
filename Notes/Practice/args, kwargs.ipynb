# %% [markdown]
# https://youtu.be/FFpDsC6B2qw?si=QJFG7BjdUesmY9il

# %%
def tea_order(customer_name, tea_type, *args):
    print(customer_name, "ordered a", tea_type, "tea")
    for arg in args:
        print("- Add", arg)

eves_extras = ["milk", "almond"]

tea_order("Eve", "green")
tea_order("Eve", "green", eves_extras)
# Out:
# Eve ordered a green tea
# Eve ordered a green tea
# - Add ['milk', 'almond']

# %%
def tea_order(customer_name, tea_type, *args):
    print(customer_name, "ordered a", tea_type, "tea")
    for arg in args:
        print("- Add", arg)

eves_extras = ["milk", "almond"]

tea_order("Eve", "green")
tea_order("Eve", "green", *eves_extras)
# Out:
# Eve ordered a green tea
# Eve ordered a green tea
# - Add milk
# - Add almond

# %%
def cofee_order(customer1_name, cofee_type):
    print(customer1_name , "ordered an" , cofee_order)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
# Out:
# Yaswanth Alam ordered an <function cofee_order at 0x0000018F96017920>

# %%
def cofee_order(customer1_name, cofee_type):
    print(customer1_name , "ordered an" , cofee_type)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino

# %%
def cofee_order(customer1_name, cofee_type):
    print(customer1_name , "ordered an" , cofee_type)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python

# %%
def cofee_order(customer1_name, cofee_type):
    print(customer1_name , "ordered an" , cofee_type)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "cisco")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       2     print(customer1_name , "ordered an" , cofee_type)
#       4 cofee_order("Yaswanth Alam" , "Mocha Cappucino")
# ----> 5 cofee_order("Automation Engineer" , "Python" , "cisco")
#
# TypeError: cofee_order() takes 2 positional arguments but 3 were given

# %%
def cofee_order(customer1_name, cofee_type , cisco = None):
    print(customer1_name , "ordered an" , cofee_type)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "cisco")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python

# %%
def cofee_order(customer1_name, cofee_type , cisco = None):
    print(customer1_name , "ordered an" , cofee_type)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python

# %%
def cofee_order(customer1_name, cofee_type , cisco = None):
    print(customer1_name , "ordered an" , cofee_type)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper", "Cisco")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       2     print(customer1_name , "ordered an" , cofee_type)
#       4 cofee_order("Yaswanth Alam" , "Mocha Cappucino")
# ----> 5 cofee_order("Automation Engineer" , "Python" , "Juniper", "Cisco")
#
# TypeError: cofee_order() takes from 2 to 3 positional arguments but 4 were given

# %%
def cofee_order(customer1_name, cofee_type , cisco = None , juniper = None):
    print(customer1_name , "ordered an" , cofee_type)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper", "Cisco")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python

# %%
def cofee_order(customer1_name, cofee_type , cisco = None):
    print(customer1_name , "ordered an" , cofee_type)
    if cisco != None:
        print("     -Device", cisco)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python
#      -Device Juniper

# %%
def cofee_order(customer1_name, cofee_type , cisco = None , Juniper = None):
    print(customer1_name , "ordered an" , cofee_type)
    if cisco != None:
        print("     -Device", cisco)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper" , "Cisco")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python
#      -Device Juniper

# %%
def cofee_order(customer1_name, cofee_type , cisco = None , Juniper = None):
    print(customer1_name , "ordered an" , cofee_type)
    if cisco != None:
        print("     -Device", cisco)
    if Juniper != None:
        print( "    -Add", Juniper)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", "lldp", "Engineering is the best")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python
#      -Device Juniper
# macsec ordered an lacp
#      -Device lldp
#     -Add Engineering is the best

# %%
def cofee_order(customer1_name, cofee_type , cisco = None , Juniper = None):
    print(customer1_name , "ordered an" , cofee_type)
    if cisco == None:
        print("     -Device", cisco)
    if Juniper != None:
        print( "    -Add", Juniper)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", "lldp", "Engineering is the best")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
#      -Device None
# Automation Engineer ordered an Python
# macsec ordered an lacp
#     -Add Engineering is the best

# %%
def cofee_order(customer1_name, cofee_type , cisco = None , Juniper = None):
    print(customer1_name , "ordered an" , cofee_type)
    if cisco == None:
        print("     -Device", cisco)
    if Juniper == None:
        print( "    -Add", Juniper)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", "lldp", "Engineering is the best")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
#      -Device None
#     -Add None
# Automation Engineer ordered an Python
#     -Add None
# macsec ordered an lacp

# %%
def cofee_order(customer1_name, cofee_type , *args):
    print(customer1_name , "ordered an" , cofee_type)
    print("      Add the values of  ", args)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", "lldp", "Engineering is the best")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
#       Add the values of   ()
# Automation Engineer ordered an Python
#       Add the values of   ('Juniper',)
# macsec ordered an lacp
#       Add the values of   ('lldp', 'Engineering is the best')

# %%
def cofee_order(customer1_name, cofee_type , *args):
    print(customer1_name , "ordered an" , cofee_type)
    for arg in args:
        print("   add" , arg)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", "lldp", "Engineering is the best")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python
#    add Juniper
# macsec ordered an lacp
#    add lldp
#    add Engineering is the best

# %%
def cofee_order(customer1_name, cofee_type , *args , **kwargs):
    print(customer1_name , "ordered an" , cofee_type)
    for arg in args:
        print("   add" , arg)
    for arg in kwargs:
        print("     test ", kwargs)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", "lldp", "Engineering is the best" , Network = "Python")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python
#    add Juniper
# macsec ordered an lacp
#    add lldp
#    add Engineering is the best
#      test  {'Network': 'Python'}

# %%
def cofee_order(customer1_name, cofee_type , *args , **kwargs):
    print(customer1_name , "ordered an" , cofee_type)
    for arg in args:
        print("   add" , arg)
    for arg in kwargs:
        print( kwargs)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", "lldp", "Engineering is the best" , Network = "Python")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python
#    add Juniper
# macsec ordered an lacp
#    add lldp
#    add Engineering is the best
# {'Network': 'Python'}

# %%
def cofee_order(customer1_name, cofee_type ,**kwargs):
    print(customer1_name , "ordered an" , cofee_type)
    for key, value in kwargs.items():
            print("   add" , key, ";", value)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
#cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", protocol = "lldp", Network = "Python")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# macsec ordered an lacp
#    add protocol ; lldp
#    add Network ; Python

# %%
def cofee_order(customer1_name, cofee_type ,*args, **kwargs):
    print(customer1_name , "ordered an" , cofee_type)
    for arg in args:
          print("   - Add the value", arg)
    for key, value in kwargs.items():
            print("   add" , key, ";", value)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", "kusto", protocol = "lldp", Network = "Python")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python
#    - Add the value Juniper
# macsec ordered an lacp
#    - Add the value kusto
#    add protocol ; lldp
#    add Network ; Python

# %%
def cofee_order(customer1_name, cofee_type ,*args, **kwargs):
    print(customer1_name , "ordered an" , cofee_type)
    for arg in args:
          print("   - Add the value", arg)
    for key, value in kwargs.items():
            print("   add" , key, ";", value)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", "kusto", protocol = "lldp", Network = "Python")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python
#    - Add the value Juniper
# macsec ordered an lacp
#    - Add the value kusto
#    add protocol ; lldp
#    add Network ; Python

# %% [markdown]
# In the above we need to always put the positional arguments before the key word argumnets.
#
# The postional argumnet was "Kusto" and the key word argumnet was protocol = "lldp", Network = "Python"

# %%
def cofee_order(customer1_name, cofee_type ,*args, **kwargs):
    print(customer1_name , "ordered an" , cofee_type)
    for arg in args:
          print("   - Add the value", arg)
    for key, value in kwargs.items():
            print("   add" , key, ";", value)

cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper")
cofee_order("macsec", "lacp", protocol = "lldp", Network = "Python" , "kusto")
# Out:
#   Cell In[4], line 10
#     cofee_order("macsec", "lacp", protocol = "lldp", Network = "Python" , "kusto")
#                                                                                  ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def cofee_order(customer1_name, cofee_type ,*args, **kwargs):
    print(customer1_name , "ordered an" , cofee_type)
    for arg in args:
          print("   - Add the value", arg)
    for key, value in kwargs.items():
            print("   add" , key, ";", value)

extra_items = ("bgp", "is-is", "OSPF" , "MPLS" , "RSVP")


cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper" , *extra_items)
cofee_order("macsec", "lacp", "kusto", protocol = "lldp", Network = "Python")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python
#    - Add the value Juniper
#    - Add the value bgp
#    - Add the value is-is
#    - Add the value OSPF
#    - Add the value MPLS
#    - Add the value RSVP
# macsec ordered an lacp
#    - Add the value kusto
#    add protocol ; lldp
#    add Network ; Python

# %%
def cofee_order(customer1_name, cofee_type ,*args, **kwargs):
    print(customer1_name , "ordered an" , cofee_type)
    for arg in args:
          print("   - Add the value", arg)
    for key, value in kwargs.items():
            print("   add" , key, ";", value)

extra_items = {"bgp" : "is-is", "OSPF" : "MPLS"}


cofee_order("Yaswanth Alam" , "Mocha Cappucino")
cofee_order("Automation Engineer" , "Python" , "Juniper" , **extra_items)
cofee_order("macsec", "lacp", "kusto", protocol = "lldp", Network = "Python")
# Out:
# Yaswanth Alam ordered an Mocha Cappucino
# Automation Engineer ordered an Python
#    - Add the value Juniper
#    add bgp ; is-is
#    add OSPF ; MPLS
# macsec ordered an lacp
#    - Add the value kusto
#    add protocol ; lldp
#    add Network ; Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
