# %% [markdown]
# To preview the commands we typed in .me file
#
#
# press ctrl + k and then letter v, a page appears like I show here
#
# ![image.png](attachment:image.png)

# %% [markdown]
# https://youtu.be/Hgucu1ch3mo?si=pIS9RqQ8q_QZTdxK
